# %%
# !pip install tensorflow
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.54.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)

# %%
import json
import pandas as pd

# Load the training dataset
train_df = pd.read_json('train_with-reference.jsonl', lines=True)

# Load the testing dataset
test_df = pd.read_json('test_without-reference.jsonl', lines=True)

# %%
pip install jsonlines
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonlines
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.1.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-3.1.0

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1

# %%
import jsonlines

with jsonlines.open("train_with-reference.jsonl") as reader:
    train_data = [obj for obj in reader]
    
print(train_data[1]['id'])
# Out:
# train_0002

# %%
import jsonlines

with jsonlines.open('train_with-reference.jsonl') as reader:
    for obj in reader:
        print(obj)
# Out:
# {'id': 'train_0001', 'utterances': [{'text': 'A) pull through', 'speaker': 'student'}, {'text': 'OK great', 'speaker': 'teacher'}, {'text': 'Not sure about the meaning of the second one... Does that person mean that being the prime minister he had to survive??', 'speaker': 'student'}], 'response': {'text': 'Ah yes good question - this is a bit ambiguous....', 'speaker': 'teacher'}}
# {'id': 'train_0002', 'utterances': [{'text': 'willpower?)', 'speaker': 'student'}, {'text': 'Yes!', 'speaker': 'teacher'}, {'text': 'So, a bit of willpower, and kids will be super successful!', 'speaker': 'teacher'}, {'text': 'Do you think it worked?', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'No! :))', 'speaker': 'teacher'}, {'text': 'why?', 'speaker': 'student'}, {'text': 'because human beings are way more complex than that', 'speaker': 'teacher'}, {'text': "You know how in science it's very important that the results of a study be replicated?", 'speaker': 'teacher'}, {'text': "yes, it's very important", 'speaker': 'student'}], 'response': {'text': 'yes, so scientists did more and more marshmallow tests and followed the lives of the kids, and they did not get the same results as the original study', 'speaker': 'teacher'}}
# {'id': 'train_0003', 'utterances': [{'text': "I see. I think it means 'don't make me start'", 'speaker': 'student'}, {'text': 'Yes actually - especially something like laughing or in the example i just sent?', 'speaker': 'teacher'}, {'text': 'sorry exactly i meant not actually', 'speaker': 'teacher'}, {'text': "yes, I understand. Similar to 'activate'", 'speaker': 'student'}, {'text': 'yes absolutely and in fact in the original example this would be a precise synonym  (less so for these recent examples but same idea)', 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}, {'text': 'OK so one more: Although the situation in the uk is getting worse things are nuder control and panic has not yet set in', 'speaker': 'teacher'}], 'response': {'text': 'under control', 'speaker': 'teacher'}}
# {'id': 'train_0004', 'utterances': [{'text': 'Wait a minute', 'speaker': 'student'}, {'text': 'Does 9.30 am on Tuesday sound good to you?', 'speaker': 'teacher'}, {'text': 'Let’s talk about it in the Skype, okay?', 'speaker': 'student'}, {'text': 'Ok', 'speaker': 'teacher'}, {'text': 'Squeak', 'speaker': 'student'}, {'text': 'Aha, yes', 'speaker': 'teacher'}, {'text': "The food that's left from yesterday?", 'speaker': 'teacher'}, {'text': 'But I know what does it mean now', 'speaker': 'student'}, {'text': 'Leftover', 'speaker': 'student'}, {'text': 'leftover food (leftover is an adjective here) or leftovers (plural noun)', 'speaker': 'teacher'}, {'text': 'Am I right?', 'speaker': 'student'}, {'text': 'Yes!', 'speaker': 'teacher'}, {'text': 'So 3 words', 'speaker': 'student'}, {'text': 'For example, I sometimes have leftovers for lunch', 'speaker': 'teacher'}, {'text': 'And a part of England?', 'speaker': 'teacher'}, {'text': 'Makes sense', 'speaker': 'student'}, {'text': 'like Yorkshire or Cambridgeshire', 'speaker': 'teacher'}, {'text': 'County', 'speaker': 'student'}], 'response': {'text': 'Yes, well done!', 'speaker': 'teacher'}}
# {'id': 'train_0005', 'utterances': [{'text': 'Oh wow, incredible!', 'speaker': 'teacher'}, {'text': 'There is special programme', 'speaker': 'student'}, {'text': 'Called stop mothion', 'speaker': 'student'}, {'text': 'Sounds like a lot of work, too, 1000 photos!', 'speaker': 'teacher'}, {'text': 'It took us about  3 hours', 'speaker': 'student'}, {'text': 'Very cool', 'speaker': 'teacher'}, {'text': "<STUDENT>, could you go back to this bit and insert some articles? 'Thank you for taking part in this study. Please go ahead and chat here, and remember that all conversations are recorded.", 'speaker': 'teacher'}, {'text': 'Oh no, what happened! Sorry', 'speaker': 'teacher'}, {'text': 'The programme went mad, please ignore it', 'speaker': 'teacher'}], 'response': {'text': 'are you there?', 'speaker': 'teacher'}}
# {'id': 'train_0006', 'utterances': [{'text': 'sorry my internet become slowly just now.', 'speaker': 'student'}, {'text': 'Did you see the tiny change? (One letter!)', 'speaker': 'teacher'}, {'text': 'relationships/relations', 'speaker': 'student'}, {'text': "Yes ok fine ... 'relationships' is logical and often possible BUT 'relations' very common in this context (e.g. international relations )", 'speaker': 'teacher'}, {'text': "BUT with 's' at the end!", 'speaker': 'teacher'}, {'text': 'okey, thanks', 'speaker': 'student'}], 'response': {'text': "do you know the word 'colloborate'?", 'speaker': 'teacher'}}
# {'id': 'train_0007', 'utterances': [{'text': "For example, I can have visitors in my house - just people who've come to see me to talk about something but they're not tourists!", 'speaker': 'teacher'}, {'text': 'Ahhh but can it be a way to use a different word in the essay?', 'speaker': 'student'}, {'text': 'For example, if I use visitors because it’s better, can I change this word ?', 'speaker': 'student'}, {'text': "It's not quite right I'd say BUT it's OK BUT there are other ways you can change other parts of your answer more accurately do you see?", 'speaker': 'teacher'}], 'response': {'text': 'so hold on....', 'speaker': 'teacher'}}
# {'id': 'train_0008', 'utterances': [{'text': 'Ah, so you do have some experience of chatting in English!', 'speaker': 'teacher'}, {'text': "Which games do you play? My husband is really into video games, but I only play some Lego games with my son (he's nearly 5)", 'speaker': 'teacher'}, {'text': 'My favourite games are GTA5 and Fortnite', 'speaker': 'student'}, {'text': 'I see! My favourite is Lego superheroes. Beginner level, I know :)', 'speaker': 'teacher'}, {'text': "Does your husband play on Xbox, doesn't he?", 'speaker': 'student'}], 'response': {'text': 'No, he plays on his desktop', 'speaker': 'teacher'}}
# {'id': 'train_0009', 'utterances': [{'text': 'Yes, I see how important is to keep listening and reading things in English', 'speaker': 'student'}, {'text': "Well, I'll continue", 'speaker': 'student'}, {'text': "yes it's the one thing really you can do", 'speaker': 'teacher'}, {'text': '21 medical', 'speaker': 'student'}, {'text': 'yes good', 'speaker': 'teacher'}, {'text': '22 admiration', 'speaker': 'student'}, {'text': 'fine', 'speaker': 'teacher'}, {'text': '23 enthusiasm', 'speaker': 'student'}, {'text': 'yes good', 'speaker': 'teacher'}, {'text': "no idea about 24 (is this sentence correct? is there a better way of saying that I don't know the answer??)", 'speaker': 'student'}, {'text': "Um you 'no idea about' is fine and common don't worry...apart from that...I haven't got a clue", 'speaker': 'teacher'}], 'response': {'text': 'is common', 'speaker': 'teacher'}}
# {'id': 'train_0010', 'utterances': [{'text': "they do overlap in a way though it is true...ok sorry I'll stop and wait for you!", 'speaker': 'teacher'}, {'text': 'it is increasing argued that the most effective way to address the problem of discipline is responsibility. Although I strongly agree that responsibility plays a significant role, education system is more important.', 'speaker': 'student'}, {'text': 'OK thanks <STUDENT> ....so , in terms of language this is great......', 'speaker': 'teacher'}], 'response': {'text': "BUT...it doesn't really make sense I'm afraid!", 'speaker': 'teacher'}}
# {'id': 'train_0011', 'utterances': [{'text': 'I understand what you mean now', 'speaker': 'student'}, {'text': "It can be very frustrating if you don't do it fairly early on..", 'speaker': 'teacher'}, {'text': "I think it's our teachers fault (teachers here). They don't care too much about it, here grammar seems to be veryyy important", 'speaker': 'student'}, {'text': "Yes I'm sure you're right - I guess it'll change with the exposure to authentic speech on the internet etc", 'speaker': 'teacher'}, {'text': "it's definitely changed already in my expereince", 'speaker': 'teacher'}], 'response': {'text': 'the average pronunciation of my younger students is better than 10 years ago for example', 'speaker': 'teacher'}}
# {'id': 'train_0012', 'utterances': [{'text': "So now I'm looking for a job in the University of Cambridge.", 'speaker': 'student'}, {'text': "in' is correct this time?", 'speaker': 'student'}, {'text': "That's a good question - 'at' would be more common here", 'speaker': 'teacher'}, {'text': 'OK, thank you!', 'speaker': 'student'}, {'text': "OK! What about: I'll meet you in/at the cinema?", 'speaker': 'teacher'}, {'text': "I think 'at' is correct.", 'speaker': 'student'}, {'text': "Yes basically - if you say 'in' you're emphasising...?", 'speaker': 'teacher'}, {'text': 'Inside something?', 'speaker': 'student'}], 'response': {'text': "Yes exactly - whereas 'at' could be just outside or whatever", 'speaker': 'teacher'}}
# {'id': 'train_0013', 'utterances': [{'text': 'commonly collocates with e.g. support for the government is wavering (i.e. weakening / faltering )', 'speaker': 'teacher'}, {'text': 'good question - yes!', 'speaker': 'teacher'}, {'text': "so maybe you often say 'it depends' <STUDENT> to a question like: 'is it always raining in the UK?' but we often say answer i'it varies' as an initial simple answer (do you see?)'", 'speaker': 'teacher'}, {'text': "it varies'", 'speaker': 'teacher'}, {'text': 'yess', 'speaker': 'student'}, {'text': 'ok great - would you like to have a go at page 14?', 'speaker': 'teacher'}, {'text': 'sure', 'speaker': 'student'}], 'response': {'text': 'ok', 'speaker': 'teacher'}}
# {'id': 'train_0014', 'utterances': [{'text': "So I have cat <CAT'S NAME>, dog <DOG'S NAME> and lizard <LIZARD'S NAME>", 'speaker': 'student'}, {'text': 'Lucky you! Is it male or female?', 'speaker': 'teacher'}, {'text': "It's similar to look after cat", 'speaker': 'student'}, {'text': 'Oh really?', 'speaker': 'teacher'}, {'text': "If you want to know is it male or female you'll need to take DNA", 'speaker': 'student'}, {'text': "It's very expansive", 'speaker': 'student'}, {'text': "Oh wow! Is that why it's called <LIZARD'S NAME>, because it could be both a boy's and a girl's name?", 'speaker': 'teacher'}, {'text': 'Yes', 'speaker': 'student'}], 'response': {'text': 'Makes sense', 'speaker': 'teacher'}}
# {'id': 'train_0015', 'utterances': [{'text': "Sorry 'the'", 'speaker': 'teacher'}, {'text': "Ahhh sorry <STUDENT> no ..your 'the' is fine actually but you need to delete 'of' ok?", 'speaker': 'teacher'}, {'text': "both of charts illustrate the different reactions' about ashdown museum before and after  the renovation", 'speaker': 'student'}, {'text': 'both the charts?', 'speaker': 'student'}, {'text': 'sorry', 'speaker': 'student'}, {'text': "visitors' reactions", 'speaker': 'student'}], 'response': {'text': 'Ok thanks so...Botb charts illustrate the different reactions to Ashdown museum before and after its renovation = good', 'speaker': 'teacher'}}
# {'id': 'train_0016', 'utterances': [{'text': 'ok, thanks I will remember this rules', 'speaker': 'student'}, {'text': "OK <STUDENT> so I guess that's it for these lessons - It was good to work with you and I wish you  the best of the luck with the exam...", 'speaker': 'teacher'}, {'text': 'thanks very much, I am really happy with you in class.', 'speaker': 'student'}, {'text': 'OK no problem - all the best and I hope things get back to normal for you soon!', 'speaker': 'teacher'}], 'response': {'text': 'Well done on all your hard work - stay positive and keep working hard!', 'speaker': 'teacher'}}
# {'id': 'train_0017', 'utterances': [{'text': 'etc.', 'speaker': 'teacher'}, {'text': "that's my reasons", 'speaker': 'student'}, {'text': "And the reason many diets don't work is becausea no one has enought willpower. Because it's not a thing!", 'speaker': 'teacher'}, {'text': 'What do you think?', 'speaker': 'teacher'}, {'text': "I don't know what to say", 'speaker': 'student'}, {'text': '...', 'speaker': 'student'}, {'text': 'Ok, no worries. Just something to think about', 'speaker': 'teacher'}, {'text': 'Shall we go back to your quiz?', 'speaker': 'teacher'}, {'text': 'The white dog!', 'speaker': 'teacher'}, {'text': 'yessss!!!!', 'speaker': 'student'}, {'text': 'I have an idea, actually. Is it a movie?', 'speaker': 'teacher'}, {'text': '1.Summer 2.White dog 4.TOP', 'speaker': 'student'}, {'text': 'Thank you', 'speaker': 'teacher'}, {'text': '3 was Crisps', 'speaker': 'student'}], 'response': {'text': 'I remember :)', 'speaker': 'teacher'}}
# {'id': 'train_0018', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Hi <TEACHER>', 'speaker': 'student'}], 'response': {'text': 'HEy there - sorrry give me a minute - go to relight my fire...', 'speaker': 'teacher'}}
# {'id': 'train_0019', 'utterances': [{'text': "Wow yeah that's pretty heavy - as I say that's definitely on the horizon here sooner rather than later...", 'speaker': 'teacher'}, {'text': 'although weirdly the schools are sti;l open!', 'speaker': 'teacher'}, {'text': "I don't understand why they keep the schools open having the experiences of Italy and now Spain", 'speaker': 'student'}, {'text': "There are so many new cases every day... It's scary", 'speaker': 'student'}], 'response': {'text': 'Yeah I think the rationale is that: Stop key workers from having childcare commitments/prevent vulnerable grandparents from being exposed through providing childcare', 'speaker': 'teacher'}}
# {'id': 'train_0020', 'utterances': [{'text': 'Yes I get the thing about talking loudly on the phone - common in Spain I imagine!', 'speaker': 'teacher'}, {'text': "I don't really get my head in when driving (I know it's wrong but I don't know how to...)", 'speaker': 'student'}, {'text': 'Um..how do you mean? YOu mean the tailgaters?', 'speaker': 'teacher'}, {'text': "E.g. 'It doesn't do my head in when people drive right behind me.'?", 'speaker': 'teacher'}, {'text': "yes, but my question is about 'get my head in' is it right??", 'speaker': 'student'}], 'response': {'text': 'No....', 'speaker': 'teacher'}}
# {'id': 'train_0021', 'utterances': [{'text': 'You are very brave! Arabic, Japanese... I see japanese writing like drawing', 'speaker': 'student'}, {'text': 'yes - just pictures - a challenge to rememember!', 'speaker': 'teacher'}, {'text': "Yes, I sea what you mean. It's very frustrating when you say something and people don't understand you", 'speaker': 'student'}, {'text': "I'm good at remembering word forms in different languages but the pictures are tough! Arabic is just an alphabet so it's actually not really very hard you see?", 'speaker': 'teacher'}], 'response': {'text': 'Yes sure....', 'speaker': 'teacher'}}
# {'id': 'train_0022', 'utterances': [{'text': "OK sorry ..so ...the phrase e.g. 'it is not as cheap as' when said quickly is like:    'snotəzcheapəz' - that's what i meant ....", 'speaker': 'teacher'}, {'text': 'Sorry , have i lost you?!', 'speaker': 'teacher'}, {'text': 'Difficult to make this clear in this format!', 'speaker': 'teacher'}, {'text': 'haha no, I finally know what you wanted to say earlier', 'speaker': 'student'}], 'response': {'text': 'ok thank god', 'speaker': 'teacher'}}
# {'id': 'train_0023', 'utterances': [{'text': 'Not bad! Can i ask you switch one sentence to a different place??', 'speaker': 'teacher'}, {'text': 'So again you have 4 sentences. Which one would you move? 1,2,3, or 4?', 'speaker': 'teacher'}, {'text': 'move 2', 'speaker': 'student'}], 'response': {'text': 'To where?', 'speaker': 'teacher'}}
# {'id': 'train_0024', 'utterances': [{'text': 'keywords they focus on in that page i mean', 'speaker': 'teacher'}, {'text': "OK, I'll do it now", 'speaker': 'student'}, {'text': 'ok', 'speaker': 'teacher'}, {'text': '...provocative, and supplied +startling+ messages about psycology...', 'speaker': 'student'}, {'text': "Is it enough this piece of text to work on it? the word I don't konw is startling", 'speaker': 'student'}, {'text': "ok thanks....'startling' does it mean: obvoius or surprising do you think? is there a context in the text to help you?", 'speaker': 'teacher'}], 'response': {'text': 'obvious', 'speaker': 'teacher'}}
# {'id': 'train_0025', 'utterances': [{'text': '?', 'speaker': 'student'}, {'text': 'slithering', 'speaker': 'teacher'}, {'text': 'A snake was slithering throught the grass, hissing gently', 'speaker': 'teacher'}, {'text': "Does the word 'slithering' remind you of something?", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'what?', 'speaker': 'teacher'}, {'text': 'Slitherin', 'speaker': 'student'}, {'text': 'Correct! Slytherin, one of the Hogwarts houses', 'speaker': 'teacher'}, {'text': 'now you know where it comes from :)', 'speaker': 'teacher'}, {'text': "Ok, next. A big snake that is not poisonous but can use it's body weight to wrap around a small animal and kill it this way...", 'speaker': 'teacher'}, {'text': '?', 'speaker': 'student'}, {'text': "it's a boa constrictor", 'speaker': 'teacher'}], 'response': {'text': 'Big beautiful snakes', 'speaker': 'teacher'}}
# {'id': 'train_0026', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'hello <TEACHER>', 'speaker': 'student'}], 'response': {'text': 'How are you? And why is yoghurt on your mind this morning? :)', 'speaker': 'teacher'}}
# {'id': 'train_0027', 'utterances': [{'text': 'evidence', 'speaker': 'student'}, {'text': 'yes, good!', 'speaker': 'teacher'}, {'text': "It's not just about criminals. 'Her good marks are evidence of her hard work' or something like that", 'speaker': 'teacher'}, {'text': 'What do we call the food left from the day before?', 'speaker': 'teacher'}, {'text': 'leftover', 'speaker': 'student'}, {'text': 'yes, good!', 'speaker': 'teacher'}, {'text': "Must / could / might / can / can't are all modals of d........", 'speaker': 'teacher'}, {'text': 'deduction', 'speaker': 'student'}, {'text': 'Well done!', 'speaker': 'teacher'}, {'text': 'Ok, some prepositions', 'speaker': 'teacher'}, {'text': '___ the morning, ___ night', 'speaker': 'teacher'}, {'text': 'in ,at', 'speaker': 'student'}], 'response': {'text': 'Good!', 'speaker': 'teacher'}}
# {'id': 'train_0028', 'utterances': [{'text': 'Hi <STUDENT> how are you? Ok?', 'speaker': 'teacher'}, {'text': 'fine thanks', 'speaker': 'student'}, {'text': "Ok great- by the way is <STUDENT'S SHORT NAME> a short form for <STUDENT'S FULL NAME> in speaking?", 'speaker': 'teacher'}, {'text': 'yes it is', 'speaker': 'student'}, {'text': 'Ok yes not surprising i guess!', 'speaker': 'teacher'}, {'text': 'Ok so you have the museum pie charts right?', 'speaker': 'teacher'}, {'text': 'yes!', 'speaker': 'student'}], 'response': {'text': 'Ok so....could you try an intro for them please?!', 'speaker': 'teacher'}}
# {'id': 'train_0029', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Hello', 'speaker': 'student'}, {'text': 'How are you?', 'speaker': 'teacher'}, {'text': "I'm fine", 'speaker': 'student'}, {'text': "How's <LIZARD'S NAME> the lizard?", 'speaker': 'teacher'}, {'text': "It's on my hand", 'speaker': 'student'}], 'response': {'text': ':) is it quite tame then?', 'speaker': 'teacher'}}
# {'id': 'train_0030', 'utterances': [{'text': "Hi <STUDENT> how's it going?", 'speaker': 'teacher'}, {'text': 'I,m fine thank you and you', 'speaker': 'student'}, {'text': "Yes not bad thanks - I couldn't sleep last night though because of the wind!", 'speaker': 'teacher'}, {'text': 'so sad, it’s strong windy', 'speaker': 'student'}, {'text': "yes it's really windy", 'speaker': 'teacher'}], 'response': {'text': 'so <STUDENT> do you have the pie charts in front of you?', 'speaker': 'teacher'}}
# {'id': 'train_0031', 'utterances': [{'text': 'I only know the meaning of the first one', 'speaker': 'student'}, {'text': "right OK - I'll give you definitions - see if you can match them up ok? hold on", 'speaker': 'teacher'}, {'text': 'Ok', 'speaker': 'student'}, {'text': 'a) (a situation) start to improve after a difficult period b) do or say something that will upset people or cause problems c) be easy and without problems d)  consider an idea, problem, or situation and try to deal with it', 'speaker': 'teacher'}, {'text': '1 d', 'speaker': 'student'}, {'text': 'yep', 'speaker': 'teacher'}, {'text': 'Maybe 2 b', 'speaker': 'student'}], 'response': {'text': "that's it!", 'speaker': 'teacher'}}
# {'id': 'train_0032', 'utterances': [{'text': "we often say e.g. 'THe pay is really good' or What's the pay like? you see", 'speaker': 'teacher'}, {'text': 'or after a pronoun e.g. my/you pay etc', 'speaker': 'teacher'}, {'text': 'your pay i mean', 'speaker': 'teacher'}, {'text': "So e.g. there's a problem with my pay - i need to talk to the finance department at work (ok?)", 'speaker': 'teacher'}, {'text': 'I understand now. Thank you!', 'speaker': 'student'}, {'text': 'Sorry one more I;ve realised is really common', 'speaker': 'teacher'}, {'text': 'okkk', 'speaker': 'student'}], 'response': {'text': "e.g. Doctors' pay is set to rise by more than 5%...", 'speaker': 'teacher'}}
# {'id': 'train_0033', 'utterances': [{'text': 'What does thick means in your sentence??', 'speaker': 'student'}, {'text': "Yes no I see what you mean about he educated/posh thing - i realise you weren't being so simplistic", 'speaker': 'teacher'}, {'text': 'so stupid is general - dumb = informal american and thick = informal British', 'speaker': 'teacher'}, {'text': 'so think is a less rude way of saying stupid?', 'speaker': 'student'}, {'text': 'not less rude actually! just another word....', 'speaker': 'teacher'}, {'text': "not very bright' = less direct!", 'speaker': 'teacher'}, {'text': 'you know bright means clever right?', 'speaker': 'teacher'}, {'text': 'I see', 'speaker': 'student'}], 'response': {'text': "smart' in the US and 'bright' in the UK", 'speaker': 'teacher'}}
# {'id': 'train_0034', 'utterances': [{'text': "I don't know what to say about Trump", 'speaker': 'student'}, {'text': "I found something online 'I have a great relationship with the blacks'", 'speaker': 'student'}, {'text': "ha! not an easy subject to face maybe! well how about: 'Trump likes to provoke his liberal opponents by using deliberately offensive language - a bit bland really but just a basic examples", 'speaker': 'teacher'}, {'text': 'example', 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}], 'response': {'text': 'what else could be provocative?', 'speaker': 'teacher'}}
# {'id': 'train_0035', 'utterances': [{'text': "ok'", 'speaker': 'student'}, {'text': 'One question: If I roll two dice the chances of me getting a double six are _______? Any ideas for the adjective?', 'speaker': 'teacher'}, {'text': "Don't worry if not! Just tell me...", 'speaker': 'teacher'}, {'text': 'High or low?', 'speaker': 'teacher'}, {'text': 'impossible', 'speaker': 'student'}, {'text': 'low', 'speaker': 'student'}, {'text': 'OK thanks!', 'speaker': 'teacher'}], 'response': {'text': "So another way of saying this could be: 'It is very _______ that you will get a double six.'?", 'speaker': 'teacher'}}
# {'id': 'train_0036', 'utterances': [{'text': 'There are many Canarian? names: Yeray, Gara, Jonay, Yaiza,', 'speaker': 'student'}, {'text': "Yes, that's the only thing we keep from the language of the first population on the islands... their names", 'speaker': 'student'}, {'text': "Wow - yes I see, really distinctive (it seems to me) ...yes Canarian =correct but I guess most English people would probably say 'from the Canary Islands' due to lack of familiarity I'm afraid!", 'speaker': 'teacher'}], 'response': {'text': 'OK amazing - any basic info on this population?!', 'speaker': 'teacher'}}
# {'id': 'train_0037', 'utterances': [{'text': "and therefore e.g. 'get' 10 out of 10/get a B etc", 'speaker': 'teacher'}, {'text': 'thanks', 'speaker': 'student'}, {'text': 'get a high score etc etc', 'speaker': 'teacher'}, {'text': "OK <STUDENT> so if you don't mind I'll start asking you questions based on the pie charts OK?", 'speaker': 'teacher'}, {'text': 'yes!', 'speaker': 'student'}, {'text': 'OK great so....can you write s sentence describing ONLY the following: Australia 1980 coal', 'speaker': 'teacher'}], 'response': {'text': 'As in NOT about change over time or France or any other fuel JUST those items OK?', 'speaker': 'teacher'}}
# {'id': 'train_0038', 'utterances': [{'text': 'Hey <STUDENT>...', 'speaker': 'teacher'}, {'text': 'Hello!', 'speaker': 'student'}, {'text': 'HOw are you? Surviving?', 'speaker': 'teacher'}, {'text': 'Yes, here I am :) still alive...', 'speaker': 'student'}, {'text': "Can you feel that is Easter? do you say 'Easter' or 'Easter time'?", 'speaker': 'student'}, {'text': 'I think that question is wrong...', 'speaker': 'student'}, {'text': 'Here it feels like a normal week! no Easter atmosphere at all', 'speaker': 'student'}], 'response': {'text': 'Um...does it feel like Easter to you? is OK!', 'speaker': 'teacher'}}
# {'id': 'train_0039', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Hello!', 'speaker': 'student'}, {'text': 'How are you today?', 'speaker': 'teacher'}, {'text': 'Good', 'speaker': 'student'}, {'text': 'and you?', 'speaker': 'student'}, {'text': 'Good to hear!', 'speaker': 'teacher'}, {'text': "I'm fine, thank you :)", 'speaker': 'teacher'}, {'text': "It's been raining here since out last class! Can you imagine?", 'speaker': 'teacher'}, {'text': 'wow', 'speaker': 'student'}], 'response': {'text': 'But at least after the rain we should have a heatwave', 'speaker': 'teacher'}}
# {'id': 'train_0040', 'utterances': [{'text': "What does 'flying colours' mean?", 'speaker': 'student'}, {'text': 'Do you remember the lesson you did with the folowing adjectives? e.g. relieved/confused/optimistic/annoyed etc? Could you give me a setence (true if possible) to describe a time you expereinced any of these feelings I just mentioned in the list?', 'speaker': 'teacher'}], 'response': {'text': 'Oh sorry - in this context it means you passed to a high standard', 'speaker': 'teacher'}}
# {'id': 'train_0041', 'utterances': [{'text': 'Haha, oh my word, poor frog!', 'speaker': 'teacher'}, {'text': 'Did the frog survive?', 'speaker': 'teacher'}, {'text': 'Some how but yes!', 'speaker': 'student'}, {'text': 'Probably they played with their paws', 'speaker': 'student'}, {'text': "Haha, that's a good story!", 'speaker': 'teacher'}, {'text': "I've had a stressful week because we had to take one of our guinea pigs to the vet's and it had a surgery!", 'speaker': 'teacher'}, {'text': 'What does surgery mean?', 'speaker': 'student'}, {'text': 'a surgery = an operation', 'speaker': 'teacher'}, {'text': "a doctor that does performs operations is called 'a surgeon'", 'speaker': 'teacher'}, {'text': 'sorry,', 'speaker': 'teacher'}], 'response': {'text': "a doctor that performs operations', without 'does'", 'speaker': 'teacher'}}
# {'id': 'train_0042', 'utterances': [{'text': 'I was about to suggest that we could work on the different meanings of the words of that type of exercises (the one on page 12)', 'speaker': 'student'}, {'text': "ok fine....how about you give me an example sentence of 'wavers' is that OK?", 'speaker': 'teacher'}, {'text': 'Do you want me to give you all the answers or shall we work on them one by one?', 'speaker': 'student'}, {'text': "um...ok let's try one by one and see how we go ok?", 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}, {'text': '1c', 'speaker': 'student'}, {'text': 'great yes keep going!', 'speaker': 'teacher'}, {'text': '2d', 'speaker': 'student'}, {'text': 'yep!', 'speaker': 'teacher'}, {'text': '3a', 'speaker': 'student'}], 'response': {'text': 'good...', 'speaker': 'teacher'}}
# {'id': 'train_0043', 'utterances': [{'text': "yes infact in my latest essay I didn't put the conclusion", 'speaker': 'student'}, {'text': "<STUDENT> - ill give you an example answer for these charts ok and you'll see how to do it more easily", 'speaker': 'teacher'}, {'text': "we don't need one, isn't it?", 'speaker': 'student'}, {'text': 'ok thamks', 'speaker': 'student'}, {'text': 'thanks', 'speaker': 'student'}, {'text': 'Hold on - yes, you do need some kind of summary/overview/conclusion paragraph but just one ok?', 'speaker': 'teacher'}, {'text': 'ok i understood', 'speaker': 'student'}], 'response': {'text': 'Maybe at the beginning or end fir the graohs etc and just at the end fir the essay', 'speaker': 'teacher'}}
# {'id': 'train_0044', 'utterances': [{'text': "they do overlap in a way though it is true...ok sorry I'll stop and wait for you!", 'speaker': 'teacher'}, {'text': 'it is increasing argued that the most effective way to address the problem of discipline is responsibility. Although I strongly agree that responsibility plays a significant role, education system is more important.', 'speaker': 'student'}], 'response': {'text': 'OK thanks <STUDENT> ....so , in terms of language this is great......', 'speaker': 'teacher'}}
# {'id': 'train_0045', 'utterances': [{'text': 'yes, I am on holiday', 'speaker': 'student'}, {'text': 'everything is not shut', 'speaker': 'student'}, {'text': "That's a shame :(", 'speaker': 'teacher'}, {'text': "that you don't have a friend to go out with", 'speaker': 'teacher'}, {'text': 'What about your parents? Are they at work?', 'speaker': 'teacher'}, {'text': 'my dad is at work', 'speaker': 'student'}, {'text': "mom doesn't work", 'speaker': 'student'}, {'text': 'but she is doing all home things', 'speaker': 'student'}, {'text': "she's doing the housework?", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': ":( yes, doesn't sound like fun for you!", 'speaker': 'teacher'}, {'text': 'What do you do for fun? Watch some movies / read books / play games?', 'speaker': 'teacher'}, {'text': 'play games', 'speaker': 'student'}, {'text': 'read books', 'speaker': 'student'}], 'response': {'text': 'computer games?', 'speaker': 'teacher'}}
# {'id': 'train_0046', 'utterances': [{'text': 'yes !!', 'speaker': 'student'}, {'text': 'it have added to my vocabulary brain.', 'speaker': 'student'}, {'text': "especially 'property' actually", 'speaker': 'teacher'}, {'text': "OK great use of present perfect (i've added them)", 'speaker': 'teacher'}, {'text': 'it might means wealth I guess', 'speaker': 'student'}, {'text': 'Ah! property is just another word for e.g. buildings/houses/flats etc', 'speaker': 'teacher'}, {'text': 'and including houses and others', 'speaker': 'student'}, {'text': "Actually 'accommodation' would be good here too maybe right?", 'speaker': 'teacher'}, {'text': 'okey...thanks', 'speaker': 'student'}, {'text': 'AND your use of wealth is interesting', 'speaker': 'teacher'}], 'response': {'text': 'You could definitely include that somehow!', 'speaker': 'teacher'}}
# {'id': 'train_0047', 'utterances': [{'text': 'Hello!', 'speaker': 'teacher'}, {'text': 'hi', 'speaker': 'student'}, {'text': 'Another benefit of exploring space is that there are massive resources and elements. such as precious metals or helium and so on where we may find them on asteroids and planets.', 'speaker': 'student'}, {'text': "OK thanks <STUDENT> - some good stuff there...have you already done more that's coming?", 'speaker': 'teacher'}, {'text': 'no..', 'speaker': 'student'}], 'response': {'text': "No that's fine! That's great start...hold on a sec...", 'speaker': 'teacher'}}
# {'id': 'train_0048', 'utterances': [{'text': 'in writing too in IELTS', 'speaker': 'teacher'}, {'text': "because the points you're making may not always be true you see", 'speaker': 'teacher'}, {'text': "your use of the word 'balance' was good ...hold on....", 'speaker': 'teacher'}, {'text': "you can say: have a balance between two things OR balance (as verb) + two things (without the word 'between' )", 'speaker': 'teacher'}, {'text': "average' would be a good word to use for your point as well", 'speaker': 'teacher'}, {'text': 'Do you mean balance satification and salary,', 'speaker': 'student'}, {'text': 'Ah I see', 'speaker': 'student'}], 'response': {'text': "as in 'your salary is below average'", 'speaker': 'teacher'}}
# {'id': 'train_0049', 'utterances': [{'text': 'Is your school going to re-open in September, by the way? Or are you going to study online?', 'speaker': 'teacher'}, {'text': "we don't know:(", 'speaker': 'student'}, {'text': 'it is sad', 'speaker': 'student'}, {'text': 'Oh really? But there are only 4 weeks left!', 'speaker': 'teacher'}, {'text': "yes, that's the problem", 'speaker': 'student'}, {'text': 'It must be awful for you :(', 'speaker': 'teacher'}, {'text': "I don't know what to buy", 'speaker': 'student'}, {'text': 'school uniform or pajama', 'speaker': 'student'}], 'response': {'text': 'Ah, I see, yes', 'speaker': 'teacher'}}
# {'id': 'train_0050', 'utterances': [{'text': 'Could you insert some prepositions please?', 'speaker': 'teacher'}, {'text': 'On march on Skype on her phone', 'speaker': 'student'}, {'text': '43892.0', 'speaker': 'teacher'}, {'text': 'in March', 'speaker': 'teacher'}, {'text': 'Which month is your birthday?', 'speaker': 'teacher'}, {'text': 'March', 'speaker': 'student'}, {'text': 'Oh really?', 'speaker': 'teacher'}, {'text': 'March too? Which date?', 'speaker': 'teacher'}, {'text': '13th', 'speaker': 'student'}, {'text': 'Ah, mine is the 22th', 'speaker': 'teacher'}, {'text': "Ok, could you give me a full sentence, please. 'My birthday __ ___ March too'", 'speaker': 'teacher'}, {'text': 'Is in March', 'speaker': 'student'}, {'text': 'yes, cool', 'speaker': 'teacher'}, {'text': "What about 'My birthday is ___ the 13th of March", 'speaker': 'teacher'}, {'text': 'On', 'speaker': 'student'}], 'response': {'text': "Yes, correct. 'I usually eat cake __ my birthday'", 'speaker': 'teacher'}}
# {'id': 'train_0051', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Helli', 'speaker': 'student'}, {'text': '*o', 'speaker': 'student'}, {'text': 'How are you?', 'speaker': 'teacher'}, {'text': 'I am fine, and you?', 'speaker': 'student'}, {'text': 'Good, thank you.', 'speaker': 'teacher'}, {'text': "Sorry about the cancellation yesterday, I had to rush my guinea pig to the vet's", 'speaker': 'teacher'}, {'text': 'no worries , everything is okay', 'speaker': 'student'}], 'response': {'text': 'Thanks :)', 'speaker': 'teacher'}}
# {'id': 'train_0052', 'utterances': [{'text': "And 'policy' is also a noun by the way", 'speaker': 'teacher'}, {'text': 'yes..maybe it is the capital of one country.', 'speaker': 'student'}, {'text': "OK well...'political' is the adjective...so financial and political centre is grammatically correct anyway", 'speaker': 'teacher'}, {'text': "I don't know the word of noun.", 'speaker': 'student'}, {'text': 'One more: “One of the best ____ “(singular or plural noun next)?', 'speaker': 'teacher'}, {'text': 'plural', 'speaker': 'student'}, {'text': "Sorry you mean you didn't know the word policy was a noun?", 'speaker': 'teacher'}, {'text': 'ways', 'speaker': 'student'}], 'response': {'text': 'Yes good!', 'speaker': 'teacher'}}
# {'id': 'train_0053', 'utterances': [{'text': 'yes', 'speaker': 'student'}, {'text': ':)', 'speaker': 'teacher'}, {'text': 'Anyway, how are you?', 'speaker': 'teacher'}, {'text': 'I am fine', 'speaker': 'student'}, {'text': 'you asked me)', 'speaker': 'student'}, {'text': "I did, but I thought you'd tell me some more", 'speaker': 'teacher'}, {'text': 'Is it still hard to enjoy the rest of your holiday?', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'sorry to hear that!', 'speaker': 'teacher'}, {'text': 'only me and my ice cream (', 'speaker': 'student'}, {'text': ':((', 'speaker': 'teacher'}, {'text': "what's your favourite flavour?", 'speaker': 'teacher'}, {'text': 'I have a lot of favorites', 'speaker': 'student'}, {'text': 'but the most is oreo', 'speaker': 'student'}, {'text': 'of cookies and cream', 'speaker': 'student'}, {'text': '*or', 'speaker': 'student'}, {'text': 'Mmm, I see why!', 'speaker': 'teacher'}], 'response': {'text': 'My favourite is peanut butter and chocolate', 'speaker': 'teacher'}}
# {'id': 'train_0054', 'utterances': [{'text': 'most of them are wiling', 'speaker': 'student'}, {'text': "well 'willing' is an adjective so you need the verb 'be' ...ah yes that's right good", 'speaker': 'teacher'}, {'text': 'ok...thanks', 'speaker': 'student'}, {'text': 'OK no problem so ...your next answer...look at these chunks...good or bad? I think education / income differences / could be replaced / for example / cleaner on our street / robots', 'speaker': 'teacher'}, {'text': 'As a group i mean', 'speaker': 'teacher'}, {'text': 'I feel those are not good', 'speaker': 'student'}], 'response': {'text': 'Well ...actually they are fine!!', 'speaker': 'teacher'}}
# {'id': 'train_0055', 'utterances': [{'text': 'yes good question hold on let me think!', 'speaker': 'teacher'}, {'text': "Yes, I completely agree, I shouldn't complain, luckily Spanish is not so different to English", 'speaker': 'student'}, {'text': 'So ...my first thought is ..sometimes no difference...as in I keep waking up at night/in the night = both OK', 'speaker': 'teacher'}, {'text': "in the sense of 'during' both are possible", 'speaker': 'teacher'}], 'response': {'text': 'BUT what time do you go to sleep at night = the only possibility ( a specific time = at', 'speaker': 'teacher'}}
# {'id': 'train_0056', 'utterances': [{'text': "like 'video games on my computer'", 'speaker': 'teacher'}, {'text': 'Understand', 'speaker': 'student'}, {'text': "In English we say 'my' much more than in Russian / Ukrainian!", 'speaker': 'teacher'}, {'text': "For example, 'I put ___ hand in ___ pocket'", 'speaker': 'teacher'}, {'text': 'What goes in the gaps?', 'speaker': 'teacher'}, {'text': 'My hand in my pocket?', 'speaker': 'student'}, {'text': 'Yes!', 'speaker': 'teacher'}, {'text': "We wouldn't need 'my' in Russian or Ukrainian but we do in English!", 'speaker': 'teacher'}, {'text': 'Can you fix this one, please', 'speaker': 'teacher'}], 'response': {'text': "I'm with dog and cat and it's pretty warm near them", 'speaker': 'teacher'}}
# {'id': 'train_0057', 'utterances': [{'text': 'Yes', 'speaker': 'student'}, {'text': "so 'while' has two meanings right? One = at the same time and the other = ?", 'speaker': 'teacher'}, {'text': 'Ans I have a question', 'speaker': 'student'}, {'text': 'yes please go ahead', 'speaker': 'teacher'}, {'text': 'And other is ...  the same thing but different number', 'speaker': 'student'}, {'text': 'Different year', 'speaker': 'student'}, {'text': "OK sorry did you have a different question? The while' question = one meaning is at the same time the and the other meaning = 'but'", 'speaker': 'teacher'}, {'text': 'Ah', 'speaker': 'student'}, {'text': 'My question is', 'speaker': 'student'}, {'text': 'Ah ok*', 'speaker': 'student'}, {'text': 'My question is', 'speaker': 'student'}], 'response': {'text': 'yeeess?', 'speaker': 'teacher'}}
# {'id': 'train_0058', 'utterances': [{'text': 'so stupid is general - dumb = informal american and thick = informal British', 'speaker': 'teacher'}, {'text': 'so think is a less rude way of saying stupid?', 'speaker': 'student'}, {'text': 'not less rude actually! just another word....', 'speaker': 'teacher'}, {'text': "not very bright' = less direct!", 'speaker': 'teacher'}, {'text': 'you know bright means clever right?', 'speaker': 'teacher'}, {'text': 'I see', 'speaker': 'student'}, {'text': "smart' in the US and 'bright' in the UK", 'speaker': 'teacher'}, {'text': 'Yes, I like that word (bright)', 'speaker': 'student'}, {'text': 'yes really common  - sounds natural', 'speaker': 'teacher'}], 'response': {'text': "most non-native won't use it they always say clever/intelligent etc", 'speaker': 'teacher'}}
# {'id': 'train_0059', 'utterances': [{'text': 'Oh no! That sounds like another  depressing story about miserable, grey England...', 'speaker': 'teacher'}, {'text': 'and cold', 'speaker': 'teacher'}, {'text': 'It was tricky but having a bike since I moved there helped me a lot.', 'speaker': 'student'}, {'text': 'Yes bikes are great in some places here', 'speaker': 'teacher'}, {'text': 'hahah yes, depressing long grey winters...', 'speaker': 'student'}, {'text': 'aahh stop', 'speaker': 'teacher'}, {'text': 'hahah', 'speaker': 'student'}, {'text': 'Is it grey today??', 'speaker': 'student'}, {'text': "ACtually right now it's sunny!!!!", 'speaker': 'teacher'}], 'response': {'text': "Give it 30 years it'll be a paradies", 'speaker': 'teacher'}}
# {'id': 'train_0060', 'utterances': [{'text': 'Sorry for crazy typing!', 'speaker': 'teacher'}, {'text': 'Is it clear enough?!', 'speaker': 'teacher'}, {'text': 'U', 'speaker': 'student'}, {'text': 'Umm', 'speaker': 'student'}, {'text': 'It’s clear', 'speaker': 'student'}, {'text': 'Sure?!', 'speaker': 'teacher'}, {'text': 'Did you mean, we have to focus the biggest proportion source in France', 'speaker': 'student'}, {'text': 'In 2000', 'speaker': 'student'}, {'text': "There are various changes it's true BUT relatively speaking it's the biggest thing", 'speaker': 'teacher'}, {'text': 'Because in 1980, proportion is not much different', 'speaker': 'student'}, {'text': 'Right', 'speaker': 'student'}, {'text': 'Yes because of my last comment', 'speaker': 'teacher'}, {'text': 'Oh', 'speaker': 'student'}, {'text': 'Oh ok', 'speaker': 'student'}], 'response': {'text': 'If you imagine this info in a bar chart itmight be easier to see tbd relative diffetence and changes', 'speaker': 'teacher'}}
# {'id': 'train_0061', 'utterances': [{'text': 'Yes. I have cousins here', 'speaker': 'student'}, {'text': "Sounds nice. It's nice to have the full summer as a holiday. English kids only get 6 weeks!", 'speaker': 'teacher'}, {'text': 'Oh! Really?', 'speaker': 'student'}, {'text': 'Yes! From about July 20 to the beginning of September', 'speaker': 'teacher'}, {'text': "That's a pitty", 'speaker': 'student'}, {'text': "I know! I can't get used to it", 'speaker': 'teacher'}, {'text': "Oh, <ANOTHER STUDENT>'s been having classes too as you probably realized yesterday", 'speaker': 'teacher'}, {'text': 'Quick question. Which book did you use with <ANOTHER TEACHER>?', 'speaker': 'teacher'}, {'text': 'Live beat 4', 'speaker': 'student'}], 'response': {'text': 'Aha, thanks for this', 'speaker': 'teacher'}}
# {'id': 'train_0062', 'utterances': [{'text': 'I have never seen such a terrible sight = Never have i seen such a ...you see?', 'speaker': 'teacher'}, {'text': "I have a question about something you wrote yesterday. In the sentence 'Not only do I like chocolate I also like cake', do we need to write 'do'??", 'speaker': 'student'}, {'text': 'yes we do! Hold on....', 'speaker': 'teacher'}, {'text': 'I understand the example with never', 'speaker': 'student'}, {'text': "OK that's good/...", 'speaker': 'teacher'}], 'response': {'text': 'With the present simple v, and past simple verbs we need  auxiliary verb do/did', 'speaker': 'teacher'}}
# {'id': 'train_0063', 'utterances': [{'text': "Could you work in a School? I don't know how to say it...", 'speaker': 'student'}, {'text': 'Not in a Language school but in a Primary or Secondary school', 'speaker': 'student'}, {'text': 'do you mean mainstream education i.e. a primary or secondary school?', 'speaker': 'teacher'}, {'text': 'yes OK!', 'speaker': 'teacher'}, {'text': 'Exactly', 'speaker': 'student'}, {'text': "more informally you could just say 'normal' school", 'speaker': 'teacher'}, {'text': "with kids'", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'I guess you prefer working with adults', 'speaker': 'student'}, {'text': 'um....I think I prefer adults to be honest', 'speaker': 'teacher'}, {'text': 'yes!', 'speaker': 'teacher'}, {'text': 'hah', 'speaker': 'student'}], 'response': {'text': 'Nothing against kids per se but....a lot of its crowd control!', 'speaker': 'teacher'}}
# {'id': 'train_0064', 'utterances': [{'text': 'Very cool', 'speaker': 'teacher'}, {'text': "<STUDENT>, could you go back to this bit and insert some articles? 'Thank you for taking part in this study. Please go ahead and chat here, and remember that all conversations are recorded.", 'speaker': 'teacher'}, {'text': 'Oh no, what happened! Sorry', 'speaker': 'teacher'}, {'text': 'The programme went mad, please ignore it', 'speaker': 'teacher'}, {'text': 'are you there?', 'speaker': 'teacher'}, {'text': 'Yes', 'speaker': 'student'}, {'text': 'Good', 'speaker': 'teacher'}, {'text': "It's film from many photos. For example you put Lego man and take photo of him.", 'speaker': 'teacher'}], 'response': {'text': 'This bit. Could you insert some articles, please?', 'speaker': 'teacher'}}
# {'id': 'train_0065', 'utterances': [{'text': '0.02', 'speaker': 'student'}, {'text': 'Ah yes i see what you mean!', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'Be careful though...hold on...', 'speaker': 'teacher'}, {'text': 'sorry', 'speaker': 'student'}, {'text': 'No problem!', 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}, {'text': 'So...saying percentage of gas used is a bit strange...', 'speaker': 'teacher'}, {'text': 'how can I say?', 'speaker': 'student'}, {'text': "Because it's the percentage of electricity produced from gas - do you see?", 'speaker': 'teacher'}, {'text': 'A simimar problem as tbe other day', 'speaker': 'teacher'}, {'text': 'So...you can sat e.g. there was a drop inthr percentage of ....?', 'speaker': 'teacher'}, {'text': 'In the', 'speaker': 'teacher'}, {'text': 'the percentage of electricity produced from natural gas', 'speaker': 'student'}, {'text': '?', 'speaker': 'student'}, {'text': 'Yes good!', 'speaker': 'teacher'}], 'response': {'text': 'Much better', 'speaker': 'teacher'}}
# {'id': 'train_0066', 'utterances': [{'text': 'Haha, I love it!', 'speaker': 'teacher'}, {'text': 'not all the teachers make lessons and not all teachers give us homework', 'speaker': 'student'}, {'text': 'interesting', 'speaker': 'teacher'}, {'text': 'cons are:we can become dumber', 'speaker': 'student'}, {'text': "we don't see our friends", 'speaker': 'student'}, {'text': "we don't do any sports", 'speaker': 'student'}, {'text': "are you feeling it's not as intellectually challenging as face-to-face school?", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'Right, I see, all good points', 'speaker': 'teacher'}, {'text': 'and I looked really ill on the quarantine', 'speaker': 'student'}], 'response': {'text': 'Sounds like online learning is less stressful, but maybe not as challenging', 'speaker': 'teacher'}}
# {'id': 'train_0067', 'utterances': [{'text': 'magnifying ___', 'speaker': 'teacher'}, {'text': 'picture', 'speaker': 'student'}, {'text': 'glass!', 'speaker': 'teacher'}, {'text': 'oh', 'speaker': 'student'}, {'text': 'magnifying glass', 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': 'a dictionary definition: a piece of curved glass that makes objects look bigger than they are', 'speaker': 'teacher'}, {'text': "Ok, <STUDENT>, a little bit of homework for you. If you have a scroll through Olia Hercules' Instagram account and find a recipe you particularly like, could you tell me about it next time? What ingredients are used and how it's made?", 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': 'Lovely!', 'speaker': 'teacher'}, {'text': 'Thursday 10 am?', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'goodbye!', 'speaker': 'student'}], 'response': {'text': 'Lovely, have a good day!', 'speaker': 'teacher'}}
# ...
# {'id': 'train_2726', 'utterances': [{'text': "Don't worry if not! Just tell me...", 'speaker': 'teacher'}, {'text': 'High or low?', 'speaker': 'teacher'}, {'text': 'impossible', 'speaker': 'student'}, {'text': 'low', 'speaker': 'student'}, {'text': 'OK thanks!', 'speaker': 'teacher'}, {'text': "So another way of saying this could be: 'It is very _______ that you will get a double six.'?", 'speaker': 'teacher'}, {'text': "unl_ _ _ _ _ _ '??", 'speaker': 'teacher'}, {'text': 'unl....', 'speaker': 'student'}, {'text': 'unlikely!', 'speaker': 'teacher'}], 'response': {'text': "So if children play violent video games they are _______ to copy the behaviour they see.'", 'speaker': 'teacher'}}
# {'id': 'train_2727', 'utterances': [{'text': 'Are you hungry and thinking about ramen? :)', 'speaker': 'teacher'}, {'text': 'not really', 'speaker': 'student'}, {'text': 'just the first food that came on my mind', 'speaker': 'student'}, {'text': 'I see :) The first food that came ___ my mind', 'speaker': 'teacher'}, {'text': 'in', 'speaker': 'student'}, {'text': 'to!', 'speaker': 'teacher'}, {'text': "it's a good expression though", 'speaker': 'teacher'}, {'text': 'Are you still in Kovel? Is it still sunny and summery?', 'speaker': 'teacher'}, {'text': 'it is sunny, but a bit coldy', 'speaker': 'student'}, {'text': "Oh that's a shame", 'speaker': 'teacher'}, {'text': 'Ok <STUDENT>, quick memory test. Could you give me an adjective with the opposite meaning?', 'speaker': 'teacher'}, {'text': 'possible - ?', 'speaker': 'teacher'}, {'text': 'impossible', 'speaker': 'student'}, {'text': 'yes!', 'speaker': 'teacher'}, {'text': 'logical', 'speaker': 'teacher'}, {'text': 'illogical', 'speaker': 'student'}], 'response': {'text': 'legal', 'speaker': 'teacher'}}
# {'id': 'train_2728', 'utterances': [{'text': '__ the park', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': 'at!', 'speaker': 'teacher'}, {'text': 'at the park/ at the theatre, at the cinema', 'speaker': 'teacher'}, {'text': 'Ok, ready for me to mix them up?', 'speaker': 'teacher'}, {'text': '___ Sunday afternoon', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': 'Nope!  __ SunDAY afternoon', 'speaker': 'teacher'}, {'text': 'On', 'speaker': 'student'}, {'text': 'Yes. in the afternoon, but on Sunday afternoon', 'speaker': 'teacher'}, {'text': '__ the past', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': 'yes!', 'speaker': 'teacher'}, {'text': '__ July', 'speaker': 'teacher'}, {'text': 'On', 'speaker': 'student'}, {'text': 'Nooo!', 'speaker': 'teacher'}, {'text': 'In with months', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': 'like in Ukrainian and Russian', 'speaker': 'teacher'}, {'text': '___ 2019', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': 'yes', 'speaker': 'teacher'}, {'text': '__ the autumn', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': '___ July 31st', 'speaker': 'teacher'}, {'text': 'In', 'speaker': 'student'}, {'text': "no, it's a particular day", 'speaker': 'teacher'}, {'text': 'On', 'speaker': 'student'}], 'response': {'text': 'yes!', 'speaker': 'teacher'}}
# {'id': 'train_2729', 'utterances': [{'text': 'Especially for speaking PArt 2', 'speaker': 'teacher'}, {'text': 'because in Chinese we do not have tenses, so I always forget them when I am writing and speaking.', 'speaker': 'student'}, {'text': "So look at these points for Part 2 speaking: Describe a journey that didn't go as planned. You should say: (hold on!)", 'speaker': 'teacher'}, {'text': 'yes , I am lack of part 2', 'speaker': 'student'}], 'response': {'text': '1. Where you were going 2. How you were travelling 3.Who you were with 4.What went wrong 5. Explain what you would do differently', 'speaker': 'teacher'}}
# {'id': 'train_2730', 'utterances': [{'text': "Good to hear. What's the weather like?", 'speaker': 'teacher'}, {'text': 'Sorry, something went wrong witht the program for a second', 'speaker': 'teacher'}, {'text': "It's sunny and very hot", 'speaker': 'student'}, {'text': 'Guess what!', 'speaker': 'student'}, {'text': "Ooh, good! It's going to be hot here on Friday. In the UK, spells of hot weather are called heatwaves. They don't usually last!", 'speaker': 'teacher'}, {'text': 'What?', 'speaker': 'teacher'}, {'text': "I'll have new friend", 'speaker': 'student'}, {'text': 'Oh yes? Did you meet someone?', 'speaker': 'teacher'}, {'text': "No, it's lizard!", 'speaker': 'student'}, {'text': 'What? Really?? What kind of lizard?', 'speaker': 'teacher'}, {'text': "It's __ lizard", 'speaker': 'teacher'}, {'text': 'A', 'speaker': 'student'}], 'response': {'text': 'aha', 'speaker': 'teacher'}}
# {'id': 'train_2731', 'utterances': [{'text': "Hi there - good to speak to you again. <STUDENT>, I thought I'd make this lesson a bit more focused so here goes! Can i ask you to write a sentnece using the following information: Pacific/biggest", 'speaker': 'teacher'}, {'text': 'The Pacific Ocean is the biggest ocean in the world.', 'speaker': 'student'}, {'text': 'Thank you - another one: Nile/longest', 'speaker': 'teacher'}, {'text': 'The Nile is the longest river in the world.', 'speaker': 'student'}, {'text': 'OK nearly there! Everest/Himalayas', 'speaker': 'teacher'}, {'text': 'Mt. Everest is the highest in the Himalayas.', 'speaker': 'student'}], 'response': {'text': 'Thanks - USA/50 states', 'speaker': 'teacher'}}
# {'id': 'train_2732', 'utterances': [{'text': 'I see', 'speaker': 'student'}, {'text': 'e for the barrel??', 'speaker': 'student'}, {'text': "sorry you know 'barrel' like round made of wood right?", 'speaker': 'teacher'}, {'text': 'yes e!', 'speaker': 'teacher'}, {'text': "Can you use 'at sea' in a sentence, please?", 'speaker': 'student'}, {'text': "Yes of course - so it's like you don't know what to do or you can't cope - like: I was all at sea in my new job on the first day", 'speaker': 'teacher'}], 'response': {'text': 'it reminds me of e.g. to be out of your depth (another watery phrase!) - you know that one?', 'speaker': 'teacher'}}
# {'id': 'train_2733', 'utterances': [{'text': 'ok', 'speaker': 'student'}, {'text': 'So good = search FOR alien life/ develop space technology/ For instance/ However, 窶ｦ', 'speaker': 'teacher'}, {'text': 'Question: Is expenditure a noun?', 'speaker': 'teacher'}, {'text': 'yes... so  expenditure of public money on search for alien life.', 'speaker': 'student'}, {'text': 'OR  government expenditure of search for alien life.', 'speaker': 'student'}, {'text': 'expenditure of public money of search for alien life.', 'speaker': 'student'}, {'text': "Sorry..internet...! OK hold on..I think the government should + NOUN right? So you can't have 'expenditure' next here ...", 'speaker': 'teacher'}], 'response': {'text': 'Can you solve this problem here?', 'speaker': 'teacher'}}
# {'id': 'train_2734', 'utterances': [{'text': "To be honest I don't know what to say about judges... what do you think??", 'speaker': 'student'}, {'text': 'sh-corpora.org/bnc/     sorry that was a link to a website  - a language corpus site where you can search with keywords - it;s cool - have a look now if you want quickly? Give me a minute to think about judges ok?', 'speaker': 'teacher'}, {'text': "sorry here's the full link......sh-corpora.org/bnc/", 'speaker': 'teacher'}, {'text': 'AAhhhhh! hold on', 'speaker': 'teacher'}], 'response': {'text': 'sh-corpora.org/bnc/', 'speaker': 'teacher'}}
# {'id': 'train_2735', 'utterances': [{'text': 'Hi <STUDENT>, happy new year! How are you?', 'speaker': 'teacher'}, {'text': 'Happy new year! Good, thank you.', 'speaker': 'student'}], 'response': {'text': 'Great - how was your Christmas - did you stay in Cambridge?', 'speaker': 'teacher'}}
# {'id': 'train_2736', 'utterances': [{'text': 'Great news about your leg!!!', 'speaker': 'student'}, {'text': "I was pessimistic about my leg because i've had sports injuries before that didn't get better without surgery but seems like i've been lucky this time", 'speaker': 'teacher'}, {'text': "yes, I mean 'we will be able to walk around our houses' Is it correct the use of 'place' in that case??", 'speaker': 'student'}], 'response': {'text': 'But I might take it down a bit/play it safe ... a bit more swimming/cycling (nice and safe!)', 'speaker': 'teacher'}}
# {'id': 'train_2737', 'utterances': [{'text': 'because at least she will be expose to nice things and maybe she is not liking them just because she is a teenager', 'speaker': 'student'}, {'text': "Ohh it's time! I will really miss our classes/conversations", 'speaker': 'student'}], 'response': {'text': "OK right - I think it was when you wrote 'even when' I got confused...Yes OK <STUDENT> , well it was good to work with you on this site and I wish you all the best", 'speaker': 'teacher'}}
# {'id': 'train_2738', 'utterances': [{'text': "Yeah, I'm using my phone, it's better than the last time, isn't it??", 'speaker': 'student'}, {'text': "I'd say you're definitely faster yeah - this is me at maximum speed I'm afraid!", 'speaker': 'teacher'}, {'text': "It's good for me. haha", 'speaker': 'student'}, {'text': ":) Listen <STUDENT> I thought I'd try something a bit more specific if that's OK - so here goes...", 'speaker': 'teacher'}, {'text': 'What’s the connection?  Tokyo/Japan', 'speaker': 'teacher'}, {'text': 'Do you mean my hometown?', 'speaker': 'student'}], 'response': {'text': "No I mean: what's the connection between those two words?", 'speaker': 'teacher'}}
# {'id': 'train_2739', 'utterances': [{'text': 'do this one', 'speaker': 'teacher'}, {'text': "Sorry I should have kept a record (actually I did but I can't find it)", 'speaker': 'teacher'}, {'text': 'not sure... my memory is really bad :(. I know we did the other one because I wrote the answers with pencil on the book and I never do it unless I do it with you', 'speaker': 'student'}, {'text': 'OK - how about a part 4? page 150 for example?', 'speaker': 'teacher'}, {'text': 'ok, 150', 'speaker': 'student'}], 'response': {'text': "ok I'll give you  a littel bit longer for each one as they're slightly more complicated perhaps", 'speaker': 'teacher'}}
# {'id': 'train_2740', 'utterances': [{'text': 'with', 'speaker': 'student'}, {'text': 'good!', 'speaker': 'teacher'}, {'text': '<STUDENT> is good __ math.', 'speaker': 'teacher'}, {'text': 'in', 'speaker': 'student'}, {'text': 'at!', 'speaker': 'teacher'}, {'text': "Good at, bad at, brilliant at, terrible at - it's always 'at'", 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': "For example, I was quite good at math at school but now I'm terrible at it!", 'speaker': 'teacher'}, {'text': '(true story)', 'speaker': 'teacher'}, {'text': "I'm quite good at languages. I'm also good at understanding children and I'm studying developmental psychology. But I'm pretty bad at math and physics", 'speaker': 'teacher'}], 'response': {'text': 'What about you?', 'speaker': 'teacher'}}
# {'id': 'train_2741', 'utterances': [{'text': 'Wait a minute', 'speaker': 'student'}, {'text': 'Does 9.30 am on Tuesday sound good to you?', 'speaker': 'teacher'}, {'text': 'Let’s talk about it in the Skype, okay?', 'speaker': 'student'}, {'text': 'Ok', 'speaker': 'teacher'}, {'text': 'Squeak', 'speaker': 'student'}, {'text': 'Aha, yes', 'speaker': 'teacher'}, {'text': "The food that's left from yesterday?", 'speaker': 'teacher'}, {'text': 'But I know what does it mean now', 'speaker': 'student'}, {'text': 'Leftover', 'speaker': 'student'}, {'text': 'leftover food (leftover is an adjective here) or leftovers (plural noun)', 'speaker': 'teacher'}, {'text': 'Am I right?', 'speaker': 'student'}, {'text': 'Yes!', 'speaker': 'teacher'}, {'text': 'So 3 words', 'speaker': 'student'}], 'response': {'text': 'For example, I sometimes have leftovers for lunch', 'speaker': 'teacher'}}
# {'id': 'train_2742', 'utterances': [{'text': 'Your turn in a minute!', 'speaker': 'teacher'}, {'text': "Do you know the word for 'travel to work regularly'?", 'speaker': 'teacher'}, {'text': 'Travel to work? I have no idea', 'speaker': 'student'}, {'text': 'Commute', 'speaker': 'teacher'}, {'text': 'He commutes to work (or at least he did before the quarantine)', 'speaker': 'teacher'}, {'text': 'Ok', 'speaker': 'student'}, {'text': 'Do you commute to school in Kyiv or are do you walk?', 'speaker': 'teacher'}, {'text': 'I commute to school', 'speaker': 'student'}, {'text': "sorry, 'or do you walk?', without 'are'", 'speaker': 'teacher'}, {'text': 'Ok, do you commute by underground?', 'speaker': 'teacher'}, {'text': "No, I don't", 'speaker': 'student'}], 'response': {'text': 'by car?', 'speaker': 'teacher'}}
# {'id': 'train_2743', 'utterances': [{'text': 'Yes, it feels like that', 'speaker': 'student'}, {'text': "I'm alright, it seems we are going to start going out soon... So happy about it", 'speaker': 'student'}, {'text': 'how about you?', 'speaker': 'student'}, {'text': 'Yes I can imagine - I wonder what it will be like?', 'speaker': 'teacher'}, {'text': 'I mean will things feel different for a while?', 'speaker': 'teacher'}], 'response': {'text': "Yes I'm fine thanks - to be perfectly honest I'm quite a self-contained person (well that's one word for it!) so the whole lockdown thing has not really affected me that much", 'speaker': 'teacher'}}
# {'id': 'train_2744', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Hello!', 'speaker': 'student'}, {'text': 'How are you today?', 'speaker': 'teacher'}, {'text': 'Good', 'speaker': 'student'}, {'text': 'and you?', 'speaker': 'student'}, {'text': 'Good to hear!', 'speaker': 'teacher'}, {'text': "I'm fine, thank you :)", 'speaker': 'teacher'}, {'text': "It's been raining here since out last class! Can you imagine?", 'speaker': 'teacher'}, {'text': 'wow', 'speaker': 'student'}, {'text': 'But at least after the rain we should have a heatwave', 'speaker': 'teacher'}, {'text': "How's Vinnytsa?", 'speaker': 'teacher'}, {'text': 'just cloudy', 'speaker': 'student'}], 'response': {'text': 'Do you prefer it like this or do you like sunshine?', 'speaker': 'teacher'}}
# {'id': 'train_2745', 'utterances': [{'text': 'sorry, do you do or teach?', 'speaker': 'student'}, {'text': 'yes I do/teach exam classes', 'speaker': 'teacher'}, {'text': 'both are fine', 'speaker': 'teacher'}, {'text': 'okk', 'speaker': 'student'}, {'text': 'lots of IELTS recently but the other Cambridge exams too', 'speaker': 'teacher'}, {'text': 'did you do First CErtificate?', 'speaker': 'teacher'}, {'text': "So you know what I am suppose to know. I mean maybe we could practise vocabulary that is used in CAE... I don't know, just an idea", 'speaker': 'student'}, {'text': "No, I've never taken an English exam", 'speaker': 'student'}], 'response': {'text': "yes of course - that's fine and yes a good idea for you - do you have books?", 'speaker': 'teacher'}}
# {'id': 'train_2746', 'utterances': [{'text': 'Hi there...', 'speaker': 'teacher'}, {'text': 'hi', 'speaker': 'student'}], 'response': {'text': "OK <STUDENT> ... so if you're ready, have a think about what you can tell about yourself using any of these adjectives:", 'speaker': 'teacher'}}
# {'id': 'train_2747', 'utterances': [{'text': "I'll use it from now on", 'speaker': 'student'}, {'text': 'ok!', 'speaker': 'teacher'}, {'text': "So by the way 'wage' is more generally associated with 'blue collar' jobs (a bit outdated this phrase but still useful here) and 'salary' more for 'white-colalr jobs'", 'speaker': 'teacher'}, {'text': "sorry 'collar'", 'speaker': 'teacher'}, {'text': 'No idea about blue or white collar', 'speaker': 'student'}, {'text': "salary' agreed in advance and often monthly blah blah - wages maybe hourly for example another possible difference", 'speaker': 'teacher'}], 'response': {'text': 'oh sorry ...which colour is e.g. unskilled manual work do you think?', 'speaker': 'teacher'}}

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
 nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import jsonlines
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# Step 1: Read and preprocess the training data
train_data = []
with jsonlines.open('train_with-reference.jsonl') as reader:
    for obj in reader:
        # Preprocess obj here as needed
        utt_texts = [word_tokenize(utt['text']) for utt in obj['utterances']]
        utt_texts = [[lemmatizer.lemmatize(w.lower()) for w in utt] for utt in utt_texts]
        teacher_resp_text = word_tokenize(obj['response']['text'])
        teacher_resp_text = [lemmatizer.lemmatize(w.lower()) for w in teacher_resp_text]
        train_data.append((utt_texts, teacher_resp_text))

# Print the preprocessed data
for example in train_data:
    input_utterances, teacher_resp = example
    print('Input Utterances:')
    for utt in input_utterances:
        print(' '.join(utt))
    print('Teacher Response:', ' '.join(teacher_resp))
    print('-----------------------')
# Out:
# Streaming output truncated to the last 5000 lines.
# i do n't know whether you have ever watched star war .
# have you ever watched star war ?
# yes , well done !
# i wonder if your lizard sleep a lot .
# doe your lizard sleep a lot
# almost ! can you spot a mistake ?
# sleep
# correct !
# ok , now could you change the question into reported speech , please
# õķ
# doe it snow a lot in ukraine ? i do n't know ...
# if it snow a lot in ukraine
# Teacher Response: yes , well done !
# -----------------------
# Input Utterances:
# woww
# sorry is that too much ! ?
# no , it 's great !
# you were right about set up a company by the way !
# Teacher Response: ok ... do them in any order if you like
# -----------------------
# Input Utterances:
# and i guess on other planet too right ?
# and an example of the resource you might find ?
# yes , maybe on moon or mar
# lunar
# yes good idea ! so on the moon or on mar ( planet in our solar system )
# and what kind of resource ?
# we may can find diamond or other crystal
# or ... oxygen and water
# Teacher Response: ok fine yes so ... maybe a good word might be precious metal ok ?
# -----------------------
# Input Utterances:
# ahh thanks , i 've heard it before ...
# ok ! well , it 's general election day today in the uk ...
# uhhh are you excited about it ? ? or worried ?
# have you already voted ?
# Teacher Response: um ... i would n't say excited exactly ... it 's hard to say to be honest . the odds are that the conservative will win which mean ( probably ! ) that brexit will go ahead in a stronger form ..
# -----------------------
# Input Utterances:
# hi < student > !
# hello
# sorry to hear you want to sleep !
# : )
# how 's life ? are you still in vinnytsa ?
# everything is okay
# i am in kovel now
# nice ! visiting family again ?
# no , just visiting friend
# sound good . i 've never been to kovel - is it nice ?
# yes , but is little
# Teacher Response: ok
# -----------------------
# Input Utterances:
# you also make some batter to make pancake !
# oohh
# is there starbucks in kyiv ?
# no
# but i bet you 've seen it in israel ?
# no , there is not starbucks in israel and ukraine : (
# ah well , i 'm sure you will one day !
# what is fast food like in israel ?
# Teacher Response: i know about kyiv ! mcdonalds and domashnya kukhnya !
# -----------------------
# Input Utterances:
# i understan !
# understand
# ok - < student > sorry for the stupid question but ... are there motorway in the canary island ?
# haha it is not a stupid question . yes there are motorway . what a coincidence , yesterday i had a conversation about it . we talked about how long we have had them
# Teacher Response: right ... so how long would it take to drive around tenerife ?
# -----------------------
# Input Utterances:
# what are you going to do at the weekend ?
# ok thanks ... or 5 word and that 's good !
# the other way is : 'what are you doing at the weekend '
# okey~
# Teacher Response: so when we talk about plan we can use the present continuous or 'going to ' but not will - this is the same in the question and answer ( about plan )
# -----------------------
# Input Utterances:
# ok so the first word for number 1 is 'australia ' a you can see i hope !
# yes , i saw it
# i ; ve emailed you the pie chart a a pdf too by the way if you need it
# yes , it is really clearly .
# Teacher Response: ok cool - i 'll give you a minute for the first one ....
# -----------------------
# Input Utterances:
# oh ok
# probably it 's beard agama
# oh , a bearded lizard ! cool !
# aha
# have you always wanted a reptile a a pet ?
# it 's my cousin 's pet not mine : (
# oh i see : (
# but you made friend with it ?
# but i 'll have it for 1 week
# ah , you 'll be looking after it ?
# i 've saw it already
# i 've ___ it already
# yes sure
# seen
# Teacher Response: correct !
# -----------------------
# Input Utterances:
# hello
# < teacher > ?
# are you here ?
# hello ? ? ?
# hi ? ? ?
# hi < student > !
# hello
# sorry , i got distracted for a second
# how are you ?
# fine
# and you ?
# great , thank you !
# did you have a good weekend ?
# yes
# Teacher Response: so , are you allowed to leave your house and go to shop / cinema etc ?
# -----------------------
# Input Utterances:
# sorry for my typing ! 'especially ' and 'were ' is what i wanted to write !
# okey ... it is ture for me to understand but i will do my best to study them .
# sorry .. it is ___ for me to understand ?
# it is truth for me to understand them , but i will do my best .
# truth ' ? !
# fact
# fact？
# oh .. it is my mistake ..
# Teacher Response: um .. sorry not sure to be honest !
# -----------------------
# Input Utterances:
# clear and direct with the main idea at the beginning ... good !
# yes , ,i always review them when you were teaching me .
# ok so now you can add some more right ? an explanation ( i.e . what doe it mean to be addicted ) ... an example ... or whatever ... ( we 'll come back to the exact language you 've used a bit later ok ? )
# Teacher Response: so .. next sentence .. go for it !
# -----------------------
# Input Utterances:
# maybe not always : )
# why not ? : )
# hmm
# maybe we do n't really like something
# but for real we are good at it
# ok , i can imagine that . i think we 're good at thing that we practice . but then , we tend to practice the thing that we like most
# yeah
# ok , let 's keep going
# our trip to the park depends __ the weather
# on
# Teacher Response: yes , good !
# -----------------------
# Input Utterances:
# ?
# yeah absolutely ... or e.g . i went to the swimming pool - there were load of peopel because it 's the school holiday ... ok < student > one more ! - 'rarely ' = formal or normal ?
# people
# of course e.g . 'crowded ' is common too
# i think it 's normal .
# ok ... it 's certainly perfectly possible and correct ... can you think of a different word ? !
# seldom ?
# Teacher Response: good idea ! so in order of formality : seldom , rarely and hardly ever
# -----------------------
# Input Utterances:
# here you could n't go to your allotment either !
# that 's definitely over the top ! i think that would never happen in the uk !
# i 've decided that allotment are quintessentially british - i.e . kind of shared/communnal but not really the perfect liberal compromise
# i mean controlled social space you know ?
# sorry , i do n't understand what you mean ...
# quintessentially ? ?
# oh right .... like the perfect example of seomthing
# a in allotment are a perfect example of britishness
# Teacher Response: or embody typical british value or whatever
# -----------------------
# Input Utterances:
# the unemployment is high in the whole country ( not sure )
# all spain ' is not wrong just a bit unusual - all of spain or various alternative obviously : all over spain/through ( more formal ) spain/ yes whole country = fine definitely not the unemploymen though !
# sorry i meant throughout spain
# ok , thanks
# next one =word order do you see it ?
# it always ha been very difficult to find a job
# it ha always been
# sorry
# Teacher Response: that 's ok that 's it yes !
# -----------------------
# Input Utterances:
# might
# could
# may
# yes , any of these !
# she always get such good grade at school . she _____ work very hard .
# must
# yes !
# the doctor said my headache _____ be because of the hot weather but they 're going to do some test to be sure .
# might
# he _____ be our teacher ! he look about twelve !
# Teacher Response: yes to the previous one !
# -----------------------
# Input Utterances:
# it 's not really formal , we use it a lot ...
# oh right - it 's a bit formal in english
# educated ' or whatever
# and do you have an informal word for that ?
# some people might never say it i guess ...
# maybe 'guess ' ?
# um .. well i guess like lot of these thing it would be replaced by a phrasal verb often - so e.g . work out
# or guess of vourse yes
# Teacher Response: but 'work out ' is maybe best here
# -----------------------
# Input Utterances:
# i see yes - because that wa something that happened a from 2 week or so ago here - everyone started stockpiling/panic buying and the shelf were base ( of a lot of stuff like tinned stuff/packets of dried food like pasta , pulse etc ) whcih wa alarming -
# no 'supply issue ' wa good !
# shelf were 'bare ' i meant
# i like 'panic buying ' , it describes very well what is actually happening
# Teacher Response: yes a neat anglo-saxon construction !
# -----------------------
# Input Utterances:
# although 'psycho ' = noun for a person of course
# so no , i 'm not a psycho - just going a bit potty !
# haha ok , good to know
# ok .... how about .... not being able to do exercise is 'doing my head in ' ?
# familiar ?
# no
# ah ok ... this one really is common ( informal but common )
# making me crazy ' ? ?
# Teacher Response: yes exactly ( driving me crazy = more common by the way )
# -----------------------
# Input Utterances:
# let me think ...
# influential ? ?
# adjective ending ..... -ive/-ous -- ial ... choose one of these !
# yes you 've got it - well done
# great clue ! thank you
# and you did n't say influencial which is a common spanish mistake
# 18 inspiration
# yes good
# 19 generosity
# great
# 20 restless ? ?
# yes right idea for the meaning = good but you need a noun i.e . the thing that led him ...
# add a noun ending to your adjective
# ness ?
# Teacher Response: yes that 's right !
# -----------------------
# Input Utterances:
# it sound very good
# i do n't think we 've talked about it before ...
# could you mention the one you know ?
# but it 's great because for example you get one youtube video and hundred of comment and they all naturally use a whole range of language to describe the same thing you know ? it 's like a mini-corpus !
# Teacher Response: yes nothing special - i just mean on e.g . youtube video or newspaper website ( where they have comment section after opinion piece for example )
# -----------------------
# Input Utterances:
# it 's like e.g . por and para for me in spanish you know
# yes , i know what is a lock but i do n't know what they are for ... here there are not river so i 'm quite ignorant about the topic
# yes , por and para are very hard to get and even hard for me to explain when i teach spanish ...
# Teacher Response: sorry for delay ... anyway so i like my boat - mainly because it 's really cheap compared to a house you know !
# -----------------------
# Input Utterances:
# while they were away abroad
# ohh great , that wa lucky ! !
# yes - we had an island in the kitchen - do you know what i mean ?
# yes , i love the idea !
# and thousand of kitchen utensil - this is the kind of thing you get excited about after 12 year on a boat ! superficial i know
# i 've only seen the on tv
# Teacher Response: hairdryers ....
# -----------------------
# Input Utterances:
# and ... motivated/scared
# proud - pleasure / happy - happiness / excited - excitation / annoyed - / disappointed - dissipation
# motivated - motivation / scared -
# yes ...
# ok thanks < student > .. sorry internet probs ... hold on a sec
# ok .. no problem
# so pride/happiness/excitement/annoyance ( anger common too ) /disappointment/motivation/fear ( the normal noun for all 3 adjective scared/frightended/afraid )
# Teacher Response: you got some of them !
# -----------------------
# Input Utterances:
# so i drive/get the train/run ( ! ) or whatever
# i kind of understand the different us of in and on but it is very confusing for me considering than in spanish there is only one word for both of them ...
# also there 's a lock between where i live and cambridge - do you know what i mean ? - yes i undersrtand about on and in - sorry !
# Teacher Response: it 's like e.g . por and para for me in spanish you know
# -----------------------
# Input Utterances:
# right that sound lovely i spent a few year living in spain and i do miss it sometimes !
# oh really ! wa it for your work ?
# well yes basically - i just taught in different school
# then you must miss sunshine during winter .
# yeah i do miss the sun ! < student > : 'few people ' = formal or normal ?
# i thought it 's normal ... but formal ?
# Teacher Response: a bit yes .... can you tell me the thing you said about mallorca in a different way ?
# -----------------------
# Input Utterances:
# were you born on march ?
# oh , i see . squeak is a sound that a mouse might make , or a squeaky door
# i wa , correct !
# thanks for explanation
# that wa easy : ) but also , the town where i live is called march
# wow
# okay
# i know , i wa very pleased when we found a house here because it 's my birth month
# have you ever been to shanghai ?
# yes , that wa easy too !
# Teacher Response: i lived there for a bit
# -----------------------
# Input Utterances:
# we get increasingly short term student which is fine but it 's more tiring/stressful
# could you work in a school ? i do n't know how to say it ...
# not in a language school but in a primary or secondary school
# do you mean mainstream education i.e . a primary or secondary school ?
# yes ok !
# exactly
# more informally you could just say 'normal ' school
# Teacher Response: with kid '
# -----------------------
# Input Utterances:
# ok thanks well done hold on ...
# is it enough ?
# ok so ... yes some good stuff here ... some good grammar and you 've got the major point about nuclear being significant in france you need to do the same for australia
# Teacher Response: i.e . not just there wa a significant increase but that it wa by far thr most significant fuel do you see ?
# -----------------------
# Input Utterances:
# yes i understand !
# do you know why i 'm confused ?
# i guess it 's like you look beyond you see ? a in ignoring what 's right in front of you ( e.g . down on the ground )
# so if you look over someone 's head you 're not looking at their head
# but above their head
# i see what you mean
# so 2b
# yes !
# Teacher Response: worth remembering by the way i.e . not very obscure ... quite normal
# -----------------------
# Input Utterances:
# do you want me to give you all the answer or shall we work on them one by one ?
# um ... ok let 's try one by one and see how we go ok ?
# ok
# 1c
# great yes keep going !
# 2d
# yep !
# 3a
# good ...
# 4c
# yes
# 5d
# good
# haha i generally make mistake ! ! !
# ha ! well maybe i bring you luck .. !
# 6b ? ?
# Teacher Response: yes i could see this might be trickier ... but yes well done !
# -----------------------
# Input Utterances:
# or 'part ' is very common too
# okk i see the correction , thank you !
# ok !
# you know one really odd thing that 's survived the uk ? religious assembly in school !
# bizzare given the vast majority of parent never go to church or whatever - just a hangover from the past
# you know that use of hangover right ?
# sure , we had them in the school i worked
# no i did n't ! i like it ( hangover use )
# Teacher Response: yes i guessed it might be new !
# -----------------------
# Input Utterances:
# amy
# nice , i like it
# unconsciously influenced by the existence of amy winehouse i realise in retrospect - not the best model perhaps
# it 's so short , in spain name are much longer i think
# yes i see - it 's true that we like short name
# hahah maybe not the best model but a great singer
# Teacher Response: yes a great singer - you know it ; s weird right that the influence on name are mostly unconscious - people do n't intentionally name kid after a famous person often
# -----------------------
# Input Utterances:
# okk
# the verb is ok - i meant the tense
# when i went to my first class i suffer so much that i completely changed my idea about it
# i suffered a lot when i went to the first class
# sorry
# simple past
# right ?
# no that 's ok ! but would it be ok to say all of this in the present in spanish ?
# Teacher Response: yes you 're right ! past simple is correct
# -----------------------
# Input Utterances:
# have and there are
# ok great thanks
# have is ok .. contain would be good too right ?
# thanks
# ok sothe resource are there .... and we have to _______ them ? ?
# yes ! ! i really like this structure .
# Teacher Response: ok !
# -----------------------
# Input Utterances:
# yes , that is what i wanted to say
# nooo
# ?
# sorry , i meant that i hope the uk stay in the eu
# oh yes of course - i 've just realised that you probably mean that .... hold on a sec
# both outcome have definitely been possible over the last few year slightly incredibly but now it doe look like we 'll almost certainly leave in some fashio ...
# Teacher Response: it 's just a question of how and when probably
# -----------------------
# Input Utterances:
# do n't you use intelligent ?
# oh sorry yes we do use those word too ....
# just not always - a in we also say bright '
# when i worked in the school there i remember teacher using much more the word 'bright '
# or e.g . 'switched on ' etc etc etc
# yes i think you 're right - in normal everyday speaking bright is raelly common - maybe 'intelligent ' sound more formal
# more than 'intelligent ' , i mean
# Teacher Response: well yes it is definitely
# -----------------------
# Input Utterances:
# ?
# yes , , because i addicted to them
# ok thanks - can you put a verb in this sentence ?
# addicted ' = adjective
# because i wa addicted to them
# ok good ! so addiction is a possible problem - anything else ?
# child trend to copy bad behaviour from game .
# ok thanks - quick example so i get the idea ?
# because they do n't have enough idea to recognise easily which behaviour are good or bad .
# Teacher Response: ok understood - 'bad behaviour ' ... for example ?
# -----------------------
# Input Utterances:
# hi < student > !
# hello !
# how are you today ?
# good
# and you ?
# good to hear !
# i 'm fine , thank you : )
# Teacher Response: it 's been raining here since out last class ! can you imagine ?
# -----------------------
# Input Utterances:
# ok , i got it , thanks
# ok < student > so let 's take another step here ok ? so we have given the basic number for coal in 2000 ( 130 out of 170 unit ) ... but what doe really mean ? it 's good if we can say that in word you know ?
# what i mean is ... in bad english we might say : 'yes coal really big 2000 ' do you see ? but in good ielts english we could say ... ?
# Teacher Response: not the number just this idea in word
# -----------------------
# Input Utterances:
# i suddenly now i have soooo much free time ... haha live is showing u that we should n't plan so much
# yes that 's true .... i guess we 've been pampered for decade
# sure
# we ca n't cope without our routine ...
# and the state doing lot of thing for u
# but it 'd be great ( if you want ) to keep looking at cae exercise
# Teacher Response: not that i 'm complaining exactly !
# -----------------------
# Input Utterances:
# is in march
# yes , cool
# what about 'my birthday is ___ the 13th of march
# on
# yes , correct . ' i usually eat cake __ my birthday '
# for
# mmm , we can say 'let 's make a cake for his birthday ' , but we say we do thing on a birthday
# what about __ monday ?
# on
# yes !
# __ christmas day ?
# for
# Teacher Response: on too !
# -----------------------
# Input Utterances:
# ?
# one more sorry .... i wa married for 5 year and it wa a disaster
# about your question earlier , how far from your house to the beach ? . do n't we need 'is ' in that sentence ? ?
# yes you 're right - i 'm being lazy and writing in short form - sorry i guess it 's the danger with this format !
# haha i see
# Teacher Response: but having said that .... it is used in speech too sometimes
# -----------------------
# Input Utterances:
# perhaps in italy , but in english
# ok
# first degree
# medicine , but in italy the entrance text is impossible to pas , so maybe i 'll study genomics
# oh right - there 's lot of work in that area here in cambridge you know that right ? !
# i know that in cambridge you must have taken the highest mark in the maturity exam
# is it right ?
# Teacher Response: do you mean it 's hard to get into cambridge university ?
# -----------------------
# Input Utterances:
# i understood the stuff of present continuous when i wa study online .
# i understood the stuff of present continuous when i wa studying online .
# ok thanks - the second one = correct good
# try one more if you can ok ?
# yes
# ok ...
# i wa learning in cambridge when i visited to london with my friend .
# Teacher Response: ok cool - you 've got it i think ...
# -----------------------
# Input Utterances:
# too simple sentence ?
# ok thanks a lot < student > ... wait a sec
# so no , not too simple
# you 've got past simple verb = good
# one question
# go
# one question : are the chart about coal production ? ? ? ?
# in this case , i ca n't use the verb halve ?
# ah ! can you ask my question first ? ?
# electricity production
# yes ! exactly good !
# so ... 'coal production ' ? ?
# coal of electricity ?
# i do n't know
# Teacher Response: ok no problem hold on a sec
# -----------------------
# Input Utterances:
# are you ready ?
# yes
# in some city and town the volume of traffic is a problem . what are the cause of this and what action can be taken to solve it ?
# you can check synonym with me first if you like < student > or just write the intro - i don ; t mind you decide !
# maybe just go for it ok ?
# yes i want to check firstly .
# Teacher Response: oh ok fine - yes check with me first then !
# -----------------------
# Input Utterances:
# < student > ... going back to the crowd in the park .... in the medium the following day there wa an ________ ?
# a word from yesterday !
# outcry ? ?
# yes exactly ! very natural here
# another similar possible word would be 'outrage ' by the way
# yes , i see how to use it ! thanks
# a bit stronger perhaps
# i 've seen that one
# more the feeling whereas outcry is more the protest
# Teacher Response: do you fancy having a go at a cae exercise ?
# -----------------------
# Input Utterances:
# i think a soldier might have lost it . what do you think ?
# i 'm not sure if he had lost it
# aha , what do you think happened ? what kind of a revolver wa it , by the way ?
# what kind ?
# yes . german , french , russian ? and how old wa it ?
# i do n't know i did n't see it
# Teacher Response: ah , i see . we can still try and guess .
# -----------------------
# Input Utterances:
# um ... 'adults ' is ok if you 're talking about adult in general ! hold on
# your noun is 'some game ' and this is fine ... but what come next ? singular or plural ?
# are
# ok good
# and the next word you have to change to the plural ? ?
# again it connects back to 'some game '
# a tiny little word ... !
# you ok < student > ?
# ok sorry - i 'll help !
# Teacher Response: you need to change 'it ' to 'they '
# -----------------------
# Input Utterances:
# what doe thick mean in your sentence ? ?
# yes no i see what you mean about he educated/posh thing - i realise you were n't being so simplistic
# so stupid is general - dumb = informal american and thick = informal british
# so think is a le rude way of saying stupid ?
# Teacher Response: not le rude actually ! just another word ....
# -----------------------
# Input Utterances:
# ok , < student > , now is your turn . could you come up with 2 truth and a lie for me , please ? i 'll give you a couple of minute
# ok
# 1.we have 3 cat and 1 dog . 2.we have pool
# ok , and the third one ?
# and 3 we have tractor
# cool , thank you
# i 'm going to adopt your strategy
# do you live in a house ?
# yes
# doe your family have a farm ?
# no
# Teacher Response: but do you grow a lot of crop ?
# -----------------------
# Input Utterances:
# i 'm laughing
# ha ! yes there are many many more ...
# no , i did n't know that use either ...
# ah ok interesting ... maybe le overlap than i thought with the verb share then ( i mean with spanish ) ...
# how about e.g . they share the distinction of being the only author to win the booker prize twice ?
# i think so , we would use the verb 'to have ' for that
# Teacher Response: bit random - just popped in there !
# -----------------------
# Input Utterances:
# wow
# that 's interesting
# they did better at school and went on to good university and have better job
# yes , that 's what people thought , wow !
# people thought , ah , we just need to teach kid some self-control
# what 's another word for it ? from the last class ?
# willpower ? )
# yes !
# so , a bit of willpower , and kid will be super successful !
# do you think it worked ?
# yes
# Teacher Response: no ! : ) )
# -----------------------
# Input Utterances:
# can you the complete the middle ? !
# only with the other word in the document remember !
# coal wa main fuel , producing 50 percent of it electricity .
# ok good - that 's the right idea and a good example sentence ! can you see the word i 've given you for number 5 in the document i emailed you ?
# Teacher Response: sorry number 2 i mean !
# -----------------------
# Input Utterances:
# which game do you play ? my husband is really into video game , but i only play some lego game with my son ( he 's nearly 5 )
# my favourite game are gta5 and fortnite
# i see ! my favourite is lego superheroes . beginner level , i know : )
# doe your husband play on xbox , doe n't he ?
# no , he play on his desktop
# he 's playing the new assassin 's creed now
# Teacher Response: well , not right now , but you know what i mean
# -----------------------
# Input Utterances:
# understand
# for example , my friend a doe n't like it when i spend time with my friend b. i think a is jealous of b
# jealous of
# the noun is 'jealousy '
# so my cat is on my knee and i think it doe n't recognise a lizard a creature
# ha , interesting ! is she ignoring the lizard ?
# lizad 's tail is on cat 's head : )
# Teacher Response: haha : ) ) ) )
# -----------------------
# Input Utterances:
# yes , it 's usually very fast
# you know what they say about english people ? when they joke they 're being serious and when they speak seriously they 're joking
# not everyone - but me for example - yes it 's often true
# i 'm glad you reminded me el club de la comedia , i should watch a bit everyday now that we are having difficult time : )
# Teacher Response: yes you 're right - maybe comedy is the way to go - just month of comedy - however stupid it is !
# -----------------------
# Input Utterances:
# ok
# cool , here go
# 1 . i grow lot of food in my garden . 2 . i live in cambridge . 3 . i have two pet guinea pig .
# what are pig name ?
# bubble and squeak : )
# so if i 'm sure that i know which one is lie what should i do ?
# Teacher Response: just tell me !
# -----------------------
# Input Utterances:
# sorry what do you mean with e g ?
# for example !
# ah ok
# ahaha
# ha !
# there wa a similar drop in coal and oil between 1980 and 2000 in france
# ?
# ok thanks a lot .. hold on ...
# so you could say : oil and coal were both significant source of electricity in 1980 , contributing 20 and 25 unit respectively but ....
# yes that 's better
# by 2000 their relative contribtion had fallen to ...
# Teacher Response: so.ething like this ... ok ?
# -----------------------
# Input Utterances:
# hold on ...
# ok
# so it 's better to do a logical distinction
# it a bit difficult to go through it right now and we 're going to have to stop now but ... yes i think i know what you mean with logical distinction and i agree ... we 'll come back to it soon ok !
# sure thanks !
# ok cheer < student > speak to you soon
# Teacher Response: bye !
# -----------------------
# Input Utterances:
# the
# yes , because it 's < lizard 's name > the lizard , not just any lizard , right ?
# a __ creature
# a
# yes , well done !
# how about 'lizard 's tail is on cat 's head ' in term of the article ?
# the lizard 's and on the cat 's
# correct : )
# did you manage to find that piece of english text where you could think about the article ?
# sorry i forgot about that : (
# Teacher Response: ok , no worry , maybe for the next time
# -----------------------
# Input Utterances:
# in
# yes , good . in the photo and in the picture
# if you ever decide to take cambridge english first , there is a task where you describe picture , and you have to say 'in the photo ' a lot
# ok , moving on
# in the morning , in the afternoon , in the evening , ___ night
# at
# good ! did n't catch you there : )
# __ the weekend
# at
# Teacher Response: yes , in british english . your american cousin probably say 'on the weekend '
# -----------------------
# Input Utterances:
# face-to-face lesson were longer
# oh really ? interesting !
# we had pair of face-to-face lesson
# how do you mean ?
# oh , i know
# double math , double engish and so on
# right ?
# yes you 're right
# so , what do you hope will happen in september ? would you like some element of studying from home to remain in place ?
# we are going to have online school
# Teacher Response: oh , do you know for sure ? or is it what you think will happen ?
# -----------------------
# Input Utterances:
# or are they your uncle 's ?
# yes
# ok , then
# i 'm with ___ dog and cat '
# uncle 's dog and cat
# nearly ! ' i 'm with ___ uncle 's dog and cat '
# the
# we 're not sure whose uncle he is ! : )
# it 's strange
# i know : ) but still !
# i 'm with ...
# my uncle 's dog and cat
# yes ! !
# well done !
# ok , now this one , easy 'mum must be angry if we do n't have lesson '
# my mum
# Teacher Response: yes !
# -----------------------
# Input Utterances:
# do you mean for the 30 % figure ?
# yes
# well you ca n't say between 40 % and 50 % right ?
# because it 's le than 40 % ( ? )
# may i ?
# ?
# yes sorry , i mean 20 % and 40 %
# ah sorry : )
# or 25 and 35
# no this is unnecessarily vague
# sorry
# Teacher Response: if you have various figure in that range then maybe
# -----------------------
# Input Utterances:
# sure
# ok ... can i ask you to have a go then at writing the following sentnce ... hold on a sec
# ok
# referring to the first chart : the 'satisfied ' category ! not an intro or nay comparison ... just the basic fact about that category for the first chart ... thanks !
# ok
# the satisfied people during the year before refurbishment , accounted for 30 %
# Teacher Response: thanks < student > - good to see you trying to use 'account for ' again ! hold on ...
# -----------------------
# Input Utterances:
# what do you think ?
# could be
# the big criticism of the marshmallow test wa that there were poorer and richer kid
# how do you think rich kid might have reacted ?
# they might have eaten it
# i think
# why ?
# i do n't know
# well , rich kid had lot of sweet and toy anyway
# so it wa easier for them not to eat the marshmallow
# maybe because they known that their parent can buy them everything they want to
# exactly !
# Teacher Response: one marshmallow wa n't important to them
# -----------------------
# Input Utterances:
# morning < student > !
# good morning !
# how are you ?
# fine
# how 's life in your other village ?
# good
# Teacher Response: that 's great , have you got an internet connection in the house this time ?
# -----------------------
# Input Utterances:
# hi < student > !
# hello < teacher >
# how are you ?
# i 'm fine
# great . how 's your lizard ?
# it 's on my t-shirt
# Teacher Response: oh really ? i thought it only lived in it tank .
# -----------------------
# Input Utterances:
# ok , do you prefer video chatting on skype or on zoom ?
# wait , sorry , it 's your turn ! !
# wait a second
# ok
# when is it better for you to talk with your parent : in the morning or at night ?
# hmm , i actually talk to them in the afternoon .
# Teacher Response: ok then , do you prefer video chatting on skype or on zoom ?
# -----------------------
# Input Utterances:
# like a dentist with a bad tooth ( do you know the word ? ! _ ... or another way to say it of you can think of one !
# hey < student > ... 'extract ' is good ok ? sorry - we 're running out of time ...
# explore
# ah ok not a bad idea !
# extract is best ok ? !
# Teacher Response: sorry < student > we 're coming to an end here - i took too long i 'm afraid ... hold on ...
# -----------------------
# Input Utterances:
# i 'm trying to open the chat on my laptop right now
# ok .... i wa thinking of buying an ipad actually - do you have any apple product ?
# no , i do n't . i have a tablet but i find it difficult to type on it
# yes i see - i 'm getting used to one but i wa thinking of making some video so wanted to get a good quality version ...
# i see
# Teacher Response: are you on your laptop now ?
# -----------------------
# Input Utterances:
# and have faith that you are improving ( you are ! )
# and try to enjoy the process
# do n't think about a 'finish line '
# yes ... i really enjoy the whole process when i am studying new knowledge .
# but sometime i feel unhappy .
# yes ... can you set yourself small achievable goal ?
# because i also forget many knowledge .
# Teacher Response: the problem sometimes is that you have no way to measure your progress you see ?
# -----------------------
# Input Utterances:
# ___ sunday afternoon
# in
# nope ! __ sunday afternoon
# on
# yes . in the afternoon , but on sunday afternoon
# __ the past
# in
# yes !
# __ july
# on
# nooo !
# in with month
# in
# like in ukrainian and russian
# ___ 2019
# in
# yes
# __ the autumn
# in
# ___ july 31st
# in
# no , it 's a particular day
# on
# yes !
# __ skype
# on
# yes
# __ the park
# in
# nope
# at
# yes : )
# __ the photo
# in
# Teacher Response: yes !
# -----------------------
# Input Utterances:
# i see , thanks
# the verb appeal = much more common than attract in this context by the way
# structure : i 'm attracted to x . = ok but ' x attracts me ' correct but le normal
# x appeal to me ' = normal
# i think that people who choose to become a politician are very interested in society , in how thing work
# uff it 's difficult to explain
# i 'll try
# Teacher Response: ok
# -----------------------
# Input Utterances:
# i think it 's impossible . they might be very expencive
# you know 'guinea pig ' ? they are not real pig !
# they are small pet animal , a bit bigger than a hamster but not a big a a rabbit
# they are not expensive : )
# i think that number 3 is lie
# nope , number 1 and 3 are true !
# ok
# Teacher Response: i do n't live in cambridge , though . i live in a little town called march , it take about 30 minute to get to cambridge by train
# -----------------------
# Input Utterances:
# hey there ...
# hi - i am here
# ok < student > ... i 've been thinking about the topic and argument in favour of investment space exploration .. hold on
# Teacher Response: have a look at these 4 main idea ( just keywords ) and see of you agree which one you agree and why ok ?
# -----------------------
# Input Utterances:
# have you followed any of the news in english ?
# yes , i follow bbc news on facebook so everyday i read something , at least the headline
# finally your president in not in intensive care whatever haha i do n't know the word
# ok right - very conscientious of you - so yeah , you 'll have picked up all the phrase we use .... it 's all good vocabulary
# no , intensive care = perfectly correct
# Teacher Response: yes he 's out now ... so i guess he 'll recover
# -----------------------
# Input Utterances:
# yes regret
# yes exactly ... so i wish i wa n't a babysitter ( now ) i wish i had studied medicine or whatever
# in the past
# because i ca n't change the thing now
# yes exactly !
# ahhhhh
# thanks
# so 3rd = unreal past
# and 2nd = unreal present/future
# thanks a lot
# ok no problem - < student > keep going with the skill if you 're ready
# the skill question i mean
# yes i am
# ok ...
# Teacher Response: you ok ?
# -----------------------
# Input Utterances:
# and tomorrow we are traveling to kovel again
# ok , < student > , remember annabel and her friend who tried to vote for her in the talent show ?
# yes
# will you be staying in kovel again
# ?
# on sunday we will be in lviv on a wedding
# it the first time when i am traveling to lviv
# oh wow ! are you sure you would like three class next week ? sound like you are super busy
# only for a night
# Teacher Response: you will love it , lviv is beautiful !
# -----------------------
# Input Utterances:
# sound perfect !
# i 'm going to take a week off at some point in july , but my husband and i are not sure what to do ! lot of place are still closed
# so it might be a 'staycation ' . do you know this word ?
# no , i do n't
# you know 'vacation ' , another word for holiday ? more american
# ok
# Teacher Response: vacation + stay ( at home ) = staycation
# -----------------------
# Input Utterances:
# also , some of them were kid from rich family and some from poor
# how do you think kid from rich family reacted ?
# they might have eaten it
# they might ! but also , rich kid had the money to buy lot of toy and sweet , and one marshmallow wa n't a important to them . so it might have been easier for them not to eat it
# yes
# Teacher Response: but poor kid did n't get much stuff , and when they saw the marshmallow , they just ate it
# -----------------------
# Input Utterances:
# haha very long , i know ...
# is it correct or is it repetitive ( considering that take for granted mean that ? )
# long and good ! yes that 's definitely a realistic example - and obviously more specific - no it 's not repetitive at all - it just replaces another verb like e.g . assume
# i see , thanks
# in fact < student > it is often basically a synonym for assume
# Teacher Response: for something good or bad
# -----------------------
# Input Utterances:
# hahah
# sorry - i wa looking at the corpus ... the word relate to the collocation it 's giving for 'abide '
# i tried to find the word on bcn but it say that to continue i have to register ... so i 'll do it later
# Teacher Response: oh no ! yes it 's free - sometimes it asks me and other time it doe n't - i registered , forgot my login and now just reload the page and it usually seems to work but yeah try later ....
# -----------------------
# Input Utterances:
# no of course - never enough time .... i wa thinking that part of the difficulty with e.g . the cae exam is getting familiar with the range of language they test you on . sometimes watching/listening to more formal stuff can be helpful
# english language i mean
# e.g . factual programme
# or topic-specific stuff
# factual ? ?
# documentary for example ?
# yes , because e.g . documentary often use more formal language
# sure
# or current affair ( if you 're into that )
# Teacher Response: not only poilitics !
# -----------------------
# Input Utterances:
# you have to remember < student > that the video on coursera are not designed for non-natives - they would be hard for most student
# also , you a n't expect to understand everything ... did you understand the main idea in the video ?
# ca n't expect i mean
# yes .. and another thing i am unhappy is that our class ending on wednesday .
# Teacher Response: yes i can understand that - it wa quite a routine i can imagine ...
# -----------------------
# Input Utterances:
# ok great i think you understand the idea but you have have to say/write it correctly ..... so hold on ....
# ok
# the main verb is 'spend ' right ?
# yes
# spending money should on public service , such a school and hospital .
# hi < student > sorry .. i lost my internet for a while there - can you read this ?
# yes , i can read it now .
# Teacher Response: ok great !
# -----------------------
# Input Utterances:
# sahara is the largest desert in the world .
# ok thanks < student > . i wanted to check this area ( or part of it at first ) for article ! doe that you make you change any of your answer ?
# sure , it 's okay .
# i 'll give you a clue : if you are talking about oceans/deserts/rivers you need .... ?
# the the the the the the the the but only once obviously
# i need to put 'the ' ? ?
# Teacher Response: yes !
# -----------------------
# Input Utterances:
# can i ask you a question ?
# it 's becoming more popular now , though
# yes sure !
# what fast food restaurant are popular in uk ?
# good question !
# mcdonalds and kfc are here of course
# but traditional english 'fast food ' or takeaway food is fish and chip
# there are lot of fish-and-chips shop in every town , or 'chippies '
# i heard something about fish and chip
# Teacher Response: yes , it
# -----------------------
# Input Utterances:
# morning < student >
# good morning !
# we still have a couple of minute before the class start , i did n't realize : )
# and we can start ! how are you today ?
# i 'm fine . and you ?
# Teacher Response: fine , thank you ! just a bit annoyed with the weather
# -----------------------
# Input Utterances:
# ofcourse
# 😁
# ok great so could you give me a quick example of the language we practised last time ? maybe use france 1980 and nuclear power a an example ok ?
# ok
# nuclear power wa generate to electricity 50 unit in france in 1980
# generated
# ok thanks < student > ... just 'generated ' or 'was generated ' ?
# only generated
# ok good ! hold on ...
# and where doe the number go ? before or after the noun it 's referring to ?
# before
# Teacher Response: ok so ... nuclear power generated .... ?
# -----------------------
# Input Utterances:
# word that mean the same thing . so 'large ' is a synonym of 'big ' .
# maybe it like protect wildlife = wildlife protection
# yes that 's a great example !
# can you try some more for some of the other word - you can choose simple synonym if you like .. that 's fine
# spend = waste
# yes ok good if you mean it negatively ... keep going ...
# important = necessary
# ok great
# Teacher Response: more more !
# -----------------------
# Input Utterances:
# you ok ? begin with the word 'males ' - doe that help ?
# male student account for the majority of my morning class
# yes very good !
# so the total/title/subject in a pie chart would be e.g . 'students ' so ... the small category first e.g . male followed by the account for followed by the total - ok ?
# one last test : use the same structure to tell me about france oil 1980 ok ? a full sentence !
# ok
# Teacher Response: ok
# -----------------------
# Input Utterances:
# so i have to use phrasal verb only with set ? ?
# yes that 's right !
# ok !
# 1 set off
# ok great ( note you need the destination ( or at least implicit )
# 2 no idea
# that 's ok come back to it after elimination ok ?
# ok
# can i use the dictionary ? ? i do n't know the meaning of the option so , no idea : ( . i only know set up and set off
# Teacher Response: yes sure hold on < student > - let me do something first ...
# -----------------------
# Input Utterances:
# e ) close brush ( i like this one ! brush like in tooth brush )
# yes this is a good one - and normal ! close shave = same meaning
# haha i understood it wa a popular word nowadays
# yes i guess ...
# actually close brush and close shave not totally the same i ; ll come back to that in a bit ...
# okk
# f ) bollock
# Teacher Response: ok thanks ! a bit vulgar obviously but very common !
# -----------------------
# Input Utterances:
# good afternoon < teacher > .
# hi there < student > , everything ok with you ?
# yes , i am health .
# ok great , i ; m pleased you 're healthy !
# just stay at hotel by myself for 14 day , and nurse are take care of everyone .
# oh right - so you 're in quarantine for 2 week ? !
# but have you tested negative ?
# absolute , i for 2 week .
# yes , the test wa negative
# Teacher Response: ok right but you still have to stay isolated ? ? ?
# -----------------------
# Input Utterances:
# yes , thank you !
# ok great - < student > i wa wondering if you might like to talk about the topic of the environment today ?
# environment ! it seems difficult . but it 's ok !
# ok well .... are environmental problem something you thing about much - if so , which one ?
# think
# i think about the global warming recently a it 's getting warmer every year !
# Teacher Response: yes i see ! i guess that 's the one that 's in the news most at the moment right ?
# -----------------------
# Input Utterances:
# ok
# 1.we have 3 cat and 1 dog . 2.we have pool
# ok , and the third one ?
# and 3 we have tractor
# cool , thank you
# i 'm going to adopt your strategy
# do you live in a house ?
# yes
# doe your family have a farm ?
# no
# but do you grow a lot of crop ?
# no
# ok
# can you swim ?
# yes
# oh , do you mean a 'pool table ' or a 'swimming pool ' ?
# swimming pool
# Teacher Response: got that
# -----------------------
# Input Utterances:
# yes really tough a you say for people with toddler etc i live in the middle of nowhere so i guess nobody can stop me from going for a walk where i am ....
# haha we have something similar ! 'me río por no llorar '
# ok nice - thanks ! exactly the same really ...
# you are very lucky there in the middle of nowhere
# Teacher Response: ya got ta laugh ' is if you can imagine the quick spoken form of the phrase ...
# -----------------------
# Input Utterances:
# it 's magnified of course
# magnified ?
# magnify = make an image bigger
# a magnifying glass is what we use to have a good look at really small object
# oh
# okay
# what food do you think it might be ?
# the thing in the middle look like a piece of apple
# but i do n't think it is
# aha , so it could be ... could you make a sentence with one of the modal we talked about last time ?
# the thing in the middle could be a piece of apple
# Teacher Response: good one !
# -----------------------
# Input Utterances:
# well they can be in a way - they 're kind of a cross between a car and a house you know ? a in they do n't retain heat very well but hey warm up quickly
# i see
# yes i just mentioned it because it struck me that it 's related to the idea of kindling you see ? because you kindle a flame - in this cae the flame of knowledge ... you kindle a feeling
# Teacher Response: in this case
# -----------------------
# Input Utterances:
# aha
# ok , cool , you sound more confident with this material today , right ?
# yes
# cool . i 've got something for today , some bit of it will probably be very familiar , but some maybe new
# my birthday is __ march . we talked __ skype . she 's always ___ her phone .
# could you insert some preposition please ?
# on march on skype on her phone
# 43892.0
# in march
# which month is your birthday ?
# march
# oh really ?
# Teacher Response: march too ? which date ?
# -----------------------
# Input Utterances:
# what about __ monday ?
# on
# yes !
# __ christmas day ?
# for
# on too !
# oh
# there 's logic to it , you 'll see in a minute
# ___ friday afternoon
# on
# yes , correct . basically , when we have the word 'day ' or when we mean a particular day , it 's always on
# on monday , on my birthday , on christmas day , on march 13th
# my 13th birsday wa on friday 13th : )
# Teacher Response: ooh , what did you do ?
# -----------------------
# Input Utterances:
# why batter , but not butter ?
# then there are lot of place where you can get a coffee and a nice sandwich , such a costa , starbucks , pret-a-manger
# i know starbucks !
# i want to drink some coffee there one day
# oh , batter is what you make out of flour , egg , maybe a bit of milk or water , or even beer . then you put the fish in the batter and fry it
# you also make some batter to make pancake !
# oohh
# Teacher Response: is there starbucks in kyiv ?
# -----------------------
# Input Utterances:
# about two month ... i came here in the middle of september .
# ok so a while now - long enough to start really getting a feel for the place i guess
# yes , i love this city very much . it ha plenty of nature compared to my hometown , tokyo .
# i feel more relaxed than in tokyo .
# Teacher Response: yes , i can imagine - there are lot of green space whereas i have an image of tokyo a being very built up ( i 've never been there though .
# -----------------------
# Input Utterances:
# hi
# i am < student >
# good afternoon < teacher >
# are you here ?
# Teacher Response: hi < student > are you there ?
# -----------------------
# Input Utterances:
# it is similar to the name of the type of a dog
# of course , that 's right ! yorkshire terrier : )
# it sound interesting
# i just googled , and they were actually bred in yorkshire in the 19th century
# ok , great . so here are my 4 thing
# ok
# Teacher Response: 1 . march 2 . shanghai 3 . bubble and squeak 4 . little woman
# -----------------------
# Input Utterances:
# not even inside ?
# you mean on the stair or something ?
# no : ( . i do n't understand why not . i just talked to one of my neighbour and he told me ( in a good way ) that if i do it , everyone would do it too . and i really think that we could plan a half and hour-walk for everyone during the day ...
# half-and-hour-walk ?
# Teacher Response: a half-hour walk ( you mean 30 minute right ? )
# -----------------------
# Input Utterances:
# we often say e.g . 'the pay is really good ' or what 's the pay like ? you see
# or after a pronoun e.g . my/you pay etc
# your pay i mean
# so e.g . there 's a problem with my pay - i need to talk to the finance department at work ( ok ? )
# i understand now . thank you !
# sorry one more i ; ve realised is really common
# okkk
# e.g . doctor ' pay is set to rise by more than 5 % ...
# Teacher Response: very common in the medium
# -----------------------
# Input Utterances:
# the world ha change
# changed
# yes good ! if your bos asks you is ok ( but with the 's ' ) .. what about 'allow ' ?
# allows
# sorry i 'll tell you this one : it 'allowing ' : 'you think you 're bos is allowing you to ... '
# ah , i see
# and the 'will ' example ?
# Teacher Response: you will make a mistake ... ?
# -----------------------
# Input Utterances:
# 2.obesity is increasing significantly .
# could i use ' obesity a a issue ha ... ' 'obesity a a issue is increasing ..
# or just obesity itself is a problem ?
# sorry internet went out ....
# do n't worry , it is always happen .
# well 'obesity ' is automatically bad generally yes .... you can just say 'obesity ' or if you like 'the problem of obesity ' but 'obesity a a problem .. ' = le good
# Teacher Response: just say 'obesity ' - it 's best !
# ...
# so you can say our personality is 'fixed '
# okey , i got it .
# a a synonym for 'predetermined '
# transform = good idea but ... it mean change completely ... can you think of a le extreme synonym ?
# beginngin with ' a ' ? !
# switch
# beginning with ' a ' ... ?
# al ... @ ?
# alter
# we lean it on class
# Teacher Response: yes ok - that 's good a a general synonym for change
# -----------------------
# Input Utterances:
# sure
# ok the kindling ha caught this time ...
# i sit warm where you are at the moment ?
# is it warm i mean !
# sorry , i do n't understand ... kindling ? ?
# ah yes sorry - it 's the name for the little bit of wood or whatever you use to start the fire at the beginning
# here 18 degree now , during the day it 's very sunny
# Teacher Response: nice .... yes it 's actually really sunny this week here too - and maybe .... 13 degree !
# -----------------------
# Input Utterances:
# no of course - i see ..
# but when i watch series in english i pay more attention in case there is something we 've practised recently ...
# by the way , have you watched the spanish series 'la casa de papel ' ? it 's very popular here
# yes good that 's the key right ? it 's called 'noticing ' in language teaching ( not a very technical term i know ! )
# Teacher Response: ah no i have n't heard of that but i 'll look out for it
# -----------------------
# Input Utterances:
# so the 'as a result ' directly follows the fact that they ca n't tell it is n't real do you see ?
# yes .. i see it
# ok cool ...
# it become more logic , 1. topic sentence 2.the explain of main idea 3.consequence
# Teacher Response: yes i think so
# -----------------------
# Input Utterances:
# because there is no blood and it 's different from others and all shooter are always 18+
# i see ! it all make sense , thank you very much !
# also , really well done with all the writing today !
# but you still need to see gameplay
# oh i will now , thank you . it 'll be my homework : )
# now , let 's have a go at some sentence i copied from the chat . could you insert the missing word ?
# Teacher Response: it 's pretty warm with cat
# -----------------------
# Input Utterances:
# yes well ... i have certainly always loved music
# and i ; m grateful for having been exposed to lot of different kind
# i enjoy sharing a wide variety of stuff with my daughter now
# but wa he disillusioned by your 'lack of ability ' or it wa just you ?
# it 's always cool seeing kid read/listen to/see cool stuff for the first time you know ?
# Teacher Response: no he wa actually very patient/encouraging/relaxed - it wa me !
# -----------------------
# Input Utterances:
# it mean that 'coal wa the ... ?
# wood ?
# most ... ?
# plant
# log
# no hold on ... a a source of electricity coal wa the most ....
# oh
# production
# ok we 're running out of time so ... 'coal wa the most significant source of electricity in australia in 1980 , generating 50 unit out of 100 unit ' = a good sentence !
# ok ?
# ok
# Teacher Response: your noun 'production ' is a good word - we 'll come back to that next tkme ok ?
# -----------------------
# Input Utterances:
# yeah - it 's generally a few degree colder up there - and much wetter too
# now i remember you really like hot weather and the sun etc !
# i 'm not so bothered to be honest
# and where did you stay if you did n't camp ?
# i kind of like the temperate climate not really hot or cold
# we were lucky and stayed in a house belonging to friend of my in-law - a nice one - so it felt pretty luxurious for u !
# Teacher Response: while they were away abroad
# -----------------------
# Input Utterances:
# hi < student > !
# hello !
# how are you this morning ? out of the cold and rain ?
# today weather is good : )
# are you still in the porch though ?
# yes
# Teacher Response: ok ! well , hope you are comfortable
# -----------------------
# Input Utterances:
# just use the one you have later ok ?
# ok , thank you
# ok do ... < student > let 's go with the chart ! could you write a short sentence with the following information please : australia coal 1980
# do n't compare with anything else i.e . gas or another time or e.g . france ok ?
# ah i see
# ok i 'll wait take your time ....
# in 1980 , australia had produced electricity by coal source 50 unit
# Teacher Response: ok thanks < student > wait a sec ...
# -----------------------
# Input Utterances:
# ok , moving on
# in the morning , in the afternoon , in the evening , ___ night
# at
# good ! did n't catch you there : )
# __ the weekend
# at
# yes , in british english . your american cousin probably say 'on the weekend '
# __ 9.30 am
# at
# Teacher Response: yes , a you 've probably realized , we 're doing phrase with 'at ' : )
# -----------------------
# Input Utterances:
# i gave up smoking a long time ago by the way thank god ...
# yes , i think you are right . i 'm not sure if runner keep running in summer time ... i do n't know if you know that in the canary island it is generally 22 degree all the year round ( is it correct ? ) so we do n't have that problem
# oh yes of course i forgot about that ... perfect ! you can say : 'all year round '
# Teacher Response: without 'the '
# -----------------------
# Input Utterances:
# wow - yes i see , really distinctive ( it seems to me ) ... yes canarian =correct but i guess most english people would probably say 'from the canary island ' due to lack of familiarity i 'm afraid !
# ok amazing - any basic info on this population ? !
# they came from the north of africa and they lived in cave
# ok i see - i 've never considered this ...
# so arabic-speaking ?
# they were farmer and also grew vegetable
# Teacher Response: this is inspiring me to visit ...
# -----------------------
# Input Utterances:
# no .. just study fundamental knowledge in school .
# ok good ... you attempted to write an intro .. show me if you 're ready !
# yes
# it is often argued that the most effective way to lead a le pressure lifestyle is charter a house . obviously , it is difficult to ass the po and con effect of renting a house . in my opinion , although house rental play a significant role , some uncomfortable experience possible occur .
# Teacher Response: ok ... ( 'basic ' knowledge better by the way )
# -----------------------
# Input Utterances:
# in
# to !
# it 's a good expression though
# are you still in kovel ? is it still sunny and summery ?
# it is sunny , but a bit coldy
# oh that 's a shame
# ok < student > , quick memory test . could you give me an adjective with the opposite meaning ?
# possible - ?
# impossible
# yes !
# logical
# illogical
# legal
# illegal
# polite
# impolite
# expensive
# inexpensive
# yes , correct !
# regular
# irregular
# mature
# immature
# correct - ?
# incorrect
# rational
# irrational
# sane
# insane
# convenient
# inconvenient
# Teacher Response: comfortable
# -----------------------
# Input Utterances:
# do n't worry if not ! just tell me ...
# high or low ?
# impossible
# low
# ok thanks !
# so another way of saying this could be : 'it is very _______ that you will get a double six . ' ?
# unl_ _ _ _ _ _ ' ? ?
# unl ....
# unlikely !
# Teacher Response: so if child play violent video game they are _______ to copy the behaviour they see . '
# -----------------------
# Input Utterances:
# are you hungry and thinking about ramen ? : )
# not really
# just the first food that came on my mind
# i see : ) the first food that came ___ my mind
# in
# to !
# it 's a good expression though
# are you still in kovel ? is it still sunny and summery ?
# it is sunny , but a bit coldy
# oh that 's a shame
# ok < student > , quick memory test . could you give me an adjective with the opposite meaning ?
# possible - ?
# impossible
# yes !
# logical
# illogical
# Teacher Response: legal
# -----------------------
# Input Utterances:
# __ the park
# in
# at !
# at the park/ at the theatre , at the cinema
# ok , ready for me to mix them up ?
# ___ sunday afternoon
# in
# nope ! __ sunday afternoon
# on
# yes . in the afternoon , but on sunday afternoon
# __ the past
# in
# yes !
# __ july
# on
# nooo !
# in with month
# in
# like in ukrainian and russian
# ___ 2019
# in
# yes
# __ the autumn
# in
# ___ july 31st
# in
# no , it 's a particular day
# on
# Teacher Response: yes !
# -----------------------
# Input Utterances:
# especially for speaking part 2
# because in chinese we do not have tense , so i always forget them when i am writing and speaking .
# so look at these point for part 2 speaking : describe a journey that did n't go a planned . you should say : ( hold on ! )
# yes , i am lack of part 2
# Teacher Response: 1 . where you were going 2 . how you were travelling 3.who you were with 4.what went wrong 5 . explain what you would do differently
# -----------------------
# Input Utterances:
# good to hear . what 's the weather like ?
# sorry , something went wrong witht the program for a second
# it 's sunny and very hot
# guess what !
# ooh , good ! it 's going to be hot here on friday . in the uk , spell of hot weather are called heatwaves . they do n't usually last !
# what ?
# i 'll have new friend
# oh yes ? did you meet someone ?
# no , it 's lizard !
# what ? really ? ? what kind of lizard ?
# it 's __ lizard
# a
# Teacher Response: aha
# -----------------------
# Input Utterances:
# hi there - good to speak to you again . < student > , i thought i 'd make this lesson a bit more focused so here go ! can i ask you to write a sentnece using the following information : pacific/biggest
# the pacific ocean is the biggest ocean in the world .
# thank you - another one : nile/longest
# the nile is the longest river in the world .
# ok nearly there ! everest/himalayas
# mt . everest is the highest in the himalaya .
# Teacher Response: thanks - usa/50 state
# -----------------------
# Input Utterances:
# i see
# e for the barrel ? ?
# sorry you know 'barrel ' like round made of wood right ?
# yes e !
# can you use 'at sea ' in a sentence , please ?
# yes of course - so it 's like you do n't know what to do or you ca n't cope - like : i wa all at sea in my new job on the first day
# Teacher Response: it reminds me of e.g . to be out of your depth ( another watery phrase ! ) - you know that one ?
# -----------------------
# Input Utterances:
# ok
# so good = search for alien life/ develop space technology/ for instance/ however , 窶ｦ
# question : is expenditure a noun ?
# yes ... so expenditure of public money on search for alien life .
# or government expenditure of search for alien life .
# expenditure of public money of search for alien life .
# sorry .. internet ... ! ok hold on .. i think the government should + noun right ? so you ca n't have 'expenditure ' next here ...
# Teacher Response: can you solve this problem here ?
# -----------------------
# Input Utterances:
# to be honest i do n't know what to say about judge ... what do you think ? ?
# sh-corpora.org/bnc/ sorry that wa a link to a website - a language corpus site where you can search with keywords - it ; s cool - have a look now if you want quickly ? give me a minute to think about judge ok ?
# sorry here 's the full link ...... sh-corpora.org/bnc/
# aahhhhh ! hold on
# Teacher Response: sh-corpora.org/bnc/
# -----------------------
# Input Utterances:
# hi < student > , happy new year ! how are you ?
# happy new year ! good , thank you .
# Teacher Response: great - how wa your christmas - did you stay in cambridge ?
# -----------------------
# Input Utterances:
# great news about your leg ! ! !
# i wa pessimistic about my leg because i 've had sport injury before that did n't get better without surgery but seems like i 've been lucky this time
# yes , i mean 'we will be able to walk around our house ' is it correct the use of 'place ' in that case ? ?
# Teacher Response: but i might take it down a bit/play it safe ... a bit more swimming/cycling ( nice and safe ! )
# -----------------------
# Input Utterances:
# because at least she will be expose to nice thing and maybe she is not liking them just because she is a teenager
# ohh it 's time ! i will really miss our classes/conversations
# Teacher Response: ok right - i think it wa when you wrote 'even when ' i got confused ... yes ok < student > , well it wa good to work with you on this site and i wish you all the best
# -----------------------
# Input Utterances:
# yeah , i 'm using my phone , it 's better than the last time , is n't it ? ?
# i 'd say you 're definitely faster yeah - this is me at maximum speed i 'm afraid !
# it 's good for me . haha
# : ) listen < student > i thought i 'd try something a bit more specific if that 's ok - so here go ...
# what ’ s the connection ? tokyo/japan
# do you mean my hometown ?
# Teacher Response: no i mean : what 's the connection between those two word ?
# -----------------------
# Input Utterances:
# do this one
# sorry i should have kept a record ( actually i did but i ca n't find it )
# not sure ... my memory is really bad : ( . i know we did the other one because i wrote the answer with pencil on the book and i never do it unless i do it with you
# ok - how about a part 4 ? page 150 for example ?
# ok , 150
# Teacher Response: ok i 'll give you a littel bit longer for each one a they 're slightly more complicated perhaps
# -----------------------
# Input Utterances:
# with
# good !
# < student > is good __ math .
# in
# at !
# good at , bad at , brilliant at , terrible at - it 's always 'at '
# okay
# for example , i wa quite good at math at school but now i 'm terrible at it !
# ( true story )
# i 'm quite good at language . i 'm also good at understanding child and i 'm studying developmental psychology . but i 'm pretty bad at math and physic
# Teacher Response: what about you ?
# -----------------------
# Input Utterances:
# wait a minute
# doe 9.30 am on tuesday sound good to you ?
# let ’ s talk about it in the skype , okay ?
# ok
# squeak
# aha , yes
# the food that 's left from yesterday ?
# but i know what doe it mean now
# leftover
# leftover food ( leftover is an adjective here ) or leftover ( plural noun )
# am i right ?
# yes !
# so 3 word
# Teacher Response: for example , i sometimes have leftover for lunch
# -----------------------
# Input Utterances:
# your turn in a minute !
# do you know the word for 'travel to work regularly ' ?
# travel to work ? i have no idea
# commute
# he commute to work ( or at least he did before the quarantine )
# ok
# do you commute to school in kyiv or are do you walk ?
# i commute to school
# sorry , 'or do you walk ? ' , without 'are '
# ok , do you commute by underground ?
# no , i do n't
# Teacher Response: by car ?
# -----------------------
# Input Utterances:
# yes , it feel like that
# i 'm alright , it seems we are going to start going out soon ... so happy about it
# how about you ?
# yes i can imagine - i wonder what it will be like ?
# i mean will thing feel different for a while ?
# Teacher Response: yes i 'm fine thanks - to be perfectly honest i 'm quite a self-contained person ( well that 's one word for it ! ) so the whole lockdown thing ha not really affected me that much
# -----------------------
# Input Utterances:
# hi < student > !
# hello !
# how are you today ?
# good
# and you ?
# good to hear !
# i 'm fine , thank you : )
# it 's been raining here since out last class ! can you imagine ?
# wow
# but at least after the rain we should have a heatwave
# how 's vinnytsa ?
# just cloudy
# Teacher Response: do you prefer it like this or do you like sunshine ?
# -----------------------
# Input Utterances:
# sorry , do you do or teach ?
# yes i do/teach exam class
# both are fine
# okk
# lot of ielts recently but the other cambridge exam too
# did you do first certificate ?
# so you know what i am suppose to know . i mean maybe we could practise vocabulary that is used in cae ... i do n't know , just an idea
# no , i 've never taken an english exam
# Teacher Response: yes of course - that 's fine and yes a good idea for you - do you have book ?
# -----------------------
# Input Utterances:
# hi there ...
# hi
# Teacher Response: ok < student > ... so if you 're ready , have a think about what you can tell about yourself using any of these adjective :
# -----------------------
# Input Utterances:
# i 'll use it from now on
# ok !
# so by the way 'wage ' is more generally associated with 'blue collar ' job ( a bit outdated this phrase but still useful here ) and 'salary ' more for 'white-colalr job '
# sorry 'collar '
# no idea about blue or white collar
# salary ' agreed in advance and often monthly blah blah - wage maybe hourly for example another possible difference
# Teacher Response: oh sorry ... which colour is e.g . unskilled manual work do you think ?
# -----------------------

# %%
student_utterances = []
teacher_responses = []

with jsonlines.open('train_with-reference.jsonl') as reader:
    for obj in reader:
        # Extract the student utterances and teacher response from the conversation object
        utt_texts = [utt['text'] for utt in obj['utterances']]
        teacher_resp_text = obj['response']['text']
        
        # Append them to their respective lists
        student_utterances.extend(utt_texts)
        teacher_responses.append(teacher_resp_text)

# %%
teacher_responses = []
student_utterances = []

with jsonlines.open('train_with-reference.jsonl') as reader:
    for obj in reader:
        # Extract the student utterances and teacher response from the conversation object
        utt_texts = [utt['text'] for utt in obj['utterances']]
        teacher_resp_text = obj['response']['text']
        
        # Append them to their respective lists
        student_utterances.extend(utt_texts)
        teacher_responses.append(teacher_resp_text)

print('Teacher Responses:')
print(teacher_responses)
print('\nStudent Utterances:')
print(student_utterances)
# Out:
# Teacher Responses:
# ['Ah yes good question - this is a bit ambiguous....', 'yes, so scientists did more and more marshmallow tests and followed the lives of the kids, and they did not get the same results as the original study', 'under control', 'Yes, well done!', 'are you there?', "do you know the word 'colloborate'?", 'so hold on....', 'No, he plays on his desktop', 'is common', "BUT...it doesn't really make sense I'm afraid!", 'the average pronunciation of my younger students is better than 10 years ago for example', "Yes exactly - whereas 'at' could be just outside or whatever", 'ok', 'Makes sense', 'Ok thanks so...Botb charts illustrate the different reactions to Ashdown museum before and after its renovation = good', 'Well done on all your hard work - stay positive and keep working hard!', 'I remember :)', 'HEy there - sorrry give me a minute - go to relight my fire...', 'Yeah I think the rationale is that: Stop key workers from having childcare commitments/prevent vulnerable grandparents from being exposed through providing childcare', 'No....', 'Yes sure....', 'ok thank god', 'To where?', 'obvious', 'Big beautiful snakes', 'How are you? And why is yoghurt on your mind this morning? :)', 'Good!', 'Ok so....could you try an intro for them please?!', ':) is it quite tame then?', 'so <STUDENT> do you have the pie charts in front of you?', "that's it!", "e.g. Doctors' pay is set to rise by more than 5%...", "smart' in the US and 'bright' in the UK", 'what else could be provocative?', "So another way of saying this could be: 'It is very _______ that you will get a double six.'?", 'OK amazing - any basic info on this population?!', 'As in NOT about change over time or France or any other fuel JUST those items OK?', 'Um...does it feel like Easter to you? is OK!', 'But at least after the rain we should have a heatwave', 'Oh sorry - in this context it means you passed to a high standard', "a doctor that performs operations', without 'does'", 'good...', 'Maybe at the beginning or end fir the graohs etc and just at the end fir the essay', 'OK thanks <STUDENT> ....so , in terms of language this is great......', 'computer games?', 'You could definitely include that somehow!', "No that's fine! That's great start...hold on a sec...", "as in 'your salary is below average'", 'Ah, I see, yes', "Yes, correct. 'I usually eat cake __ my birthday'", 'Thanks :)', 'Yes good!', 'My favourite is peanut butter and chocolate', 'Well ...actually they are fine!!', 'BUT what time do you go to sleep at night = the only possibility ( a specific time = at', "I'm with dog and cat and it's pretty warm near them", 'yeeess?', "most non-native won't use it they always say clever/intelligent etc", "Give it 30 years it'll be a paradies", 'If you imagine this info in a bar chart itmight be easier to see tbd relative diffetence and changes', 'Aha, thanks for this', 'With the present simple v, and past simple verbs we need  auxiliary verb do/did', 'Nothing against kids per se but....a lot of its crowd control!', 'This bit. Could you insert some articles, please?', 'Much better', 'Sounds like online learning is less stressful, but maybe not as challenging', 'Lovely, have a good day!', 'much more often I mean', 'remember?', 'No! this was your original! But you need to change it as you just suggested...', 'yes good!', "OK so no-one was badly hurt - that's the importnat thing", 'is it an actual white dog? or the name of a band / shop etc.?', "Don't think about a 'finish line'", 'yep well done', "OK I'm going to log out now but I'll log back on soon - please log out when you can....", "OK I'll catch up with you in the week - thanks a lot bye", 'do you see it?', 'OK nice - thanks! Exactly the same really...', 'Yes', "what's it closer to half/two thirds/three quarters?", 'Bye <STUDENT> :)', "Yes me too - that's OK don't worry about it - try my question on the your past tenses ok?", 'Ok, next one. A word for a competition, for example in chess', 'hold on - i;ve got Spanish interference..',  ...
#
# Student Utterances:
# ['A) pull through', 'OK great', 'Not sure about the meaning of the second one... Does that person mean that being the prime minister he had to survive??', 'willpower?)', 'Yes!', 'So, a bit of willpower, and kids will be super successful!', 'Do you think it worked?', 'yes', 'No! :))', 'why?', 'because human beings are way more complex than that', "You know how in science it's very important that the results of a study be replicated?", "yes, it's very important", "I see. I think it means 'don't make me start'", 'Yes actually - especially something like laughing or in the example i just sent?', 'sorry exactly i meant not actually', "yes, I understand. Similar to 'activate'", 'yes absolutely and in fact in the original example this would be a precise synonym  (less so for these recent examples but same idea)', 'ok', 'OK so one more: Although the situation in the uk is getting worse things are nuder control and panic has not yet set in', 'Wait a minute', 'Does 9.30 am on Tuesday sound good to you?', 'Let’s talk about it in the Skype, okay?', 'Ok', 'Squeak', 'Aha, yes', "The food that's left from yesterday?", 'But I know what does it mean now', 'Leftover', 'leftover food (leftover is an adjective here) or leftovers (plural noun)', 'Am I right?', 'Yes!', 'So 3 words', 'For example, I sometimes have leftovers for lunch', 'And a part of England?', 'Makes sense', 'like Yorkshire or Cambridgeshire', 'County', 'Oh wow, incredible!', 'There is special programme', 'Called stop mothion', 'Sounds like a lot of work, too, 1000 photos!', 'It took us about  3 hours', 'Very cool', "<STUDENT>, could you go back to this bit and insert some articles? 'Thank you for taking part in this study. Please go ahead and chat here, and remember that all conversations are recorded.", 'Oh no, what happened! Sorry', 'The programme went mad, please ignore it', 'sorry my internet become slowly just now.', 'Did you see the tiny change? (One letter!)', 'relationships/relations', "Yes ok fine ... 'relationships' is logical and often possible BUT 'relations' very common in this context (e.g. international relations )", "BUT with 's' at the end!", 'okey, thanks', "For example, I can have visitors in my house - just people who've come to see me to talk about something but they're not tourists!", 'Ahhh but can it be a way to use a different word in the essay?', 'For example, if I use visitors because it’s better, can I change this word ?', "It's not quite right I'd say BUT it's OK BUT there are other ways you can change other parts of your answer more accurately do you see?", 'Ah, so you do have some experience of chatting in English!', "Which games do you play? My husband is really into video games, but I only play some Lego games with my son (he's nearly 5)", 'My favourite games are GTA5 and Fortnite', 'I see! My favourite is Lego superheroes. Beginner level, I know :)', "Does your husband play on Xbox, doesn't he?", 'Yes, I see how important is to keep listening and reading things in English', "Well, I'll continue", "yes it's the one thing really you can do", '21 medical', 'yes good', '22 admiration', 'fine', '23 enthusiasm', 'yes good', "no idea about 24 (is this sentence correct? is there a better way of saying that I don't know the answer??)", "Um you 'no idea about' is fine and common don't worry...apart from that...I haven't got a clue", "they do overlap in a way though it is true...ok sorry I'll stop and wait for you!", 'it is increasing argued that the most effective way to address the problem of discipline is responsibility. Although I strongly agree that responsibility plays a significant role, education system is more important.', 'OK thanks <STUDENT> ....so , in terms of language this is great......', 'I understand what you mean now', "It can be very frustrating if you don't do it fairly early on..", "I think it's our teachers fault (teachers here). They don't care too much about it, here grammar seems to be veryyy important", "Yes I'm sure you're right - I ...

# %%
test_data = []
with jsonlines.open('test_without-reference.jsonl') as reader:
    for obj in reader:
        # Extract the student utterances and blank spaces from the conversation object
        utt_texts = [utt['text'] for utt in obj['utterances']]
        blank_indices = [i for i, utt in enumerate(obj['utterances']) if utt['speaker'] == 'TEACHER' and utt['text'] == '']
        
        # Append the data to the test_data list
        test_data.append({'utterances': utt_texts, 'blank_indices': blank_indices})

# %%
# Load the trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Set the model to evaluation mode
model.eval()

# Generate teacher responses for each blank space in the test data
generated_responses = []
for convo in test_data:
    utt_texts = convo['utterances']
    blank_indices = convo['blank_indices']
    for i in blank_indices:
        # Concatenate the student utterances up to the blank space
        prompt = ' '.join(utt_texts[:i+1])
        
        # Generate the teacher response for the blank space
        generated_response = model.generate(
            input_ids=model.tokenizer.encode(prompt),
            max_length=50,
            do_sample=True,
            top_p=0.9,
            top_k=0,
            temperature=0.7,
            num_return_sequences=1,
        )[0]
        
        # Decode the generated response and append it to the list of generated responses
        generated_response = model.tokenizer.decode(generated_response, skip_special_tokens=True)
        generated_responses.append(generated_response)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import jsonlines

# Load the testing data
with jsonlines.open('test_without-reference.jsonl') as reader:
    test_data = [obj for obj in reader]

# Generate responses for blanks in the testing data
generated_responses = []
for obj in test_data:
    for utt in obj['utterances']:
        if utt['speaker'] == 'TEACHER' and utt['text'].strip() == '':
            generated_resp = generate_response(utt['context'], tokenizer, model)
            generated_responses.append(generated_resp)
            utt['text'] = generated_resp

# Save the updated testing data with generated responses
with jsonlines.open('test_with-generated-response.jsonl', mode='w') as writer:
    for obj in test_data:
        writer.write(obj)

# Print the generated responses
print('Generated Responses:')
for resp in generated_responses:
    print(resp)
# Out:
# Generated Responses:

# %%
import jsonlines
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# Load the trained model and tokenizer
model = TFGPT2LMHeadModel.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Load the testing dataset
with jsonlines.open('test_without-reference.jsonl') as reader:
    test_data = [obj for obj in reader]

# Generate responses for the blank spaces in the testing dataset
for obj in test_data:
    for utt in obj['utterances']:
        if utt['speaker'] == 'TEACHER' and utt['text'] == '':
            # Get the index of the blank in the teacher responses list
            blank_idx = obj['utterances'].index(utt)
            
            # Generate response for the blank using the previous student message
            student_msg = obj['utterances'][blank_idx-1]['text']
            input_ids = tokenizer.encode(student_msg, return_tensors='tf')
            gen_tokens = model.generate(input_ids, max_length=20, do_sample=True)
            gen_text = tokenizer.decode(gen_tokens[0], skip_special_tokens=True)
            
            # Replace the blank with the generated response
            obj['utterances'][blank_idx]['text'] = gen_text

# Save the updated testing dataset in a new JSONL file
with jsonlines.open('test_with-generated-responses.jsonl', mode='w') as writer:
    writer.write_all(test_data)

# Print the updated testing dataset
with jsonlines.open('test_with-generated-responses.jsonl') as reader:
    for obj in reader:
        print(obj)
# Out:
# Downloading tf_model.h5:   0%|          | 0.00/498M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# {'id': 'test_0001', 'utterances': [{'text': "Do you say them as 'extreme weather', right?", 'speaker': 'student'}, {'text': 'Absolutely yes the two words together: so, the three collocations for the consequences are; rising sea levels/melting ice caps and extreme weather - last category: what about the solutions?!', 'speaker': 'teacher'}, {'text': "It's reducing CO2 emissions. For example, using solar/wind energy instead of fossil fuels.", 'speaker': 'student'}]}
# {'id': 'test_0002', 'utterances': [{'text': 'But most importantly, there could have been other reasons behind children not eating / eating the marshmallow', 'speaker': 'teacher'}, {'text': 'For example, they might not have liked marshmallows!', 'speaker': 'teacher'}, {'text': 'Or they could have wanted to please the researchers', 'speaker': 'teacher'}, {'text': "Yes that's true", 'speaker': 'student'}, {'text': 'What do you think could have been the reasons?', 'speaker': 'teacher'}, {'text': 'Maybe some of them were too young?', 'speaker': 'student'}, {'text': 'Yes, exactly!', 'speaker': 'teacher'}]}
# {'id': 'test_0003', 'utterances': [{'text': 'my train leaving at 9:30', 'speaker': 'student'}, {'text': 'or - my train leaving time at 9:30.', 'speaker': 'student'}, {'text': "OK thanks...so you can describe your own plans with present continuous or 'going to' ...when we talk about courses/trains etc (things with timetables) we often use present simple...", 'speaker': 'teacher'}]}
# {'id': 'test_0004', 'utterances': [{'text': 'my time was shorter than yesterday.', 'speaker': 'student'}, {'text': 'So the adjective you can use with time (for running for example) is good/fast ok?', 'speaker': 'teacher'}, {'text': 'yes... so my time was faster than yesterday.', 'speaker': 'student'}, {'text': 'OK great! my time was faster/quicker/better than yesterday! good', 'speaker': 'teacher'}]}
# {'id': 'test_0005', 'utterances': [{'text': 'right?', 'speaker': 'student'}, {'text': 'yes,, thanks', 'speaker': 'student'}, {'text': "well <STUDENT> - we just usually use the verb 'be' with these adjectives", 'speaker': 'teacher'}, {'text': 'wow... I got it', 'speaker': 'student'}, {'text': "like e.g. rich/poor/old etc - not because it's a feeling", 'speaker': 'teacher'}, {'text': 'So in a way this bit is the easy bit (the verb I mean) - the thing you have to get right is the adjective itself and the preposition that comes next you see?', 'speaker': 'teacher'}]}
# {'id': 'test_0006', 'utterances': [{'text': 'Which is easy, because you can use my / his / your etc. and not think about articles!', 'speaker': 'teacher'}, {'text': 'Only 10 minutes left!', 'speaker': 'student'}, {'text': 'I know, we can finish early if you are getting cold?', 'speaker': 'teacher'}, {'text': "I'm really cold", 'speaker': 'student'}]}
# {'id': 'test_0007', 'utterances': [{'text': "That's great!", 'speaker': 'student'}, {'text': 'But of course my main job is to help trainees pass the course!!', 'speaker': 'teacher'}]}
# {'id': 'test_0008', 'utterances': [{'text': "I'm sure...", 'speaker': 'student'}, {'text': 'as in some will be in your passive knowledge but perhaps not used so much', 'speaker': 'teacher'}, {'text': 'in my experience with e.g. Italians/Spanish/French etc', 'speaker': 'teacher'}, {'text': 'for obvious reasons', 'speaker': 'teacher'}, {'text': "Can you give an example? I can't think of any", 'speaker': 'student'}, {'text': 'yes sure ..hold on...', 'speaker': 'teacher'}, {'text': 'so verbs first ...maybe a bit easier cos there are more perhaps', 'speaker': 'teacher'}]}
# {'id': 'test_0009', 'utterances': [{'text': "f you get a very high mark in e.g. a university degree you might receive a 'distinction' if you're familiar with that idea", 'speaker': 'teacher'}, {'text': "Thanks for your example with relieved -  try another adjective when you're ready", 'speaker': 'teacher'}, {'text': "That's interesting. Thank you for telling me the origin of the phrase.", 'speaker': 'student'}]}
# {'id': 'test_0010', 'utterances': [{'text': 'innocent??', 'speaker': 'student'}, {'text': "Right! and 'abrupt' = frank/direct", 'speaker': 'teacher'}, {'text': "If you're speak frankly/directly is it good?", 'speaker': 'teacher'}, {'text': 'I mean if you speak', 'speaker': 'teacher'}, {'text': "It depends on situations, but I think it's generally good.", 'speaker': 'student'}]}
# {'id': 'test_0011', 'utterances': [{'text': 'so..they play games to stop feeling depressed/lonely/bored.', 'speaker': 'student'}, {'text': "yes ok...E.g. I realized that smoking was bad when I read the news.'", 'speaker': 'teacher'}, {'text': "Try your sentence with 'realise' again if you can ok?", 'speaker': 'teacher'}, {'text': 'Adults can realise that playing in the game word, but children are not.', 'speaker': 'student'}]}
# {'id': 'test_0012', 'utterances': [{'text': 'yes, I will find a word', 'speaker': 'student'}, {'text': "relieve one's feelings", 'speaker': 'student'}, {'text': "OK good idea...so , you can 'relieve pain' for example...in more common language we can say e.g. they play games to stop feeling depressed", 'speaker': 'teacher'}, {'text': 'or lonely or bored etc', 'speaker': 'teacher'}, {'text': 'okey', 'speaker': 'student'}]}
# {'id': 'test_0013', 'utterances': [{'text': 'materialistic = the adjective you need here (good word)', 'speaker': 'teacher'}, {'text': 'yes... I think it is a strange idea...', 'speaker': 'student'}, {'text': 'Are there any arguments in favour of spending money on space exploration which might be easier to explain?', 'speaker': 'teacher'}, {'text': 'I think If I disagree with this idea is more easily to explain.', 'speaker': 'student'}]}
# {'id': 'test_0014', 'utterances': [{'text': 'IS this one new for you too?', 'speaker': 'teacher'}, {'text': 'I think so', 'speaker': 'student'}, {'text': "OK - well you've got to start somewhere! I think these two structures will help you get a better score", 'speaker': 'teacher'}, {'text': 'Both of them are new and wonderful for me.', 'speaker': 'student'}, {'text': 'thanks', 'speaker': 'student'}]}
# {'id': 'test_0015', 'utterances': [{'text': "BUT with 's' at the end!", 'speaker': 'teacher'}, {'text': 'okey, thanks', 'speaker': 'student'}, {'text': "do you know the word 'colloborate'?", 'speaker': 'teacher'}, {'text': 'no.. it looks like more advance', 'speaker': 'student'}, {'text': "Well - it's a nice word yes... Does it mean work together or work separately do you think?", 'speaker': 'teacher'}, {'text': 'I think it may means work together', 'speaker': 'student'}]}
# {'id': 'test_0016', 'utterances': [{'text': 'What about e.g. a ring that costs $1,000?', 'speaker': 'teacher'}, {'text': 'Good! Thank you', 'speaker': 'student'}, {'text': 'Shall we go back to yesterday mistakes?', 'speaker': 'student'}, {'text': 'yes sure!', 'speaker': 'teacher'}, {'text': 'a one thousand-dollar ring', 'speaker': 'student'}, {'text': 'yes good', 'speaker': 'teacher'}, {'text': 'there is police', 'speaker': 'student'}, {'text': "Shall I say 'there are police everywhere'?", 'speaker': 'student'}, {'text': 'yes!', 'speaker': 'teacher'}, {'text': 'why?? is it like people?', 'speaker': 'student'}, {'text': 'Hold on...', 'speaker': 'teacher'}, {'text': "So it's a bit difficult with groups/organisations sometimes...", 'speaker': 'teacher'}, {'text': 'so for example some can be either e.g. a football team can be Manchester UNited is/are it depends', 'speaker': 'teacher'}]}
# {'id': 'test_0017', 'utterances': [{'text': "Don't worry about it now but i just wanted to point that out ok?", 'speaker': 'teacher'}, {'text': 'yes...I think it maybe far away from question.', 'speaker': 'student'}, {'text': 'okey, thanks a lot', 'speaker': 'student'}, {'text': 'OK no probs - but it was a good way to practise language anyway...', 'speaker': 'teacher'}]}
# {'id': 'test_0018', 'utterances': [{'text': 'They said that it was my fault so I had to fix my car and pay for it. I learnt the lesson ;)', 'speaker': 'student'}, {'text': 'Oh no! I guess you can never tell what people are going to do...', 'speaker': 'teacher'}]}
# {'id': 'test_0019', 'utterances': [{'text': 'yes', 'speaker': 'student'}, {'text': "yes I remember now sorry - the master's!", 'speaker': 'teacher'}, {'text': 'no,,,I will study my first degree in the UK', 'speaker': 'student'}, {'text': "I just left from Japan's university and becoming a freshman in the UK", 'speaker': 'student'}, {'text': 'because I really want to study in LSE for my master, it is really difficult for me if I graduated from Japan.', 'speaker': 'student'}]}
# {'id': 'test_0020', 'utterances': [{'text': 'Hi there...', 'speaker': 'teacher'}, {'text': 'hi', 'speaker': 'student'}, {'text': 'Right <STUDENT> - Would you like to try beginning of a main paragraph for the essay question?', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'Choose an advantage of renting  and go for it!', 'speaker': 'teacher'}]}
# {'id': 'test_0021', 'utterances': [{'text': 'For example...pregnant women often go to hospital to give _____?', 'speaker': 'teacher'}, {'text': "beginning with 'b_ _ _ _ '!", 'speaker': 'teacher'}, {'text': 'begin', 'speaker': 'student'}, {'text': "Good try! 'birth' is the word here...", 'speaker': 'teacher'}, {'text': 'okey.', 'speaker': 'student'}]}
# {'id': 'test_0022', 'utterances': [{'text': 'Yes', 'speaker': 'student'}, {'text': "But poor kids didn't get much stuff, and when they saw the marshmallow, they just ate it", 'speaker': 'teacher'}, {'text': 'And then rich kids went to better schools and universitities / colleges and got into better jobs!', 'speaker': 'teacher'}, {'text': 'Not because they had better self-control, but because they could afford them', 'speaker': 'teacher'}]}
# {'id': 'test_0023', 'utterances': [{'text': 'yes', 'speaker': 'student'}, {'text': 'Sorry ...not exactly!', 'speaker': 'teacher'}, {'text': 'or have some grammar mistakes', 'speaker': 'student'}, {'text': "Yes that's right...What about the first chunk? What do you need to change?", 'speaker': 'teacher'}, {'text': 'most of young people?', 'speaker': 'teacher'}, {'text': 'most young people', 'speaker': 'student'}, {'text': 'Yes great wel ldone - like we said yesterday right?', 'speaker': 'teacher'}, {'text': "OK and the next chunk ....you need to change the noun 'benfit' to an adjective ..do you know it?", 'speaker': 'teacher'}]}
# {'id': 'test_0024', 'utterances': [{'text': '....', 'speaker': 'student'}, {'text': "after that it's better if I write information in general?", 'speaker': 'student'}, {'text': 'Yes...', 'speaker': 'teacher'}, {'text': "like '...are more satisfied'", 'speaker': 'student'}, {'text': 'Yes for example', 'speaker': 'teacher'}, {'text': 'than the visitors in the years before', 'speaker': 'student'}, {'text': "Yes ok ...again , pretty good you've got the big idea clearly expressed", 'speaker': 'teacher'}, {'text': 'thanks', 'speaker': 'student'}, {'text': 'A couple of small things...', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': "Dont say ' we can conclude'- just say it!", 'speaker': 'teacher'}, {'text': 'Use past simple...', 'speaker': 'teacher'}, {'text': "I.e. 'were' more satisfied", 'speaker': 'teacher'}]}
# {'id': 'test_0025', 'utterances': [{'text': "I mean the 'way' can not use here to explain something from partens", 'speaker': 'student'}, {'text': 'Oh i see sorry - yes I guess you;re right! you inherit an ability/talent etc = the collocation!', 'speaker': 'teacher'}]}
# {'id': 'test_0026', 'utterances': [{'text': 'against??', 'speaker': 'student'}, {'text': 'no try again!', 'speaker': 'teacher'}, {'text': 'for??', 'speaker': 'student'}, {'text': 'for??', 'speaker': 'student'}, {'text': "Yes that's it!", 'speaker': 'teacher'}, {'text': "I didn't know that.", 'speaker': 'student'}, {'text': "OK so your sentience is possible/good  -can you try another sentence with the word 'beat' for the same score", 'speaker': 'teacher'}, {'text': 'Barcelona was beaten by Liverpool 1-0.', 'speaker': 'student'}]}
# {'id': 'test_0027', 'utterances': [{'text': 'I mean', 'speaker': 'student'}, {'text': 'If the teacher teach a good things to students', 'speaker': 'student'}, {'text': 'These student’ll be an effective person', 'speaker': 'student'}]}
# {'id': 'test_0028', 'utterances': [{'text': "I need a lo of preparation. At the moment I'm taking lessons (1 hour a week, I can't afford more) and I have some books... I should spend more time studying however after the course I'm too tired.", 'speaker': 'student'}, {'text': "I see what you mean. That's very good!", 'speaker': 'student'}]}
# {'id': 'test_0029', 'utterances': [{'text': 'haha yes, sadly people say that phenomenon always occurs so harry up, show her as much cool things as you can now!!', 'speaker': 'student'}, {'text': "Yes, I figure that anything you do is worth it - even if it doesn't seem like it at the time - so your nephew might like those things at some point!", 'speaker': 'teacher'}]}
# {'id': 'test_0030', 'utterances': [{'text': "hahah Yes, I'm sorry to tell you", 'speaker': 'student'}, {'text': 'But yours is unusual right?', 'speaker': 'teacher'}, {'text': "Not on the Canary Islands, it's originally from here so there are a lot of <STUDENT'S NAME> but not on (in?) the mainland.", 'speaker': 'student'}]}
# {'id': 'test_0031', 'utterances': [{'text': 'ha! yes great ecample!!!!!!!!', 'speaker': 'teacher'}, {'text': 'example', 'speaker': 'teacher'}, {'text': 'the same as in America in the north of the UK but less nasal!', 'speaker': 'teacher'}, {'text': "That's interesting.", 'speaker': 'student'}, {'text': 'Thank you for telling me a lot of things today.', 'speaker': 'student'}]}
# {'id': 'test_0032', 'utterances': [{'text': 'ok good', 'speaker': 'teacher'}, {'text': 'And one last test: what are your plans after this lesson?', 'speaker': 'teacher'}, {'text': 'I am going to revision all knowledge which I studied in the class', 'speaker': 'student'}, {'text': 'OK good answer - what a good student1', 'speaker': 'teacher'}, {'text': "OK so remember: 'going to' + infinitive (VERB right?) - so where's your verb?", 'speaker': 'teacher'}, {'text': "the verb is after  the 'going to'", 'speaker': 'student'}, {'text': 'I am going to review the knowledge which I study in this class.', 'speaker': 'student'}]}
# {'id': 'test_0033', 'utterances': [{'text': '?', 'speaker': 'teacher'}, {'text': 'social media', 'speaker': 'student'}, {'text': 'ok fine....one more?', 'speaker': 'teacher'}, {'text': 'and  education between parents and shools.', 'speaker': 'student'}, {'text': 'schools', 'speaker': 'student'}, {'text': "OK great - so you mean that schools and parents don't....??", 'speaker': 'teacher'}, {'text': "they don't have more sympathetic approaches to deal with it.", 'speaker': 'student'}, {'text': "OK ...is that a cause? I suppose it could be! At least it explains why it doesn't stop ....", 'speaker': 'teacher'}]}
# {'id': 'test_0034', 'utterances': [{'text': 'OK... I have a lot of things to study today!', 'speaker': 'student'}, {'text': 'We can stop there if you like! Give me  a second...(or continue with example if you prefer!', 'speaker': 'teacher'}, {'text': "Ah, of course it's OK! His story relieve me.", 'speaker': 'student'}]}
# {'id': 'test_0035', 'utterances': [{'text': 'thanks,, I really want to use the word which you were teaching me.', 'speaker': 'student'}, {'text': "Use an adjective beginning with 's' for the first gap and add a tiny little word for the second gap...can you do it?! It is often argued that the most effective way to lead a less ________  lifestyle is __ rent a house.", 'speaker': 'teacher'}, {'text': 'depress   and   that', 'speaker': 'student'}]}
# {'id': 'test_0036', 'utterances': [{'text': 'Hi <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Hi <TEACHER>!', 'speaker': 'student'}]}
# {'id': 'test_0037', 'utterances': [{'text': 'Could you try relief or excitement? I thin k this is useful...', 'speaker': 'teacher'}, {'text': 'The result of an exam was a relief for me.', 'speaker': 'student'}]}
# {'id': 'test_0038', 'utterances': [{'text': 'But all really common', 'speaker': 'teacher'}, {'text': "OK, thank you. I'll write them down", 'speaker': 'student'}, {'text': "OK ...you're happy with e.g. 'I got my car fixed' right - I'm sure you know it ....", 'speaker': 'teacher'}, {'text': 'So pull in means that you stop somewher??', 'speaker': 'student'}]}
# {'id': 'test_0039', 'utterances': [{'text': 'Hi there...', 'speaker': 'teacher'}, {'text': 'hey, I am here', 'speaker': 'student'}, {'text': "OK so,  let's have a think about this again <STUDENT> OK? Don't answer yet but here is what we're going to do:  'I saw this when you_______(teach) us.'", 'speaker': 'teacher'}, {'text': 'So <STUDENT>....what action happened first? you seeing the table or me teaching you?', 'speaker': 'teacher'}, {'text': 'I seeing table firstly', 'speaker': 'student'}]}
# {'id': 'test_0040', 'utterances': [{'text': 'All right <STUDENT>?', 'speaker': 'teacher'}, {'text': 'I think exercise is plural', 'speaker': 'student'}, {'text': 'exercises', 'speaker': 'student'}, {'text': 'Well yes...they are both possible but they mean slightly different things! Which one means physical activity in general?', 'speaker': 'teacher'}, {'text': "So e.g. It's good to try to do regular __________?", 'speaker': 'teacher'}, {'text': "I think 'exercise' is means physical activity", 'speaker': 'student'}]}
# {'id': 'test_0041', 'utterances': [{'text': 'yes - it would be a very high frequency word in this area', 'speaker': 'teacher'}, {'text': '<STUDENT>, would you like to finish off page 128?', 'speaker': 'teacher'}, {'text': 'yes, please', 'speaker': 'student'}, {'text': "ok go for it when you're ready", 'speaker': 'teacher'}, {'text': 'we were looking at answer number 5', 'speaker': 'student'}, {'text': 'yes sure...', 'speaker': 'teacher'}, {'text': "the answer is b but I checked the meaning of 'lessened' and it seems very similar to shunk, isn't it?", 'speaker': 'student'}]}
# {'id': 'test_0042', 'utterances': [{'text': "yes, I'm ready!", 'speaker': 'student'}, {'text': 'Yes, you;re right ... it;s that too like if you;re hurt yourself/forget something for example (bit less rude than shit)', 'speaker': 'teacher'}, {'text': 'I see', 'speaker': 'student'}]}
# {'id': 'test_0043', 'utterances': [{'text': "Oh no, it's a mistake. I thought the verb was to tent, I`ll correct it thanks", 'speaker': 'student'}, {'text': "OK sure - She hit me with her elbow the other day and it really hurt even though she's only 9", 'speaker': 'teacher'}, {'text': 'haha did she hit you by accident??', 'speaker': 'student'}]}
# {'id': 'test_0044', 'utterances': [{'text': "and 'they' you see", 'speaker': 'teacher'}, {'text': 'Ah, because they are a team, right??', 'speaker': 'student'}]}
# {'id': 'test_0045', 'utterances': [{'text': 'unsatisfactory', 'speaker': 'student'}, {'text': "unsuit_ _ _ _ '??", 'speaker': 'teacher'}, {'text': 'unsuitable?', 'speaker': 'student'}, {'text': 'yes good!', 'speaker': 'teacher'}, {'text': "And ...'inapprop_ _ _ _ _ '??", 'speaker': 'teacher'}, {'text': 'and...inapprppriate', 'speaker': 'student'}, {'text': 'yes great...so either of these words would be good to use here OK?', 'speaker': 'teacher'}]}
# {'id': 'test_0046', 'utterances': [{'text': "sorry i'm back!", 'speaker': 'student'}, {'text': "It's because of CO2?", 'speaker': 'student'}, {'text': "Yes absolutely - what's happening with CO2?", 'speaker': 'teacher'}, {'text': 'CO2 emittion is going up because of consuming fossil fuels, and in addition, plants is decreasing that change CO2 to Os.', 'speaker': 'student'}, {'text': 'O2', 'speaker': 'student'}, {'text': "Sorry, plants 'are'", 'speaker': 'student'}]}
# {'id': 'test_0047', 'utterances': [{'text': 'Sorry, it was an unnecessary part!!', 'speaker': 'student'}, {'text': 'Ok no problem! Listen <STUDENT> can you tell me about any famous places (like buildings) you have visited in the UK - just one sentnce is enough', 'speaker': 'teacher'}, {'text': 'Brighton is one of the best resort place in Europe.', 'speaker': 'student'}]}
# {'id': 'test_0048', 'utterances': [{'text': "OK thanks <STUDENT> - let's try it together a bit more....hold on", 'speaker': 'teacher'}, {'text': 'yes thanks', 'speaker': 'student'}, {'text': "the '50%' refers to electricity right?", 'speaker': 'teacher'}, {'text': 'so....Australia used coal to produce....?', 'speaker': 'teacher'}, {'text': '50% of electricity', 'speaker': 'student'}, {'text': 'Yes good!', 'speaker': 'teacher'}, {'text': "So it's not a percentage of coal you see?", 'speaker': 'teacher'}, {'text': "it's a percentage of ELECTRICITY from different fuels", 'speaker': 'teacher'}, {'text': 'yes now I have understood', 'speaker': 'student'}]}
# {'id': 'test_0049', 'utterances': [{'text': 'a short word is missing!', 'speaker': 'teacher'}, {'text': 'Is in', 'speaker': 'student'}, {'text': "nope, you have 'is' already", 'speaker': 'teacher'}, {'text': 'Now?', 'speaker': 'student'}, {'text': 'like!', 'speaker': 'teacher'}, {'text': "What's the weather like?", 'speaker': 'teacher'}, {'text': 'Oh ok', 'speaker': 'student'}, {'text': "It's been raining since Tuesday!", 'speaker': 'teacher'}, {'text': "What's life like in your village?", 'speaker': 'teacher'}, {'text': "It's hard and interesting", 'speaker': 'student'}, {'text': "Good answer! I kind of want to know more, but it's time to let you go!", 'speaker': 'teacher'}]}
# {'id': 'test_0050', 'utterances': [{'text': '?', 'speaker': 'teacher'}, {'text': "not sure. I don't say it but I don't know if it is right", 'speaker': 'student'}, {'text': 'I search on the internet', 'speaker': 'student'}, {'text': "no that's good - just wanted to check - lots of non-natives use 'search' a lot now because of the internet of course  - it's fine for that but they use it too much for other things you see - look up and check = perfect", 'speaker': 'teacher'}, {'text': 'OK', 'speaker': 'student'}]}
# {'id': 'test_0051', 'utterances': [{'text': 'haha...you always give me a lot of tips.', 'speaker': 'student'}, {'text': 'ok', 'speaker': 'student'}]}
# {'id': 'test_0052', 'utterances': [{'text': '555555you know😂', 'speaker': 'student'}, {'text': 'So...! Before you said: 15 units of electricity was produced from nuclear power in France in 1980. (=good!) Now do a second part to link this with the situation in in 2000', 'speaker': 'teacher'}, {'text': 'OK?!', 'speaker': 'teacher'}, {'text': 'I mean another sentence...', 'speaker': 'teacher'}]}
# {'id': 'test_0053', 'utterances': [{'text': 'okey..I am confuse about it.', 'speaker': 'student'}, {'text': 'airport/university/station', 'speaker': 'student'}]}
# {'id': 'test_0054', 'utterances': [{'text': 'will', 'speaker': 'student'}, {'text': "ok good - for first conditional we usually use 'will'", 'speaker': 'teacher'}, {'text': 'okey, thanks', 'speaker': 'student'}, {'text': "One final one: 'In my view, scientists _________ discover a cure for most diseases .'", 'speaker': 'teacher'}, {'text': 'are going to', 'speaker': 'student'}, {'text': "Ok thanks - 'will' is also possible here - which one is best if you are making a general prediction (at some time in the future)", 'speaker': 'teacher'}]}
# {'id': 'test_0055', 'utterances': [{'text': 'Missing word?', 'speaker': 'teacher'}, {'text': 'yes.i studied the topic sentence  when you were teaching us on class.', 'speaker': 'student'}, {'text': 'a', 'speaker': 'student'}, {'text': 'OK thanks great..one more...: “…and even cheaper than _____ a normal one”. What kind of word do you need in the gap? Noun or verb?', 'speaker': 'teacher'}, {'text': 'buy', 'speaker': 'student'}, {'text': 'verb', 'speaker': 'student'}, {'text': "So for example: 'Water is cheaper than whisky.' Correct?", 'speaker': 'teacher'}]}
# {'id': 'test_0056', 'utterances': [{'text': "good idea ...reference would be 'Ref:'", 'speaker': 'teacher'}, {'text': 'okk', 'speaker': 'student'}, {'text': "sorry not 'of course' for the pronunciation exactly!", 'speaker': 'teacher'}, {'text': "it's arbitrary", 'speaker': 'teacher'}, {'text': 'unlike e.g and i.e.', 'speaker': 'teacher'}, {'text': 'Any other questions <STUDENT>?', 'speaker': 'teacher'}, {'text': 'No, thanks', 'speaker': 'student'}, {'text': 'We can continue with your plan :)', 'speaker': 'student'}]}
# {'id': 'test_0057', 'utterances': [{'text': 'but for example', 'speaker': 'student'}, {'text': "if I say 'we can see...' then I have to use the present simle", 'speaker': 'student'}, {'text': 'simple', 'speaker': 'student'}, {'text': '?', 'speaker': 'student'}, {'text': 'even if I used always the past in my essay', 'speaker': 'student'}]}
# {'id': 'test_0058', 'utterances': [{'text': '......is that human is not isolation in space.', 'speaker': 'student'}, {'text': 'I am sure..', 'speaker': 'student'}, {'text': 'not sure', 'speaker': 'student'}, {'text': "OK thanks ... 'isolation' = nice word.... you mean that there is life on other planets?", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'OK undestood! So can you change your sentence to show that this just a possibility?', 'speaker': 'teacher'}, {'text': 'human want to spend millions on search of aline life.', 'speaker': 'student'}]}
# {'id': 'test_0059', 'utterances': [{'text': 'Yes, I think so', 'speaker': 'student'}, {'text': "Sorry <STUDENT> , before i forget .... close brush WITH soemthing (often death!) whereas 'a close shave' basically comes after the dangerous thing (and bigger variety of things possible than with 'brush') has been mentioned...OK?!", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'e.g. we nearly crashed! yes, it was a close shave.', 'speaker': 'teacher'}, {'text': 'ok!', 'speaker': 'teacher'}, {'text': 'I see, thanks', 'speaker': 'student'}]}
# {'id': 'test_0060', 'utterances': [{'text': 'One more <STUDENT>: Sahara/Africa ...give me a sentence!', 'speaker': 'teacher'}, {'text': 'The Sahara is in Africa.', 'speaker': 'student'}, {'text': "Yes good - so we use 'the' with _____ and ______?", 'speaker': 'teacher'}, {'text': 'The Sahara is biggest in Africa.', 'speaker': 'student'}, {'text': 'with river and desert？', 'speaker': 'student'}, {'text': 'or with place and name.', 'speaker': 'student'}]}
# {'id': 'test_0061', 'utterances': [{'text': 'Hi <STUDENT>, is that you?!', 'speaker': 'teacher'}, {'text': 'Hi <TEACHER>', 'speaker': 'student'}, {'text': 'How are you?', 'speaker': 'student'}, {'text': "Yeah I'm good thanks - all OK with you?", 'speaker': 'teacher'}, {'text': "I'm fine, getting a cold though...", 'speaker': 'student'}]}
# {'id': 'test_0062', 'utterances': [{'text': 'I see', 'speaker': 'student'}, {'text': "(en español decimos 'practicar deporte')", 'speaker': 'student'}, {'text': "Yes I understand So e.g. If an English person says I practise football' do they mean i play football", 'speaker': 'teacher'}, {'text': '?', 'speaker': 'teacher'}, {'text': 'no, I think that means that you repeat something you want to improve?', 'speaker': 'student'}, {'text': 'something to do with football', 'speaker': 'student'}]}
# {'id': 'test_0063', 'utterances': [{'text': 'excite about / disappointed with', 'speaker': 'student'}, {'text': 'OK good thanks', 'speaker': 'teacher'}, {'text': 'thanks', 'speaker': 'student'}]}
# {'id': 'test_0064', 'utterances': [{'text': 'no.. I just could write very simple sentences before.', 'speaker': 'student'}, {'text': "OK well don't worry too much - the first two-sentence version was still good and you could still get a high score with that OK?", 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}, {'text': 'hanks', 'speaker': 'student'}, {'text': 'thanks', 'speaker': 'student'}]}
# {'id': 'test_0065', 'utterances': [{'text': "One of....it can make them more violent.' is good OR for example: .'....can lead to v______  beh_______'??", 'speaker': 'teacher'}, {'text': 'can lead to violent behaviours', 'speaker': 'student'}]}
# {'id': 'test_0066', 'utterances': [{'text': 'OK?!', 'speaker': 'teacher'}, {'text': "Yes, I mean so. Even though IELTS isn't a competiton...", 'speaker': 'student'}, {'text': "OK - you mean you still want to say 'win' - OK you can, you can - it's possible!", 'speaker': 'teacher'}, {'text': 'to really emphasis she though of it like a compettiion I guess!', 'speaker': 'teacher'}, {'text': 'thought', 'speaker': 'teacher'}]}
# {'id': 'test_0067', 'utterances': [{'text': 'and Scotland', 'speaker': 'student'}, {'text': 'yes sure', 'speaker': 'teacher'}, {'text': "So ...we normally say: 'Whisky....'?", 'speaker': 'teacher'}, {'text': "So START with 'whisky'", 'speaker': 'teacher'}, {'text': 'Whisky was made in Scotland.', 'speaker': 'student'}, {'text': 'ok good - only in the past or in general ?', 'speaker': 'teacher'}, {'text': 'In general we can say that whisky are made in Scotland.', 'speaker': 'student'}, {'text': "OK - thanks. Singular or plural? I mean is 'whisky' countable?", 'speaker': 'teacher'}, {'text': 'I am not sure...may uncountable.', 'speaker': 'student'}]}
# {'id': 'test_0068', 'utterances': [{'text': "I'll give you my own examples as you go along but don't stop OK?", 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}]}
# {'id': 'test_0069', 'utterances': [{'text': 'ok', 'speaker': 'student'}, {'text': "I just think it's good to think about main ideas which are easy to explain or give examples for....I know we might have different ideas about this but i feel that this idea is a bot more difficult to make successful in an essay - it's a bit vague/abstract do you see what i mean?", 'speaker': 'teacher'}]}
# {'id': 'test_0070', 'utterances': [{'text': 'with your snow example again i mean', 'speaker': 'teacher'}, {'text': 'It is highly likely that it will snow later', 'speaker': 'student'}, {'text': "ok great thanks (just because you originally wrote: 'that itsnows'", 'speaker': 'teacher'}, {'text': 'It is highly likely to get some snow later? Not sure', 'speaker': 'student'}, {'text': 'that it snows', 'speaker': 'teacher'}, {'text': 'I see, sorryy', 'speaker': 'student'}]}
# {'id': 'test_0071', 'utterances': [{'text': 'and its', 'speaker': 'teacher'}, {'text': 'for the class', 'speaker': 'teacher'}, {'text': 'okey - so I can say for the class, its continue until 04th of April. right?', 'speaker': 'student'}]}
# {'id': 'test_0072', 'utterances': [{'text': 'motivated to / proud of / scared of / disappointed to / happy with / annoy with / excited to', 'speaker': 'student'}, {'text': 'I think it is hard for me', 'speaker': 'student'}, {'text': "I don't know the rules of preposition.", 'speaker': 'student'}]}
# {'id': 'test_0073', 'utterances': [{'text': "Ha! Quite ironic ! I guess it's a little bit similar to me teaching English in some countries where there is high unemployment - sometimes I felt a bit guilty because ogten in reality better English didn't really make any difference to their job prospects!", 'speaker': 'teacher'}, {'text': "haha I know, it's very difficult to keep a language if you don't practise", 'speaker': 'student'}]}
# {'id': 'test_0074', 'utterances': [{'text': 'the host can enter each room when they like', 'speaker': 'teacher'}, {'text': 'I see, that would be great', 'speaker': 'student'}, {'text': "yes it's very effective (i was doing lessons on Zoom for a bit)", 'speaker': 'teacher'}, {'text': 'no, we all work at the same time so', 'speaker': 'student'}, {'text': "Well, I'm not sure about the use of 'I' or 'me' in sentences like", 'speaker': 'student'}]}
# {'id': 'test_0075', 'utterances': [{'text': 'and attempt to break regulations whatever in schools or at home, because they just want to copy the behaviours when they did in games.', 'speaker': 'student'}, {'text': 'they attempt ( I forgot the subject ).', 'speaker': 'student'}]}
# {'id': 'test_0076', 'utterances': [{'text': 'Choose a tense <STUDENT> to complete the question!', 'speaker': 'teacher'}, {'text': 'what are you doing?', 'speaker': 'student'}, {'text': 'what should I do?', 'speaker': 'student'}]}
# {'id': 'test_0077', 'utterances': [{'text': "Yes you're right ...count to ten and keep calm....", 'speaker': 'teacher'}, {'text': 'yes, I still remembering the easy of problem and solution.', 'speaker': 'student'}]}
# {'id': 'test_0078', 'utterances': [{'text': "average' would be a good word to use for your point as well", 'speaker': 'teacher'}, {'text': 'Do you mean balance satification and salary,', 'speaker': 'student'}, {'text': 'Ah I see', 'speaker': 'student'}, {'text': "as in 'your salary is below average'", 'speaker': 'teacher'}, {'text': "Next question: 'What skills are needed to get a good job nowadays?'", 'speaker': 'teacher'}, {'text': 'Nowadays I think', 'speaker': 'student'}, {'text': 'It’s need a lot of skiils', 'speaker': 'student'}, {'text': 'Comunucation', 'speaker': 'student'}, {'text': 'It or computer skill', 'speaker': 'student'}, {'text': 'And language also', 'speaker': 'student'}, {'text': 'THanks - good examples (communication,language and IT skills)', 'speaker': 'teacher'}]}
# {'id': 'test_0079', 'utterances': [{'text': "so in fact in this example we only have one thing - coal - so while is ok but whereas isn't ...OK?", 'speaker': 'teacher'}, {'text': 'Ok', 'speaker': 'student'}, {'text': 'but you could say : Coal was the most important source in 2000 while/whereas in France nuclear power (both fine because we have two things )', 'speaker': 'teacher'}]}
# {'id': 'test_0080', 'utterances': [{'text': 'OK so this is exactly what we need to practise <STUDENT>!!', 'speaker': 'teacher'}, {'text': "So remember we said yesterday that if you say the word 'recent' this goes together with which verb tense??", 'speaker': 'teacher'}, {'text': 'present continue', 'speaker': 'student'}, {'text': 'past continue', 'speaker': 'student'}]}
# {'id': 'test_0081', 'utterances': [{'text': "so...I think I can delete the 'effects'", 'speaker': 'student'}, {'text': 'Yes good!', 'speaker': 'teacher'}, {'text': "pros and cons' already includes that idea", 'speaker': 'teacher'}]}
# {'id': 'test_0082', 'utterances': [{'text': 'Hi <STUDENT>?', 'speaker': 'teacher'}, {'text': 'Hi', 'speaker': 'student'}, {'text': 'How are you?', 'speaker': 'student'}, {'text': "I'm good thanks - all OK with you?", 'speaker': 'teacher'}, {'text': "Yes, I'm very well too", 'speaker': 'student'}]}
# {'id': 'test_0083', 'utterances': [{'text': 'So you could say : oil and coal were both significant sources of electricity in 1980, contributing 20 and 25 units respectively but....', 'speaker': 'teacher'}, {'text': "yes that's better", 'speaker': 'student'}, {'text': 'By 2000 their relative contribtion had fallen to...', 'speaker': 'teacher'}, {'text': 'So.ething like this...ok?', 'speaker': 'teacher'}, {'text': 'yes thanks', 'speaker': 'student'}, {'text': "Bit more complex i know but i think you're  ready to make this jump!", 'speaker': 'teacher'}, {'text': 'Did you notice the verb tense in the second part?', 'speaker': 'teacher'}, {'text': 'passive', 'speaker': 'student'}]}
# {'id': 'test_0084', 'utterances': [{'text': 'In my class  there was a very posh Camila', 'speaker': 'student'}, {'text': 'Less traditional ones for boys that are popular now = e.g. Archie', 'speaker': 'teacher'}, {'text': 'And Isla (I like this one, very original) and Freya', 'speaker': 'student'}, {'text': "Most of them end in vowels and are a bit 'babyish' that's the fashion!", 'speaker': 'teacher'}, {'text': 'Yes Camilla = posh!', 'speaker': 'teacher'}]}
# {'id': 'test_0085', 'utterances': [{'text': 'So two action right? Which one started first? (the seeing or the walking?)', 'speaker': 'teacher'}, {'text': 'walking is the first action', 'speaker': 'student'}, {'text': 'OK good fine so...we have two tenses: the present simple and the present continuous OK?', 'speaker': 'teacher'}, {'text': 'and during he is walking, I saw him, after I seeing him, he still walking along the street.', 'speaker': 'student'}, {'text': "yes exactly good! So the seeing is 'inside' the walking!", 'speaker': 'teacher'}, {'text': 'yes,ok', 'speaker': 'student'}]}
# {'id': 'test_0086', 'utterances': [{'text': 'Yes nothing special - I just mean on e.g. youtube videos or newspaper websites (where they have comment sections after opinion pieces for example)', 'speaker': 'teacher'}, {'text': 'Ahh now I see what you mean', 'speaker': 'student'}]}
# {'id': 'test_0087', 'utterances': [{'text': 'no ,it not finished', 'speaker': 'student'}, {'text': 'so we use present simple', 'speaker': 'student'}, {'text': 'or present continue', 'speaker': 'student'}, {'text': 'OK good - so some time phrases AUTOMATICALLY need the past simple OR the present perfect OK? It depends on the phrase', 'speaker': 'teacher'}, {'text': 'okey, I understand.', 'speaker': 'student'}, {'text': 'So e.g. last year/last week/2018/ = ? (past simple or present perfect?)', 'speaker': 'teacher'}, {'text': 'present simple because it is specific time', 'speaker': 'student'}, {'text': 'OK fine (you mean past simple right?!)', 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'OK!', 'speaker': 'teacher'}]}
# {'id': 'test_0088', 'utterances': [{'text': 'like dress up?', 'speaker': 'student'}, {'text': "Yes, that's right, a verb + preposition that work together and mean something different from just the verb", 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': "Ok, all today's phrasal verbs have something to do with mobile phones! I bet you know a lot of them, let's see", 'speaker': 'teacher'}, {'text': 'We press the power button, to ___ the phone on / off', 'speaker': 'teacher'}, {'text': 'put', 'speaker': 'student'}, {'text': 'no, we switch the phone on / off', 'speaker': 'teacher'}]}
# {'id': 'test_0089', 'utterances': [{'text': 'okey - so just use present simple to describe the future in this sentence, right?', 'speaker': 'student'}, {'text': "Yes that's right!", 'speaker': 'teacher'}, {'text': 'I finish my course at the end of this week. - or My course finishing at the end of this week.', 'speaker': 'student'}]}
# {'id': 'test_0090', 'utterances': [{'text': 'My course is finishing at the end of this week.', 'speaker': 'student'}, {'text': "THat's it great", 'speaker': 'teacher'}, {'text': 'thanks - I realised my mistakes on English grammar.', 'speaker': 'student'}]}
# {'id': 'test_0091', 'utterances': [{'text': 'yes..', 'speaker': 'student'}, {'text': 'So for example......The Black Death happened in the 14th century when population was increasing.', 'speaker': 'teacher'}, {'text': 'So this is talking about the 14thcentury which ash definitely finished', 'speaker': 'teacher'}, {'text': 'But for our essay intro we want (imagine) to talk about recent time - from past and up to NOW', 'speaker': 'teacher'}, {'text': 'which tense??', 'speaker': 'teacher'}, {'text': 'present perfect?', 'speaker': 'student'}, {'text': 'YEs!', 'speaker': 'teacher'}]}
# {'id': 'test_0092', 'utterances': [{'text': 'Morning <STUDENT>!', 'speaker': 'teacher'}, {'text': 'Good morning', 'speaker': 'student'}]}
# {'id': 'test_0093', 'utterances': [{'text': 'present continue', 'speaker': 'student'}, {'text': 'You have 1. a topic sentence 2. Explanation of topic sentence 3. Result and 4. Summary with a bit on the other side (very good!).', 'speaker': 'teacher'}, {'text': 'okey, thanks!!', 'speaker': 'student'}, {'text': "You've got some good 'chunks' of language...hold on!", 'speaker': 'teacher'}]}
# {'id': 'test_0094', 'utterances': [{'text': "Ah yes sorry - it's the name for the little bits of wood or whatever you use to start the fire at the beginning", 'speaker': 'teacher'}, {'text': "Here 18 degrees now, during the day it's very sunny", 'speaker': 'student'}, {'text': "NIce....yes it's actually really sunny this week here too - and maybe....13 degrees!", 'speaker': 'teacher'}, {'text': 'Not too bad 13!!', 'speaker': 'student'}, {'text': "yes! Actually my boat gets warm in the sun so it doesn't really matter about the outside temperatrue...", 'speaker': 'teacher'}]}
# {'id': 'test_0095', 'utterances': [{'text': 'ok, it is better than my sentence.', 'speaker': 'student'}, {'text': 'Well yes I guess so! BUT we can take one more step if we like....Look at the one coming up...can you see I have deleted the full stop and the verb - you just need to change the form of the verb ..can you try it?Coal was by far the most significant fuel, _________  130 out of 170 units', 'speaker': 'teacher'}]}
# {'id': 'test_0096', 'utterances': [{'text': 'yeah', 'speaker': 'student'}, {'text': "Ok, let's keep going", 'speaker': 'teacher'}, {'text': 'Our trip to the park depends __ the weather', 'speaker': 'teacher'}, {'text': 'on', 'speaker': 'student'}, {'text': 'yes, good!', 'speaker': 'teacher'}, {'text': "She makes her own decisions.  She's quite independent ___ her friends' opinions", 'speaker': 'teacher'}, {'text': 'on', 'speaker': 'student'}, {'text': "No, that's the tricky one. Depend on (verb), dependent on (adjective), but independent from", 'speaker': 'teacher'}, {'text': 'ok', 'speaker': 'student'}, {'text': 'For example, America became independent ___ the United Kingdom in the 18th century', 'speaker': 'teacher'}, {'text': 'from', 'speaker': 'student'}, {'text': 'yes, but', 'speaker': 'teacher'}]}
# {'id': 'test_0097', 'utterances': [{'text': 'methods = good yes', 'speaker': 'teacher'}, {'text': "months...because I use 'one if..'", 'speaker': 'student'}, {'text': 'one of', 'speaker': 'student'}, {'text': 'yes exactly - perfect', 'speaker': 'teacher'}, {'text': 'yes..', 'speaker': 'student'}, {'text': '<STUDENT> - I just wan to focus a bit more on verb tenses OK? Hold on...', 'speaker': 'teacher'}, {'text': 'If I wanted to type quickly, I also wrong on spelling.', 'speaker': 'student'}, {'text': 'yes..okey', 'speaker': 'student'}]}
# {'id': 'test_0098', 'utterances': [{'text': 'sorry I mean if you only say that exercise is the most importnatn thing', 'speaker': 'teacher'}, {'text': 'So for example...in your opinion is diet as important as exercise or less important ?', 'speaker': 'teacher'}, {'text': 'as important as exercise', 'speaker': 'student'}, {'text': "ah ok! So if this is your 'thesis' then you should say that in the intro...hold on...", 'speaker': 'teacher'}]}
# {'id': 'test_0099', 'utterances': [{'text': 'OK thanks <STUDENT> for all that  ... hold on asec', 'speaker': 'teacher'}, {'text': 'seemed like - I forgot to use past simple here.', 'speaker': 'student'}, {'text': 'yes OK got it!', 'speaker': 'teacher'}]}
# {'id': 'test_0100', 'utterances': [{'text': "I think it's great! I can see much more people exercising on the streets nowadays than a few years ago", 'speaker': 'student'}, {'text': 'Yes, you know one thing that I think about with running and Spain is that it  must be really hot for some of the year - as in too hot to run(?)', 'speaker': 'teacher'}]}
# {'id': 'test_0101', 'utterances': [{'text': 'But for example, the changes you made to your use of tenses last week was a big step', 'speaker': 'teacher'}, {'text': 'thanks for youencourage me', 'speaker': 'student'}, {'text': 'it might not feel that way but any English speaker reading/listening to your correct present perfect/past simple or going to/will examples would notice a big difference', 'speaker': 'teacher'}, {'text': 'OK fine!', 'speaker': 'teacher'}, {'text': 'thanks very much.', 'speaker': 'student'}]}
# {'id': 'test_0102', 'utterances': [{'text': 'I understand your correction. In Spanish we have both words (controvertido y provocativo) and I see that controversial is more appropriated', 'speaker': 'student'}, {'text': 'controversial', 'speaker': 'teacher'}]}
# {'id': 'test_0103', 'utterances': [{'text': 'Wow... you are really into running! Ely is so far from here.', 'speaker': 'student'}, {'text': "Oh right! I see what you mean...well it's better int he summer/warmer weather anyway because you can sit outside. If you run a lot you get used it and it doesn't seem hard? Unless you try to run faster of course - that's what starts making the difference", 'speaker': 'teacher'}, {'text': 'the ? was a mistake!', 'speaker': 'teacher'}]}
# {'id': 'test_0104', 'utterances': [{'text': "Yes, unfortunately it's true and I went back Japan two weeks ago because of this. I was so confused because she was really fine until that day.", 'speaker': 'student'}, {'text': "OK thanks I understand. I think maybe 'shocked' is better here.", 'speaker': 'teacher'}]}
# {'id': 'test_0105', 'utterances': [{'text': "some jobs which are couldn't be replaced", 'speaker': 'student'}, {'text': "Listen - I think we should practise the passive - we'll start more simply with it - it would be good if you could use it correctly!", 'speaker': 'teacher'}, {'text': 'ok, I will do more passive practice after class.', 'speaker': 'student'}]}
# {'id': 'test_0106', 'utterances': [{'text': 'was/were + __ing', 'speaker': 'student'}, {'text': "OK great so...'I__________ it when you ____  ______ us.'??", 'speaker': 'teacher'}, {'text': 'I saw it the when you were teaching us.', 'speaker': 'student'}, {'text': "OK fantastic - you've got it", 'speaker': 'teacher'}, {'text': 'yes!! thanks', 'speaker': 'student'}]}
# {'id': 'test_0107', 'utterances': [{'text': 'ok', 'speaker': 'student'}, {'text': "I'm finished = also OK but again, less common", 'speaker': 'teacher'}, {'text': "I thought that might be your next question- I was trying to be clever and pre-empt it (it's a common one!)", 'speaker': 'teacher'}, {'text': 'pre-empt??', 'speaker': 'student'}, {'text': 'predict', 'speaker': 'student'}]}
# {'id': 'test_0108', 'utterances': [{'text': 'I have always felt scared with spider even though there are no dangerous ones in the UK.', 'speaker': 'student'}, {'text': 'scared of', 'speaker': 'student'}, {'text': 'yes good correction', 'speaker': 'teacher'}, {'text': "can you change the verb 'feel' ?", 'speaker': 'teacher'}, {'text': 'the present = I am scared', 'speaker': 'teacher'}, {'text': 'and in this example?', 'speaker': 'teacher'}, {'text': 'I have always feel scared of spiders', 'speaker': 'student'}, {'text': 'I have always __________ scared of spiders.?', 'speaker': 'teacher'}, {'text': "Don't use 'feel'! What verb do you need?", 'speaker': 'teacher'}, {'text': 'A simple verb!', 'speaker': 'teacher'}]}
# {'id': 'test_0109', 'utterances': [{'text': 'ok', 'speaker': 'student'}, {'text': 'because the plans are not truth,  right?', 'speaker': 'student'}]}
# {'id': 'test_0110', 'utterances': [{'text': 'One final question <STUDENT>: do you think bullying is worse than in the past?', 'speaker': 'teacher'}, {'text': "no.. I don't think so, with time goes by, people who got a high education are more than before", 'speaker': 'student'}, {'text': 'as a result, they will become teachers and parents.', 'speaker': 'student'}, {'text': 'they have the more soften way to deal with this problem.', 'speaker': 'student'}]}
# ...
# {'id': 'test_0244', 'utterances': [{'text': "That's OK - important thing is it's NOT past simple", 'speaker': 'teacher'}, {'text': 'OK <STUDENT> - shall we try a completely new topic to just get going and forget about these problems', 'speaker': 'teacher'}, {'text': 'yes.. I am ready.', 'speaker': 'student'}]}
# {'id': 'test_0245', 'utterances': [{'text': 'it is good to try to do regular exercise', 'speaker': 'student'}, {'text': 'Yes both exercise and exercises means phyiscal activity (ah I see what you mean yes - exercises can be for school or whatever yes)', 'speaker': 'teacher'}, {'text': 'okay, I understand .', 'speaker': 'student'}]}
# {'id': 'test_0246', 'utterances': [{'text': 'so the answer is virtually?', 'speaker': 'student'}, {'text': 'yes!', 'speaker': 'teacher'}, {'text': 'ahhh', 'speaker': 'student'}, {'text': '6d', 'speaker': 'student'}, {'text': 'yep!', 'speaker': 'teacher'}, {'text': '77b', 'speaker': 'student'}, {'text': 'well done!', 'speaker': 'teacher'}, {'text': '8c', 'speaker': 'student'}, {'text': 'OK great  - a clear pass at CAE!', 'speaker': 'teacher'}, {'text': 'haha', 'speaker': 'student'}, {'text': 'The beginning was terrible!!', 'speaker': 'student'}, {'text': "Well I forgive you the 'ranks' one - but not the 'overlook'! :)", 'speaker': 'teacher'}, {'text': 'oh thank you!', 'speaker': 'student'}]}
# {'id': 'test_0247', 'utterances': [{'text': 'Number 3 talks about his physical appearance', 'speaker': 'student'}, {'text': 'ok!', 'speaker': 'teacher'}, {'text': 'Number 5 talks about a local problem', 'speaker': 'student'}, {'text': 'yep', 'speaker': 'teacher'}, {'text': 'the most sarcastic I think it is number 2?', 'speaker': 'student'}, {'text': 'YEs absolutely! Classic British example - i could have written that myself!', 'speaker': 'teacher'}, {'text': 'haha', 'speaker': 'student'}, {'text': 'nobody here seems to suport Boris heres', 'speaker': 'student'}, {'text': 'but maybe number 4?', 'speaker': 'student'}, {'text': "Yes i guess 'support' is not quite the right word!", 'speaker': 'teacher'}]}
# {'id': 'test_0248', 'utterances': [{'text': "No, I don't know 'rake it in'. It's the first time I see it... I think", 'speaker': 'student'}, {'text': 'accumulate says my dictionary', 'speaker': 'student'}]}
# {'id': 'test_0249', 'utterances': [{'text': "Do you mean it's good to use 'normal' words instead of 'academic' words?", 'speaker': 'teacher'}, {'text': 'yes', 'speaker': 'student'}, {'text': 'OK right sorry yes I understand ...hold on...', 'speaker': 'teacher'}, {'text': 'I think the important thing is that you achieve the right result using the language you know as accurately as possible', 'speaker': 'teacher'}, {'text': 'in other words the priority is to write an effective intro', 'speaker': 'teacher'}, {'text': "if you don't do that because ou make lots of mistakes trying to use 'difficult' words then no that's not great", 'speaker': 'teacher'}]}
# {'id': 'test_0250', 'utterances': [{'text': 'organised', 'speaker': 'student'}, {'text': 'The sun gets on my balcony only a few hours a day so I try to make sure I go out on time!', 'speaker': 'student'}]}
# {'id': 'test_0251', 'utterances': [{'text': "It's famous in Japan as a hometown of the Peter Rabbit.", 'speaker': 'student'}, {'text': "Yes, it's certainly very pretty - if you're lucky it's sunny (but cold) and clear - if not it just rains! Yes I get that about being famous in Japan - you see quite a few Japanese tourists there...", 'speaker': 'teacher'}, {'text': 'I hope you will have many sunny days there!', 'speaker': 'student'}]}
# {'id': 'test_0252', 'utterances': [{'text': "I believe so, because if you had a high salary but a job that you don't really enjoy, it would be difficult for you to be happy", 'speaker': 'student'}, {'text': "it's important to do a work that we can enjoy because it will be our main occupation during the day", 'speaker': 'student'}]}
# {'id': 'test_0253', 'utterances': [{'text': 'Do you?', 'speaker': 'student'}, {'text': "ok well....yes definitely! it's very common", 'speaker': 'teacher'}, {'text': 'including in normal speaking', 'speaker': 'teacher'}, {'text': "It sounds formal to me... but I see than I'm wrong", 'speaker': 'student'}, {'text': 'you know that you can something or someone for granted right?', 'speaker': 'teacher'}, {'text': 'take something or someone for granted', 'speaker': 'teacher'}, {'text': "I think I know... I can't think of an examlo", 'speaker': 'student'}, {'text': 'example', 'speaker': 'student'}, {'text': "I didn't know you could take someone for granted though", 'speaker': 'student'}]}
# {'id': 'test_0254', 'utterances': [{'text': 'qualities', 'speaker': 'student'}, {'text': 'characters', 'speaker': 'student'}, {'text': 'yes good ...or characteristics ...OK? Both are countable and mean particular features ...your CHARACTER or PERSONALITY = uncountable (at least for one person they are uncountable )', 'speaker': 'teacher'}, {'text': "So in other words a person's character or personality includes different specific qualities or characteristics (OK?)", 'speaker': 'teacher'}, {'text': 'not ok', 'speaker': 'student'}, {'text': 'Ha!', 'speaker': 'teacher'}, {'text': 'Hold on...', 'speaker': 'teacher'}, {'text': 'we can only write characteristics here', 'speaker': 'student'}, {'text': "No 'qualities' is OK too = the same thing", 'speaker': 'teacher'}, {'text': "Oh sorry yes you can't write character", 'speaker': 'teacher'}]}
# {'id': 'test_0255', 'utterances': [{'text': 'yes, i found my mistake', 'speaker': 'student'}, {'text': 'ok....', 'speaker': 'teacher'}, {'text': 'Yes sorry i see it -good!', 'speaker': 'teacher'}, {'text': 'thanks', 'speaker': 'student'}, {'text': 'Try to remember this OK? YOU make this mistake a lot!', 'speaker': 'teacher'}, {'text': 'yes, I need to check this point every time when I want to use present continuous.', 'speaker': 'student'}]}
# {'id': 'test_0256', 'utterances': [{'text': 'in your opinion?', 'speaker': 'teacher'}, {'text': "of course, I suppose it is the best way for people's health.", 'speaker': 'student'}, {'text': 'OK fine ....so if you agree then you can just say that e.g.: I strongly agree that ....?', 'speaker': 'teacher'}, {'text': 'ok, I strongly agree that doing exercise is the best way', 'speaker': 'student'}, {'text': 'Or sorry....at the most basic level you could just say: I strongly agree with this idea.', 'speaker': 'teacher'}]}
# {'id': 'test_0257', 'utterances': [{'text': 'New knowledge is always studied by me. when I had full motivation on it.', 'speaker': 'student'}, {'text': 'my parents were disappointed with my last IELTS score.', 'speaker': 'student'}, {'text': 'ok good', 'speaker': 'teacher'}, {'text': 'but bad sorry', 'speaker': 'teacher'}, {'text': "OK <STUDENT>: 'when I had full motivation on it.'  try this again BUT with the verb/adjective structure we're focusing on ok?", 'speaker': 'teacher'}]}
# {'id': 'test_0258', 'utterances': [{'text': 'switch', 'speaker': 'student'}, {'text': "beginning with'a' ...?", 'speaker': 'teacher'}, {'text': 'al...@?', 'speaker': 'teacher'}, {'text': 'alter', 'speaker': 'student'}, {'text': 'we lean it on class', 'speaker': 'student'}, {'text': "yes OK - that's good as a general synonym for change", 'speaker': 'teacher'}, {'text': 'and good here too', 'speaker': 'teacher'}, {'text': 'okey,', 'speaker': 'student'}, {'text': "switch ' is like one specific to another specific thing do you see ?", 'speaker': 'teacher'}, {'text': 'like from your left hand to your right hand for example', 'speaker': 'teacher'}]}
# {'id': 'test_0259', 'utterances': [{'text': 'yes, well done!', 'speaker': 'teacher'}, {'text': 'Ýåý', 'speaker': 'student'}, {'text': 'Has he been to the USA?', 'speaker': 'teacher'}, {'text': "I don't know ...", 'speaker': 'teacher'}, {'text': 'If  he has ever been to the USA', 'speaker': 'student'}, {'text': 'Perfect!', 'speaker': 'teacher'}, {'text': 'if or whether', 'speaker': 'teacher'}, {'text': "It's starting to make sense, right?", 'speaker': 'teacher'}, {'text': 'AHA', 'speaker': 'student'}, {'text': "It's called 'reported speech' but we use it way more often, with all kinds of 'I don't know' and 'I wonder'", 'speaker': 'teacher'}, {'text': "not just 'he said'", 'speaker': 'teacher'}, {'text': 'őķ', 'speaker': 'student'}]}
# {'id': 'test_0260', 'utterances': [{'text': 'it might means wealth I guess', 'speaker': 'student'}, {'text': 'Ah! property is just another word for e.g. buildings/houses/flats etc', 'speaker': 'teacher'}, {'text': 'and including houses and others', 'speaker': 'student'}, {'text': "Actually 'accommodation' would be good here too maybe right?", 'speaker': 'teacher'}, {'text': 'okey...thanks', 'speaker': 'student'}, {'text': 'AND your use of wealth is interesting', 'speaker': 'teacher'}, {'text': 'You could definitely include that somehow!', 'speaker': 'teacher'}, {'text': 'or similar words...wealth = adjective or noun?', 'speaker': 'teacher'}]}
# {'id': 'test_0261', 'utterances': [{'text': 'just one word!', 'speaker': 'teacher'}, {'text': 'You OK?! Bad internet connection?', 'speaker': 'teacher'}, {'text': 'yes, i am back', 'speaker': 'student'}, {'text': 'let me try', 'speaker': 'student'}, {'text': 'ok!', 'speaker': 'teacher'}, {'text': 'There are many museums in London. -', 'speaker': 'student'}, {'text': 'OK cool hold on', 'speaker': 'teacher'}, {'text': 'okey', 'speaker': 'student'}]}
# {'id': 'test_0262', 'utterances': [{'text': "sure ... well 'firmly' first e.g. opposed/committed = common with noun forms too", 'speaker': 'teacher'}, {'text': "By the way, I think the first question is wrong... Maybe 'which adj ca be used with highly?", 'speaker': 'student'}, {'text': "well both possible... 'with which' and in general prepositions first = formal or normal?", 'speaker': 'teacher'}, {'text': "Ahh thanks, I didn't sound good to me.", 'speaker': 'student'}]}
# {'id': 'test_0263', 'utterances': [{'text': 'I think I only know put on and off', 'speaker': 'student'}, {'text': 'Well these are good ones to know! Hold on a sec....(but you can continue if you like!)', 'speaker': 'teacher'}, {'text': 'tolerate/insult or kill!/delay/ suggest/install', 'speaker': 'teacher'}, {'text': "can you think of a phrsal verb with put for these meanings?!  (you can use the 'logic' of the preposition as a rough guide(!)", 'speaker': 'teacher'}, {'text': "No idea but I'll try", 'speaker': 'student'}]}
# {'id': 'test_0264', 'utterances': [{'text': 'ok', 'speaker': 'teacher'}, {'text': '1. to start something', 'speaker': 'student'}, {'text': '2. to stop someone to do something', 'speaker': 'student'}, {'text': '3. boring', 'speaker': 'student'}, {'text': '4. Opportunity to change', 'speaker': 'student'}, {'text': '5. to be honest', 'speaker': 'student'}, {'text': '6. to boast', 'speaker': 'student'}, {'text': '7. prepare for something', 'speaker': 'student'}, {'text': '8. something you are good at', 'speaker': 'student'}]}
# {'id': 'test_0265', 'utterances': [{'text': 'taking about the site, the sentences that are shown with the word are from texts??', 'speaker': 'student'}, {'text': 'Are all correct? I mean, the sentences...', 'speaker': 'student'}, {'text': "yes it's called a concordance - have you seen one before? It just has a massive database of spoken and written texts from different sources and searches them for you", 'speaker': 'teacher'}, {'text': "well, they're basically 'correct' yes - 'authentic' at least", 'speaker': 'teacher'}, {'text': "For me <STUDENT> it's like a dictionary but better you know", 'speaker': 'teacher'}]}
# {'id': 'test_0266', 'utterances': [{'text': 'brith', 'speaker': 'student'}, {'text': "ok yes 'birth'", 'speaker': 'teacher'}, {'text': "AND number 3: Beethoven;s talent was 'i _ _ _ _ ' ?", 'speaker': 'teacher'}, {'text': 'It means something he was born with!', 'speaker': 'teacher'}, {'text': 'innate', 'speaker': 'student'}, {'text': 'ok great! And e.g. patience/honesty/kindness/selfishness etc are ....?', 'speaker': 'teacher'}, {'text': 'character', 'speaker': 'student'}, {'text': "you need a COUNTABLE noun here ...so e.g. 'character' is not possible (at least in this context) - a person's character is made up of different _______?", 'speaker': 'teacher'}]}
# {'id': 'test_0267', 'utterances': [{'text': 'coal of electricity?', 'speaker': 'student'}, {'text': "I don't know", 'speaker': 'student'}, {'text': 'OK no problem hold on a sec', 'speaker': 'teacher'}, {'text': 'I ask me the same question when I wrote the sentence', 'speaker': 'student'}, {'text': 'well...If you begin with e.g. Australia....can you continue from here?', 'speaker': 'teacher'}, {'text': "you need a verb next obviously so 'Australia....'?", 'speaker': 'teacher'}, {'text': 'Australia use 50% of electricity....', 'speaker': 'student'}, {'text': "OK nearly...! Did Australia 'use' electricity? well obviously yes but what about coal?", 'speaker': 'teacher'}]}
# {'id': 'test_0268', 'utterances': [{'text': "So OK <STUDENT> yes - this is a good idea and the CATEGORY here is 'scientific' right?", 'speaker': 'teacher'}, {'text': 'As in increasing fundamental  scientific knowledge...', 'speaker': 'teacher'}, {'text': '366.0', 'speaker': 'student'}, {'text': 'like why is 365days a year but sometime is 366 days.', 'speaker': 'student'}, {'text': 'Yes understood!', 'speaker': 'teacher'}, {'text': 'yes!! basic knowledge', 'speaker': 'student'}]}
# {'id': 'test_0269', 'utterances': [{'text': 'Hey welcome back', 'speaker': 'teacher'}, {'text': 'yes, I am here', 'speaker': 'student'}]}
# {'id': 'test_0270', 'utterances': [{'text': 'Could you tell me another way of saying that they might be motivated to choose their profession by the high salary?', 'speaker': 'student'}, {'text': 'motivated by something is correct??', 'speaker': 'student'}, {'text': "Yes OK sure...so 'motivated to' is a good idea...I was going to suggest a couple of phrases for this...yes: motivated to (do something) and 'motivated by (+noun) = good hold on", 'speaker': 'teacher'}, {'text': "another good word here might be 'driven' OK?", 'speaker': 'teacher'}]}
# {'id': 'test_0271', 'utterances': [{'text': 'So e.g. newspapers exaggerate', 'speaker': 'teacher'}, {'text': 'ok, I am remembering those words', 'speaker': 'student'}, {'text': 'thanks', 'speaker': 'student'}]}
# {'id': 'test_0272', 'utterances': [{'text': 'I want to continue', 'speaker': 'student'}, {'text': 'I understand that you are super busy!', 'speaker': 'teacher'}, {'text': 'but this time', 'speaker': 'student'}, {'text': 'I usually finish at 3 am', 'speaker': 'student'}, {'text': 'okay', 'speaker': 'student'}, {'text': "let's talk about it later", 'speaker': 'student'}, {'text': 'Yes, have a think, ok?', 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': 'Oh, can we start a bit earlier on Tuesday, 9.45 am?', 'speaker': 'teacher'}, {'text': 'oh, what about the third lesson this week?', 'speaker': 'student'}, {'text': 'Ooh, thanks for reminding me!', 'speaker': 'teacher'}, {'text': 'Friday 10.30 am?', 'speaker': 'teacher'}, {'text': 'okay', 'speaker': 'student'}, {'text': 'Sure :)', 'speaker': 'teacher'}]}
# {'id': 'test_0273', 'utterances': [{'text': 'OK so <STUDENT>, thinking about the questions from yesterday about different jobs....so you were talking about football players and you said they have a very good salary ...hold on a sec', 'speaker': 'teacher'}, {'text': "haha I don't know much about football but players from Barcelona club or Real Madrid earn far too much money", 'speaker': 'student'}]}

# %%
import jsonlines

teacher_responses = []
student_utterances = []

with jsonlines.open('train_with-reference.jsonl') as reader:
    for obj in reader:
        # Extract the student utterances and teacher response from the conversation object
        utt_texts = [utt['text'] for utt in obj['utterances']]
        teacher_resp_text = obj['response']['text']
        
        # Append them to their respective lists
        student_utterances.extend(utt_texts)
        teacher_responses.append(teacher_resp_text)

# %%
import json
import pandas as pd

# %%
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()

# %%
json_list = [json.loads(line) for line in lines]

# %%
df = pd.DataFrame(json_list)

# %%
df.columns
# Out:
# Index(['id', 'utterances', 'response'], dtype='object')

# %%
df.head(10)
# Out:
#            id                                         utterances  \
# 0  train_0001  [{'text': 'A) pull through', 'speaker': 'stude...
# 1  train_0002  [{'text': 'willpower?)', 'speaker': 'student'}...
# 2  train_0003  [{'text': 'I see. I think it means 'don't make...
# 3  train_0004  [{'text': 'Wait a minute', 'speaker': 'student...
# 4  train_0005  [{'text': 'Oh wow, incredible!', 'speaker': 't...
# 5  train_0006  [{'text': 'sorry my internet become slowly jus...
# 6  train_0007  [{'text': 'For example, I can have visitors in...
# 7  train_0008  [{'text': 'Ah, so you do have some experience ...
# 8  train_0009  [{'text': 'Yes, I see how important is to keep...
# 9  train_0010  [{'text': 'they do overlap in a way though it ...
#
#                                             response
# 0  {'text': 'Ah yes good question - this is a bit...
# 1  {'text': 'yes, so scientists did more and more...
# 2    {'text': 'under control', 'speaker': 'teacher'}
# 3  {'text': 'Yes, well done!', 'speaker': 'teacher'}
# 4   {'text': 'are you there?', 'speaker': 'teacher'}
# 5  {'text': 'do you know the word 'colloborate'?'...
# 6   {'text': 'so hold on....', 'speaker': 'teacher'}
# 7  {'text': 'No, he plays on his desktop', 'speak...
# 8        {'text': 'is common', 'speaker': 'teacher'}
# 9  {'text': 'BUT...it doesn't really make sense I...

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
import json
import pandas as pd

# Load training data
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = [json.loads(line) for line in lines]
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(utterances):
    teacher_utterances = [u for u in utterances if u['speaker'] == 'teacher']
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]['text']
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = [json.loads(line) for line in lines]
test_df = pd.DataFrame(test_data)

# Generate teacher responses for test data
test_df['teacher_response'] = test_df['utterances'].apply(generate_teacher_response)

# Save test data with teacher responses to file
with open('test_with-teacher-response.jsonl', 'w') as f:
    for line in test_df.to_json(orient='records', lines=True):
        f.write(line + '\n')

# %%
import json
import pandas as pd

# Load training data
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = [json.loads(line) for line in lines]
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(utterances):
    teacher_utterances = [u for u in utterances if u['speaker'] == 'teacher']
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]['text']
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = [json.loads(line) for line in lines]
test_df = pd.DataFrame(test_data)

# Generate teacher responses for test data
test_df['teacher_response'] = test_df['utterances'].apply(generate_teacher_response)

# Save test data with teacher responses to file
with open('test_with-teacher-response.jsonl', 'w') as f:
    for line in test_df.to_json(orient='records', lines=True):
        f.write(line + '\n')

# Print the first 10 rows of the test data with teacher responses
print(test_df.head(10))
# Out:
#           id                                         utterances  \
# 0  test_0001  [{'text': 'Do you say them as 'extreme weather...
# 1  test_0002  [{'text': 'But most importantly, there could h...
# 2  test_0003  [{'text': 'my train leaving at 9:30', 'speaker...
# 3  test_0004  [{'text': 'my time was shorter than yesterday....
# 4  test_0005  [{'text': 'right?', 'speaker': 'student'}, {'t...
# 5  test_0006  [{'text': 'Which is easy, because you can use ...
# 6  test_0007  [{'text': 'That's great!', 'speaker': 'student...
# 7  test_0008  [{'text': 'I'm sure...', 'speaker': 'student'}...
# 8  test_0009  [{'text': 'f you get a very high mark in e.g. ...
# 9  test_0010  [{'text': 'innocent??', 'speaker': 'student'},...
#
#                                     teacher_response
# 0  ____ ____ ____ ____ ____ together: so, ____ __...
# 1                                      Yes, exactly!
# 2  OK thanks...so ____ ____ ____ ____ ____ ____ _...
# 3  OK great! my ____ ____ faster/quicker/better _...
# 4  So in a ____ ____ ____ is ____ ____ ____ (the ...
# 5  I know, we ____ ____ ____ if ____ ____ ____ cold?
# 6  ____ of ____ my ____ ____ is to ____ ____ ____...
# 7  so ____ ____ ...maybe a ____ ____ ____ ____ __...
# 8  ____ ____ ____ ____ ____ ____ - ____ ____ ____...
# 9                                I ____ if ____ ____

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    test_data.append({'id': data['id'], 'utterances': data['utterances'], 'teacher_response': generate_teacher_response([u['text'] for u in data['utterances'] if u['speaker'] == 'teacher'])})
test_df = pd.DataFrame(test_data)

# Save test data with teacher responses to file
with open('test_with-teacher-response.jsonl', 'w') as f:
    for line in test_df.to_json(orient='records', lines=True):
        f.write(line + '\n')

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    test_data.append({'id': data['id'], 'utterances': data['utterances'], 'teacher_response': generate_teacher_response([u['text'] for u in data['utterances'] if u['speaker'] == 'teacher'])})
test_df = pd.DataFrame(test_data)

# Save test data with teacher responses to file
with open('test_with-teacher-resp.jsonl', 'w') as f:
    f.write(test_df.to_json(orient='records'))

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance and split it into words
        teacher_utterance = teacher_utterances[-1].split()
        # Replace the last word with a blank
        teacher_utterance[-1] = '____'
        return ' '.join(teacher_utterance)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    test_data.append({'id': data['id'], 'utterances': data['utterances'], 'teacher_response': generate_teacher_response([u['text'] for u in data['utterances'] if u['speaker'] == 'teacher'])})
test_df = pd.DataFrame(test_data)

# Save test data with teacher responses to file
with open('test_with-teacher-respon.jsonl', 'w') as f:
    for line in test_df.to_json(orient='records', lines=True):
        f.write(line + '\n')

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    teacher_response = generate_teacher_response([u['text'] for u in data['utterances'] if u['speaker'] == 'teacher'])
    test_data.append({'id': data['id'], 'utterances': data['utterances'], 'teacher_response': teacher_response})
test_df = pd.DataFrame(test_data)

# Save test data with teacher responses to file
with open('test_with-teacher-respons.jsonl', 'w') as f:
    for _, row in test_df.iterrows():
        data = {'id': row['id'], 'teacher_response': row['teacher_response']}
        utterances = [{'text': u['text'], 'speaker': u['speaker']} for u in row['utterances']]
        data['utterances'] = utterances
        f.write(json.dumps(data) + '\n')

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = [u['text'] for u in data['utterances'] if u['speaker'] == 'teacher']
    test_dialogue = ''
    for i, utterance in enumerate(data['utterances']):
        if i > 0:
            # Add newline character before each student utterance except the first one
            test_dialogue += '\n'
        test_dialogue += f"{utterance['speaker'].capitalize()}: {utterance['text']}"
    test_data.append({'id': data['id'], 'dialogue_context': test_dialogue, 'reference_response': generate_teacher_response(teacher_utterances)})
test_df = pd.DataFrame(test_data)

# Print dialogue context and reference response for each test instance
for i, row in test_df.iterrows():
    print(f"[ DIALOGUE CONTEXT ]\n{row['dialogue_context']}\n\n[ REFERENCE RESPONSE ]\nTeacher: {row['reference_response']}")
# Out:
# [ DIALOGUE CONTEXT ]
# Student: Do you say them as 'extreme weather', right?
# Teacher: Absolutely yes the two words together: so, the three collocations for the consequences are; rising sea levels/melting ice caps and extreme weather - last category: what about the solutions?!
# Student: It's reducing CO2 emissions. For example, using solar/wind energy instead of fossil fuels.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ together: so, ____ ____ ____ ____ ____ ____ are; ____ ____ levels/melting ____ ____ ____ ____ ____ - ____ category: ____ ____ ____ solutions?!
# [ DIALOGUE CONTEXT ]
# Teacher: But most importantly, there could have been other reasons behind children not eating / eating the marshmallow
# Teacher: For example, they might not have liked marshmallows!
# Teacher: Or they could have wanted to please the researchers
# Student: Yes that's true
# Teacher: What do you think could have been the reasons?
# Student: Maybe some of them were too young?
# Teacher: Yes, exactly!
#
# [ REFERENCE RESPONSE ]
# Teacher: Yes, exactly!
# [ DIALOGUE CONTEXT ]
# Student: my train leaving at 9:30
# Student: or - my train leaving time at 9:30.
# Teacher: OK thanks...so you can describe your own plans with present continuous or 'going to' ...when we talk about courses/trains etc (things with timetables) we often use present simple...
#
# [ REFERENCE RESPONSE ]
# Teacher: OK thanks...so ____ ____ ____ ____ ____ ____ ____ ____ ____ or 'going to' ...when we ____ ____ courses/trains ____ (things ____ timetables) we ____ ____ ____ simple...
# [ DIALOGUE CONTEXT ]
# Student: my time was shorter than yesterday.
# Teacher: So the adjective you can use with time (for running for example) is good/fast ok?
# Student: yes... so my time was faster than yesterday.
# Teacher: OK great! my time was faster/quicker/better than yesterday! good
#
# [ REFERENCE RESPONSE ]
# Teacher: OK great! my ____ ____ faster/quicker/better ____ yesterday! ____
# [ DIALOGUE CONTEXT ]
# Student: right?
# Student: yes,, thanks
# Teacher: well <STUDENT> - we just usually use the verb 'be' with these adjectives
# Student: wow... I got it
# Teacher: like e.g. rich/poor/old etc - not because it's a feeling
# Teacher: So in a way this bit is the easy bit (the verb I mean) - the thing you have to get right is the adjective itself and the preposition that comes next you see?
#
# [ REFERENCE RESPONSE ]
# Teacher: So in a ____ ____ ____ is ____ ____ ____ (the ____ I mean) - ____ ____ ____ ____ to ____ ____ is ____ ____ ____ ____ ____ ____ ____ ____ ____ ____ see?
# [ DIALOGUE CONTEXT ]
# Teacher: Which is easy, because you can use my / his / your etc. and not think about articles!
# Student: Only 10 minutes left!
# Teacher: I know, we can finish early if you are getting cold?
# Student: I'm really cold
#
# [ REFERENCE RESPONSE ]
# Teacher: I know, we ____ ____ ____ if ____ ____ ____ cold?
# [ DIALOGUE CONTEXT ]
# Student: That's great!
# Teacher: But of course my main job is to help trainees pass the course!!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ of ____ my ____ ____ is to ____ ____ ____ ____ course!!
# [ DIALOGUE CONTEXT ]
# Student: I'm sure...
# Teacher: as in some will be in your passive knowledge but perhaps not used so much
# Teacher: in my experience with e.g. Italians/Spanish/French etc
# Teacher: for obvious reasons
# Student: Can you give an example? I can't think of any
# Teacher: yes sure ..hold on...
# Teacher: so verbs first ...maybe a bit easier cos there are more perhaps
#
# [ REFERENCE RESPONSE ]
# Teacher: so ____ ____ ...maybe a ____ ____ ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: f you get a very high mark in e.g. a university degree you might receive a 'distinction' if you're familiar with that idea
# Teacher: Thanks for your example with relieved -  try another adjective when you're ready
# Student: That's interesting. Thank you for telling me the origin of the phrase.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ ____ - ____ ____ ____ ____ you're ____
# [ DIALOGUE CONTEXT ]
# Student: innocent??
# Teacher: Right! and 'abrupt' = frank/direct
# Teacher: If you're speak frankly/directly is it good?
# Teacher: I mean if you speak
# Student: It depends on situations, but I think it's generally good.
#
# [ REFERENCE RESPONSE ]
# Teacher: I ____ if ____ ____
# [ DIALOGUE CONTEXT ]
# Student: so..they play games to stop feeling depressed/lonely/bored.
# Teacher: yes ok...E.g. I realized that smoking was bad when I read the news.'
# Teacher: Try your sentence with 'realise' again if you can ok?
# Student: Adults can realise that playing in the game word, but children are not.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ 'realise' ____ if ____ ____ ok?
# [ DIALOGUE CONTEXT ]
# Student: yes, I will find a word
# Student: relieve one's feelings
# Teacher: OK good idea...so , you can 'relieve pain' for example...in more common language we can say e.g. they play games to stop feeling depressed
# Teacher: or lonely or bored etc
# Student: okey
#
# [ REFERENCE RESPONSE ]
# Teacher: or ____ or ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: materialistic = the adjective you need here (good word)
# Student: yes... I think it is a strange idea...
# Teacher: Are there any arguments in favour of spending money on space exploration which might be easier to explain?
# Student: I think If I disagree with this idea is more easily to explain.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ in ____ of ____ ____ on ____ ____ ____ ____ be ____ to explain?
# [ DIALOGUE CONTEXT ]
# Teacher: IS this one new for you too?
# Student: I think so
# Teacher: OK - well you've got to start somewhere! I think these two structures will help you get a better score
# Student: Both of them are new and wonderful for me.
# Student: thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: OK - ____ you've ____ to ____ somewhere! I ____ ____ ____ ____ ____ ____ ____ ____ a ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: BUT with 's' at the end!
# Student: okey, thanks
# Teacher: do you know the word 'colloborate'?
# Student: no.. it looks like more advance
# Teacher: Well - it's a nice word yes... Does it mean work together or work separately do you think?
# Student: I think it may means work together
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ - it's a ____ ____ yes... ____ it ____ ____ ____ or ____ ____ do ____ think?
# [ DIALOGUE CONTEXT ]
# Teacher: What about e.g. a ring that costs $1,000?
# Student: Good! Thank you
# Student: Shall we go back to yesterday mistakes?
# Teacher: yes sure!
# Student: a one thousand-dollar ring
# Teacher: yes good
# Student: there is police
# Student: Shall I say 'there are police everywhere'?
# Teacher: yes!
# Student: why?? is it like people?
# Teacher: Hold on...
# Teacher: So it's a bit difficult with groups/organisations sometimes...
# Teacher: so for example some can be either e.g. a football team can be Manchester UNited is/are it depends
#
# [ REFERENCE RESPONSE ]
# Teacher: so ____ ____ ____ ____ be ____ e.g. a ____ ____ ____ be ____ ____ is/are it ____
# [ DIALOGUE CONTEXT ]
# Teacher: Don't worry about it now but i just wanted to point that out ok?
# Student: yes...I think it maybe far away from question.
# Student: okey, thanks a lot
# Teacher: OK no probs - but it was a good way to practise language anyway...
#
# [ REFERENCE RESPONSE ]
# Teacher: OK no ____ - ____ it ____ a ____ ____ to ____ ____ anyway...
# [ DIALOGUE CONTEXT ]
# Student: They said that it was my fault so I had to fix my car and pay for it. I learnt the lesson ;)
# Teacher: Oh no! I guess you can never tell what people are going to do...
#
# [ REFERENCE RESPONSE ]
# Teacher: Oh no! I ____ ____ ____ ____ ____ ____ ____ ____ ____ to do...
# [ DIALOGUE CONTEXT ]
# Student: yes
# Teacher: yes I remember now sorry - the master's!
# Student: no,,,I will study my first degree in the UK
# Student: I just left from Japan's university and becoming a freshman in the UK
# Student: because I really want to study in LSE for my master, it is really difficult for me if I graduated from Japan.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ I ____ ____ ____ - ____ master's!
# [ DIALOGUE CONTEXT ]
# Teacher: Hi there...
# Student: hi
# Teacher: Right <STUDENT> - Would you like to try beginning of a main paragraph for the essay question?
# Student: yes
# Teacher: Choose an advantage of renting  and go for it!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ an ____ of ____ ____ go ____ it!
# [ DIALOGUE CONTEXT ]
# Teacher: For example...pregnant women often go to hospital to give _____?
# Teacher: beginning with 'b_ _ _ _ '!
# Student: begin
# Teacher: Good try! 'birth' is the word here...
# Student: okey.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ try! 'birth' is ____ ____ here...
# [ DIALOGUE CONTEXT ]
# Student: Yes
# Teacher: But poor kids didn't get much stuff, and when they saw the marshmallow, they just ate it
# Teacher: And then rich kids went to better schools and universitities / colleges and got into better jobs!
# Teacher: Not because they had better self-control, but because they could afford them
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ self-control, ____ ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: yes
# Teacher: Sorry ...not exactly!
# Student: or have some grammar mistakes
# Teacher: Yes that's right...What about the first chunk? What do you need to change?
# Teacher: most of young people?
# Student: most young people
# Teacher: Yes great wel ldone - like we said yesterday right?
# Teacher: OK and the next chunk ....you need to change the noun 'benfit' to an adjective ..do you know it?
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ ____ ____ ____ ....you ____ to ____ ____ ____ 'benfit' to an ____ ..do ____ ____ it?
# [ DIALOGUE CONTEXT ]
# Student: ....
# Student: after that it's better if I write information in general?
# Teacher: Yes...
# Student: like '...are more satisfied'
# Teacher: Yes for example
# Student: than the visitors in the years before
# Teacher: Yes ok ...again , pretty good you've got the big idea clearly expressed
# Student: thanks
# Teacher: A couple of small things...
# Student: yes
# Teacher: Dont say ' we can conclude'- just say it!
# Teacher: Use past simple...
# Teacher: I.e. 'were' more satisfied
#
# [ REFERENCE RESPONSE ]
# Teacher: I.e. 'were' ____ ____
# [ DIALOGUE CONTEXT ]
# Student: I mean the 'way' can not use here to explain something from partens
# Teacher: Oh i see sorry - yes I guess you;re right! you inherit an ability/talent etc = the collocation!
#
# [ REFERENCE RESPONSE ]
# Teacher: Oh i ____ ____ - ____ I ____ you;re right! ____ ____ an ability/talent ____ = ____ collocation!
# [ DIALOGUE CONTEXT ]
# Student: against??
# Teacher: no try again!
# Student: for??
# Student: for??
# Teacher: Yes that's it!
# Student: I didn't know that.
# Teacher: OK so your sentience is possible/good  -can you try another sentence with the word 'beat' for the same score
# Student: Barcelona was beaten by Liverpool 1-0.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK so ____ ____ is possible/good -can ____ ____ ____ ____ ____ ____ ____ 'beat' ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: I mean
# Student: If the teacher teach a good things to students
# Student: These student’ll be an effective person
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: I need a lo of preparation. At the moment I'm taking lessons (1 hour a week, I can't afford more) and I have some books... I should spend more time studying however after the course I'm too tired.
# Student: I see what you mean. That's very good!
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: haha yes, sadly people say that phenomenon always occurs so harry up, show her as much cool things as you can now!!
# Teacher: Yes, I figure that anything you do is worth it - even if it doesn't seem like it at the time - so your nephew might like those things at some point!
#
# [ REFERENCE RESPONSE ]
# Teacher: Yes, I ____ ____ ____ ____ do is ____ it - ____ if it doesn't ____ ____ it at ____ ____ - so ____ ____ ____ ____ ____ ____ at ____ point!
# [ DIALOGUE CONTEXT ]
# Student: hahah Yes, I'm sorry to tell you
# Teacher: But yours is unusual right?
# Student: Not on the Canary Islands, it's originally from here so there are a lot of <STUDENT'S NAME> but not on (in?) the mainland.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ is ____ right?
# [ DIALOGUE CONTEXT ]
# Teacher: ha! yes great ecample!!!!!!!!
# Teacher: example
# Teacher: the same as in America in the north of the UK but less nasal!
# Student: That's interesting.
# Student: Thank you for telling me a lot of things today.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ as in ____ in ____ ____ of ____ UK ____ ____ nasal!
# [ DIALOGUE CONTEXT ]
# Teacher: ok good
# Teacher: And one last test: what are your plans after this lesson?
# Student: I am going to revision all knowledge which I studied in the class
# Teacher: OK good answer - what a good student1
# Teacher: OK so remember: 'going to' + infinitive (VERB right?) - so where's your verb?
# Student: the verb is after  the 'going to'
# Student: I am going to review the knowledge which I study in this class.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK so remember: 'going to' + ____ (VERB right?) - so where's ____ verb?
# [ DIALOGUE CONTEXT ]
# Teacher: ?
# Student: social media
# Teacher: ok fine....one more?
# Student: and  education between parents and shools.
# Student: schools
# Teacher: OK great - so you mean that schools and parents don't....??
# Student: they don't have more sympathetic approaches to deal with it.
# Teacher: OK ...is that a cause? I suppose it could be! At least it explains why it doesn't stop ....
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ...is ____ a cause? I ____ it ____ be! At ____ it ____ ____ it doesn't ____ ....
# [ DIALOGUE CONTEXT ]
# Student: OK... I have a lot of things to study today!
# Teacher: We can stop there if you like! Give me  a second...(or continue with example if you prefer!
# Student: Ah, of course it's OK! His story relieve me.
#
# [ REFERENCE RESPONSE ]
# Teacher: We ____ ____ ____ if ____ like! ____ me a second...(or ____ ____ ____ if ____ prefer!
# [ DIALOGUE CONTEXT ]
# Student: thanks,, I really want to use the word which you were teaching me.
# Teacher: Use an adjective beginning with 's' for the first gap and add a tiny little word for the second gap...can you do it?! It is often argued that the most effective way to lead a less ________  lifestyle is __ rent a house.
# Student: depress   and   that
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ an ____ ____ ____ 's' ____ ____ ____ ____ ____ ____ a ____ ____ ____ ____ ____ ____ gap...can ____ do it?! It is ____ ____ ____ ____ ____ ____ ____ to ____ a ____ ________ ____ is __ ____ a house.
# [ DIALOGUE CONTEXT ]
# Teacher: Hi <STUDENT>!
# Student: Hi <TEACHER>!
#
# [ REFERENCE RESPONSE ]
# Teacher: Hi <STUDENT>!
# [ DIALOGUE CONTEXT ]
# Teacher: Could you try relief or excitement? I thin k this is useful...
# Student: The result of an exam was a relief for me.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ or excitement? I ____ k ____ is useful...
# [ DIALOGUE CONTEXT ]
# Teacher: But all really common
# Student: OK, thank you. I'll write them down
# Teacher: OK ...you're happy with e.g. 'I got my car fixed' right - I'm sure you know it ....
# Student: So pull in means that you stop somewher??
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ...you're ____ ____ e.g. 'I ____ my ____ fixed' ____ - I'm ____ ____ ____ it ....
# [ DIALOGUE CONTEXT ]
# Teacher: Hi there...
# Student: hey, I am here
# Teacher: OK so,  let's have a think about this again <STUDENT> OK? Don't answer yet but here is what we're going to do:  'I saw this when you_______(teach) us.'
# Teacher: So <STUDENT>....what action happened first? you seeing the table or me teaching you?
# Student: I seeing table firstly
#
# [ REFERENCE RESPONSE ]
# Teacher: So <STUDENT>....what ____ ____ first? ____ ____ ____ ____ or me ____ you?
# [ DIALOGUE CONTEXT ]
# Teacher: All right <STUDENT>?
# Student: I think exercise is plural
# Student: exercises
# Teacher: Well yes...they are both possible but they mean slightly different things! Which one means physical activity in general?
# Teacher: So e.g. It's good to try to do regular __________?
# Student: I think 'exercise' is means physical activity
#
# [ REFERENCE RESPONSE ]
# Teacher: So e.g. It's ____ to ____ to do ____ __________?
# [ DIALOGUE CONTEXT ]
# Teacher: yes - it would be a very high frequency word in this area
# Teacher: <STUDENT>, would you like to finish off page 128?
# Student: yes, please
# Teacher: ok go for it when you're ready
# Student: we were looking at answer number 5
# Teacher: yes sure...
# Student: the answer is b but I checked the meaning of 'lessened' and it seems very similar to shunk, isn't it?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ sure...
# [ DIALOGUE CONTEXT ]
# Student: yes, I'm ready!
# Teacher: Yes, you;re right ... it;s that too like if you;re hurt yourself/forget something for example (bit less rude than shit)
# Student: I see
#
# [ REFERENCE RESPONSE ]
# Teacher: Yes, you;re ____ ... it;s ____ ____ ____ if you;re ____ yourself/forget ____ ____ ____ (bit ____ ____ ____ shit)
# [ DIALOGUE CONTEXT ]
# Student: Oh no, it's a mistake. I thought the verb was to tent, I`ll correct it thanks
# Teacher: OK sure - She hit me with her elbow the other day and it really hurt even though she's only 9
# Student: haha did she hit you by accident??
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ - ____ ____ me ____ ____ ____ ____ ____ ____ ____ it ____ ____ ____ ____ she's ____ 9
# [ DIALOGUE CONTEXT ]
# Teacher: and 'they' you see
# Student: Ah, because they are a team, right??
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ 'they' ____ ____
# [ DIALOGUE CONTEXT ]
# Student: unsatisfactory
# Teacher: unsuit_ _ _ _ '??
# Student: unsuitable?
# Teacher: yes good!
# Teacher: And ...'inapprop_ _ _ _ _ '??
# Student: and...inapprppriate
# Teacher: yes great...so either of these words would be good to use here OK?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ great...so ____ of ____ ____ ____ be ____ to ____ ____ OK?
# [ DIALOGUE CONTEXT ]
# Student: sorry i'm back!
# Student: It's because of CO2?
# Teacher: Yes absolutely - what's happening with CO2?
# Student: CO2 emittion is going up because of consuming fossil fuels, and in addition, plants is decreasing that change CO2 to Os.
# Student: O2
# Student: Sorry, plants 'are'
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ - what's ____ ____ CO2?
# [ DIALOGUE CONTEXT ]
# Student: Sorry, it was an unnecessary part!!
# Teacher: Ok no problem! Listen <STUDENT> can you tell me about any famous places (like buildings) you have visited in the UK - just one sentnce is enough
# Student: Brighton is one of the best resort place in Europe.
#
# [ REFERENCE RESPONSE ]
# Teacher: Ok no problem! ____ <STUDENT> ____ ____ ____ me ____ ____ ____ ____ (like buildings) ____ ____ ____ in ____ UK - ____ ____ ____ is ____
# [ DIALOGUE CONTEXT ]
# Teacher: OK thanks <STUDENT> - let's try it together a bit more....hold on
# Student: yes thanks
# Teacher: the '50%' refers to electricity right?
# Teacher: so....Australia used coal to produce....?
# Student: 50% of electricity
# Teacher: Yes good!
# Teacher: So it's not a percentage of coal you see?
# Teacher: it's a percentage of ELECTRICITY from different fuels
# Student: yes now I have understood
#
# [ REFERENCE RESPONSE ]
# Teacher: it's a ____ of ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: a short word is missing!
# Student: Is in
# Teacher: nope, you have 'is' already
# Student: Now?
# Teacher: like!
# Teacher: What's the weather like?
# Student: Oh ok
# Teacher: It's been raining since Tuesday!
# Teacher: What's life like in your village?
# Student: It's hard and interesting
# Teacher: Good answer! I kind of want to know more, but it's time to let you go!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ answer! I ____ of ____ to ____ more, ____ it's ____ to ____ ____ go!
# [ DIALOGUE CONTEXT ]
# Teacher: ?
# Student: not sure. I don't say it but I don't know if it is right
# Student: I search on the internet
# Teacher: no that's good - just wanted to check - lots of non-natives use 'search' a lot now because of the internet of course  - it's fine for that but they use it too much for other things you see - look up and check = perfect
# Student: OK
#
# [ REFERENCE RESPONSE ]
# Teacher: no that's ____ - ____ ____ to ____ - ____ of non-natives ____ 'search' a ____ ____ ____ of ____ ____ of ____ - it's ____ ____ ____ ____ ____ ____ it ____ ____ ____ ____ ____ ____ ____ - ____ up ____ ____ = ____
# [ DIALOGUE CONTEXT ]
# Student: haha...you always give me a lot of tips.
# Student: ok
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: 555555you know😂
# Teacher: So...! Before you said: 15 units of electricity was produced from nuclear power in France in 1980. (=good!) Now do a second part to link this with the situation in in 2000
# Teacher: OK?!
# Teacher: I mean another sentence...
#
# [ REFERENCE RESPONSE ]
# Teacher: I ____ ____ sentence...
# [ DIALOGUE CONTEXT ]
# Student: okey..I am confuse about it.
# Student: airport/university/station
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: will
# Teacher: ok good - for first conditional we usually use 'will'
# Student: okey, thanks
# Teacher: One final one: 'In my view, scientists _________ discover a cure for most diseases .'
# Student: are going to
# Teacher: Ok thanks - 'will' is also possible here - which one is best if you are making a general prediction (at some time in the future)
#
# [ REFERENCE RESPONSE ]
# Teacher: Ok ____ - 'will' is ____ ____ ____ - ____ ____ is ____ if ____ ____ ____ a ____ ____ (at ____ ____ in ____ future)
# [ DIALOGUE CONTEXT ]
# Teacher: Missing word?
# Student: yes.i studied the topic sentence  when you were teaching us on class.
# Student: a
# Teacher: OK thanks great..one more...: “…and even cheaper than _____ a normal one”. What kind of word do you need in the gap? Noun or verb?
# Student: buy
# Student: verb
# Teacher: So for example: 'Water is cheaper than whisky.' Correct?
#
# [ REFERENCE RESPONSE ]
# Teacher: So ____ example: 'Water is ____ ____ whisky.' Correct?
# [ DIALOGUE CONTEXT ]
# Teacher: good idea ...reference would be 'Ref:'
# Student: okk
# Teacher: sorry not 'of course' for the pronunciation exactly!
# Teacher: it's arbitrary
# Teacher: unlike e.g and i.e.
# Teacher: Any other questions <STUDENT>?
# Student: No, thanks
# Student: We can continue with your plan :)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ <STUDENT>?
# [ DIALOGUE CONTEXT ]
# Student: but for example
# Student: if I say 'we can see...' then I have to use the present simle
# Student: simple
# Student: ?
# Student: even if I used always the past in my essay
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: ......is that human is not isolation in space.
# Student: I am sure..
# Student: not sure
# Teacher: OK thanks ... 'isolation' = nice word.... you mean that there is life on other planets?
# Student: yes
# Teacher: OK undestood! So can you change your sentence to show that this just a possibility?
# Student: human want to spend millions on search of aline life.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK undestood! So ____ ____ ____ ____ ____ to ____ ____ ____ ____ a possibility?
# [ DIALOGUE CONTEXT ]
# Student: Yes, I think so
# Teacher: Sorry <STUDENT> , before i forget .... close brush WITH soemthing (often death!) whereas 'a close shave' basically comes after the dangerous thing (and bigger variety of things possible than with 'brush') has been mentioned...OK?!
# Student: yes
# Teacher: e.g. we nearly crashed! yes, it was a close shave.
# Teacher: ok!
# Student: I see, thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: ok!
# [ DIALOGUE CONTEXT ]
# Teacher: One more <STUDENT>: Sahara/Africa ...give me a sentence!
# Student: The Sahara is in Africa.
# Teacher: Yes good - so we use 'the' with _____ and ______?
# Student: The Sahara is biggest in Africa.
# Student: with river and desert？
# Student: or with place and name.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ - so we ____ 'the' ____ _____ ____ ______?
# [ DIALOGUE CONTEXT ]
# Teacher: Hi <STUDENT>, is that you?!
# Student: Hi <TEACHER>
# Student: How are you?
# Teacher: Yeah I'm good thanks - all OK with you?
# Student: I'm fine, getting a cold though...
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ I'm ____ ____ - ____ OK ____ you?
# [ DIALOGUE CONTEXT ]
# Student: I see
# Student: (en español decimos 'practicar deporte')
# Teacher: Yes I understand So e.g. If an English person says I practise football' do they mean i play football
# Teacher: ?
# Student: no, I think that means that you repeat something you want to improve?
# Student: something to do with football
#
# [ REFERENCE RESPONSE ]
# Teacher: ?
# [ DIALOGUE CONTEXT ]
# Student: excite about / disappointed with
# Teacher: OK good thanks
# Student: thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ ____
# [ DIALOGUE CONTEXT ]
# Student: no.. I just could write very simple sentences before.
# Teacher: OK well don't worry too much - the first two-sentence version was still good and you could still get a high score with that OK?
# Student: ok
# Student: hanks
# Student: thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ don't ____ ____ ____ - ____ ____ two-sentence ____ ____ ____ ____ ____ ____ ____ ____ ____ a ____ ____ ____ ____ OK?
# [ DIALOGUE CONTEXT ]
# Teacher: One of....it can make them more violent.' is good OR for example: .'....can lead to v______  beh_______'??
# Student: can lead to violent behaviours
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ of....it ____ ____ ____ ____ violent.' is ____ OR ____ example: .'....can ____ to v______ beh_______'??
# [ DIALOGUE CONTEXT ]
# Teacher: OK?!
# Student: Yes, I mean so. Even though IELTS isn't a competiton...
# Teacher: OK - you mean you still want to say 'win' - OK you can, you can - it's possible!
# Teacher: to really emphasis she though of it like a compettiion I guess!
# Teacher: thought
#
# [ REFERENCE RESPONSE ]
# Teacher: ____
# [ DIALOGUE CONTEXT ]
# Student: and Scotland
# Teacher: yes sure
# Teacher: So ...we normally say: 'Whisky....'?
# Teacher: So START with 'whisky'
# Student: Whisky was made in Scotland.
# Teacher: ok good - only in the past or in general ?
# Student: In general we can say that whisky are made in Scotland.
# Teacher: OK - thanks. Singular or plural? I mean is 'whisky' countable?
# Student: I am not sure...may uncountable.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK - thanks. ____ or plural? I ____ is 'whisky' countable?
# [ DIALOGUE CONTEXT ]
# Teacher: I'll give you my own examples as you go along but don't stop OK?
# Student: ok
#
# [ REFERENCE RESPONSE ]
# Teacher: I'll ____ ____ my ____ ____ as ____ go ____ ____ don't ____ OK?
# [ DIALOGUE CONTEXT ]
# Student: ok
# Teacher: I just think it's good to think about main ideas which are easy to explain or give examples for....I know we might have different ideas about this but i feel that this idea is a bot more difficult to make successful in an essay - it's a bit vague/abstract do you see what i mean?
#
# [ REFERENCE RESPONSE ]
# Teacher: I ____ ____ it's ____ to ____ ____ ____ ____ ____ ____ ____ to ____ or ____ ____ for....I ____ we ____ ____ ____ ____ ____ ____ ____ i ____ ____ ____ ____ is a ____ ____ ____ to ____ ____ in an ____ - it's a ____ vague/abstract do ____ ____ ____ i mean?
# [ DIALOGUE CONTEXT ]
# Teacher: with your snow example again i mean
# Student: It is highly likely that it will snow later
# Teacher: ok great thanks (just because you originally wrote: 'that itsnows'
# Student: It is highly likely to get some snow later? Not sure
# Teacher: that it snows
# Student: I see, sorryy
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ it ____
# [ DIALOGUE CONTEXT ]
# Teacher: and its
# Teacher: for the class
# Student: okey - so I can say for the class, its continue until 04th of April. right?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: motivated to / proud of / scared of / disappointed to / happy with / annoy with / excited to
# Student: I think it is hard for me
# Student: I don't know the rules of preposition.
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Teacher: Ha! Quite ironic ! I guess it's a little bit similar to me teaching English in some countries where there is high unemployment - sometimes I felt a bit guilty because ogten in reality better English didn't really make any difference to their job prospects!
# Student: haha I know, it's very difficult to keep a language if you don't practise
#
# [ REFERENCE RESPONSE ]
# Teacher: Ha! ____ ____ ! I ____ it's a ____ ____ ____ to me ____ ____ in ____ ____ ____ ____ is ____ ____ - ____ I ____ a ____ ____ ____ ____ in ____ ____ ____ didn't ____ ____ ____ ____ to ____ ____ prospects!
# [ DIALOGUE CONTEXT ]
# Teacher: the host can enter each room when they like
# Student: I see, that would be great
# Teacher: yes it's very effective (i was doing lessons on Zoom for a bit)
# Student: no, we all work at the same time so
# Student: Well, I'm not sure about the use of 'I' or 'me' in sentences like
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ it's ____ ____ (i ____ ____ ____ on ____ ____ a bit)
# [ DIALOGUE CONTEXT ]
# Student: and attempt to break regulations whatever in schools or at home, because they just want to copy the behaviours when they did in games.
# Student: they attempt ( I forgot the subject ).
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Teacher: Choose a tense <STUDENT> to complete the question!
# Student: what are you doing?
# Student: what should I do?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ a ____ <STUDENT> to ____ ____ question!
# [ DIALOGUE CONTEXT ]
# Teacher: Yes you're right ...count to ten and keep calm....
# Student: yes, I still remembering the easy of problem and solution.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ you're ____ ...count to ____ ____ ____ calm....
# [ DIALOGUE CONTEXT ]
# Teacher: average' would be a good word to use for your point as well
# Student: Do you mean balance satification and salary,
# Student: Ah I see
# Teacher: as in 'your salary is below average'
# Teacher: Next question: 'What skills are needed to get a good job nowadays?'
# Student: Nowadays I think
# Student: It’s need a lot of skiils
# Student: Comunucation
# Student: It or computer skill
# Student: And language also
# Teacher: THanks - good examples (communication,language and IT skills)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ - ____ ____ (communication,language ____ IT skills)
# [ DIALOGUE CONTEXT ]
# Teacher: so in fact in this example we only have one thing - coal - so while is ok but whereas isn't ...OK?
# Student: Ok
# Teacher: but you could say : Coal was the most important source in 2000 while/whereas in France nuclear power (both fine because we have two things )
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ : ____ ____ ____ ____ ____ ____ in 2000 while/whereas in ____ ____ ____ (both ____ ____ we ____ ____ ____ )
# [ DIALOGUE CONTEXT ]
# Teacher: OK so this is exactly what we need to practise <STUDENT>!!
# Teacher: So remember we said yesterday that if you say the word 'recent' this goes together with which verb tense??
# Student: present continue
# Student: past continue
#
# [ REFERENCE RESPONSE ]
# Teacher: So ____ we ____ ____ ____ if ____ ____ ____ ____ 'recent' ____ ____ ____ ____ ____ ____ tense??
# [ DIALOGUE CONTEXT ]
# Student: so...I think I can delete the 'effects'
# Teacher: Yes good!
# Teacher: pros and cons' already includes that idea
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ cons' ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: Hi <STUDENT>?
# Student: Hi
# Student: How are you?
# Teacher: I'm good thanks - all OK with you?
# Student: Yes, I'm very well too
#
# [ REFERENCE RESPONSE ]
# Teacher: I'm ____ ____ - ____ OK ____ you?
# [ DIALOGUE CONTEXT ]
# Teacher: So you could say : oil and coal were both significant sources of electricity in 1980, contributing 20 and 25 units respectively but....
# Student: yes that's better
# Teacher: By 2000 their relative contribtion had fallen to...
# Teacher: So.ething like this...ok?
# Student: yes thanks
# Teacher: Bit more complex i know but i think you're  ready to make this jump!
# Teacher: Did you notice the verb tense in the second part?
# Student: passive
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ ____ in ____ ____ part?
# [ DIALOGUE CONTEXT ]
# Student: In my class  there was a very posh Camila
# Teacher: Less traditional ones for boys that are popular now = e.g. Archie
# Student: And Isla (I like this one, very original) and Freya
# Teacher: Most of them end in vowels and are a bit 'babyish' that's the fashion!
# Teacher: Yes Camilla = posh!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ = posh!
# [ DIALOGUE CONTEXT ]
# Teacher: So two action right? Which one started first? (the seeing or the walking?)
# Student: walking is the first action
# Teacher: OK good fine so...we have two tenses: the present simple and the present continuous OK?
# Student: and during he is walking, I saw him, after I seeing him, he still walking along the street.
# Teacher: yes exactly good! So the seeing is 'inside' the walking!
# Student: yes,ok
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ good! So ____ ____ is 'inside' ____ walking!
# [ DIALOGUE CONTEXT ]
# Teacher: Yes nothing special - I just mean on e.g. youtube videos or newspaper websites (where they have comment sections after opinion pieces for example)
# Student: Ahh now I see what you mean
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ - I ____ ____ on e.g. ____ ____ or ____ ____ (where ____ ____ ____ ____ ____ ____ ____ ____ example)
# [ DIALOGUE CONTEXT ]
# Student: no ,it not finished
# Student: so we use present simple
# Student: or present continue
# Teacher: OK good - so some time phrases AUTOMATICALLY need the past simple OR the present perfect OK? It depends on the phrase
# Student: okey, I understand.
# Teacher: So e.g. last year/last week/2018/ = ? (past simple or present perfect?)
# Student: present simple because it is specific time
# Teacher: OK fine (you mean past simple right?!)
# Student: yes
# Teacher: OK!
#
# [ REFERENCE RESPONSE ]
# Teacher: OK!
# [ DIALOGUE CONTEXT ]
# Student: like dress up?
# Teacher: Yes, that's right, a verb + preposition that work together and mean something different from just the verb
# Student: okay
# Teacher: Ok, all today's phrasal verbs have something to do with mobile phones! I bet you know a lot of them, let's see
# Teacher: We press the power button, to ___ the phone on / off
# Student: put
# Teacher: no, we switch the phone on / off
#
# [ REFERENCE RESPONSE ]
# Teacher: no, we ____ ____ ____ on / ____
# [ DIALOGUE CONTEXT ]
# Student: okey - so just use present simple to describe the future in this sentence, right?
# Teacher: Yes that's right!
# Student: I finish my course at the end of this week. - or My course finishing at the end of this week.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ that's right!
# [ DIALOGUE CONTEXT ]
# Student: My course is finishing at the end of this week.
# Teacher: THat's it great
# Student: thanks - I realised my mistakes on English grammar.
#
# [ REFERENCE RESPONSE ]
# Teacher: THat's it ____
# [ DIALOGUE CONTEXT ]
# Student: yes..
# Teacher: So for example......The Black Death happened in the 14th century when population was increasing.
# Teacher: So this is talking about the 14thcentury which ash definitely finished
# Teacher: But for our essay intro we want (imagine) to talk about recent time - from past and up to NOW
# Teacher: which tense??
# Student: present perfect?
# Teacher: YEs!
#
# [ REFERENCE RESPONSE ]
# Teacher: YEs!
# [ DIALOGUE CONTEXT ]
# Teacher: Morning <STUDENT>!
# Student: Good morning
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ <STUDENT>!
# [ DIALOGUE CONTEXT ]
# Student: present continue
# Teacher: You have 1. a topic sentence 2. Explanation of topic sentence 3. Result and 4. Summary with a bit on the other side (very good!).
# Student: okey, thanks!!
# Teacher: You've got some good 'chunks' of language...hold on!
#
# [ REFERENCE RESPONSE ]
# Teacher: You've ____ ____ ____ 'chunks' of language...hold on!
# [ DIALOGUE CONTEXT ]
# Teacher: Ah yes sorry - it's the name for the little bits of wood or whatever you use to start the fire at the beginning
# Student: Here 18 degrees now, during the day it's very sunny
# Teacher: NIce....yes it's actually really sunny this week here too - and maybe....13 degrees!
# Student: Not too bad 13!!
# Teacher: yes! Actually my boat gets warm in the sun so it doesn't really matter about the outside temperatrue...
#
# [ REFERENCE RESPONSE ]
# Teacher: yes! ____ my ____ ____ ____ in ____ ____ so it doesn't ____ ____ ____ ____ ____ temperatrue...
# [ DIALOGUE CONTEXT ]
# Student: ok, it is better than my sentence.
# Teacher: Well yes I guess so! BUT we can take one more step if we like....Look at the one coming up...can you see I have deleted the full stop and the verb - you just need to change the form of the verb ..can you try it?Coal was by far the most significant fuel, _________  130 out of 170 units
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ I ____ so! ____ we ____ ____ ____ ____ ____ if we like....Look at ____ ____ ____ up...can ____ ____ I ____ ____ ____ ____ ____ ____ ____ ____ - ____ ____ ____ to ____ ____ ____ of ____ ____ ..can ____ ____ it?Coal ____ by ____ ____ ____ ____ fuel, _________ 130 ____ of 170 ____
# [ DIALOGUE CONTEXT ]
# Student: yeah
# Teacher: Ok, let's keep going
# Teacher: Our trip to the park depends __ the weather
# Student: on
# Teacher: yes, good!
# Teacher: She makes her own decisions.  She's quite independent ___ her friends' opinions
# Student: on
# Teacher: No, that's the tricky one. Depend on (verb), dependent on (adjective), but independent from
# Student: ok
# Teacher: For example, America became independent ___ the United Kingdom in the 18th century
# Student: from
# Teacher: yes, but
#
# [ REFERENCE RESPONSE ]
# Teacher: yes, ____
# [ DIALOGUE CONTEXT ]
# Teacher: methods = good yes
# Student: months...because I use 'one if..'
# Student: one of
# Teacher: yes exactly - perfect
# Student: yes..
# Teacher: <STUDENT> - I just wan to focus a bit more on verb tenses OK? Hold on...
# Student: If I wanted to type quickly, I also wrong on spelling.
# Student: yes..okey
#
# [ REFERENCE RESPONSE ]
# Teacher: <STUDENT> - I ____ ____ to ____ a ____ ____ on ____ ____ OK? ____ on...
# [ DIALOGUE CONTEXT ]
# Teacher: sorry I mean if you only say that exercise is the most importnatn thing
# Teacher: So for example...in your opinion is diet as important as exercise or less important ?
# Student: as important as exercise
# Teacher: ah ok! So if this is your 'thesis' then you should say that in the intro...hold on...
#
# [ REFERENCE RESPONSE ]
# Teacher: ah ok! So if ____ is ____ 'thesis' ____ ____ ____ ____ ____ in ____ intro...hold on...
# [ DIALOGUE CONTEXT ]
# Teacher: OK thanks <STUDENT> for all that  ... hold on asec
# Student: seemed like - I forgot to use past simple here.
# Teacher: yes OK got it!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ OK ____ it!
# [ DIALOGUE CONTEXT ]
# Student: I think it's great! I can see much more people exercising on the streets nowadays than a few years ago
# Teacher: Yes, you know one thing that I think about with running and Spain is that it  must be really hot for some of the year - as in too hot to run(?)
#
# [ REFERENCE RESPONSE ]
# Teacher: Yes, ____ ____ ____ ____ ____ I ____ ____ ____ ____ ____ ____ is ____ it ____ be ____ ____ ____ ____ of ____ ____ - as in ____ ____ to run(?)
# [ DIALOGUE CONTEXT ]
# Teacher: But for example, the changes you made to your use of tenses last week was a big step
# Student: thanks for youencourage me
# Teacher: it might not feel that way but any English speaker reading/listening to your correct present perfect/past simple or going to/will examples would notice a big difference
# Teacher: OK fine!
# Student: thanks very much.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK fine!
# [ DIALOGUE CONTEXT ]
# Student: I understand your correction. In Spanish we have both words (controvertido y provocativo) and I see that controversial is more appropriated
# Teacher: controversial
#
# [ REFERENCE RESPONSE ]
# Teacher: ____
# [ DIALOGUE CONTEXT ]
# Student: Wow... you are really into running! Ely is so far from here.
# Teacher: Oh right! I see what you mean...well it's better int he summer/warmer weather anyway because you can sit outside. If you run a lot you get used it and it doesn't seem hard? Unless you try to run faster of course - that's what starts making the difference
# Teacher: the ? was a mistake!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ? ____ a mistake!
# [ DIALOGUE CONTEXT ]
# Student: Yes, unfortunately it's true and I went back Japan two weeks ago because of this. I was so confused because she was really fine until that day.
# Teacher: OK thanks I understand. I think maybe 'shocked' is better here.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ I understand. I ____ ____ 'shocked' is ____ here.
# [ DIALOGUE CONTEXT ]
# Student: some jobs which are couldn't be replaced
# Teacher: Listen - I think we should practise the passive - we'll start more simply with it - it would be good if you could use it correctly!
# Student: ok, I will do more passive practice after class.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ - I ____ we ____ ____ ____ ____ - we'll ____ ____ ____ ____ it - it ____ be ____ if ____ ____ ____ it correctly!
# [ DIALOGUE CONTEXT ]
# Student: was/were + __ing
# Teacher: OK great so...'I__________ it when you ____  ______ us.'??
# Student: I saw it the when you were teaching us.
# Teacher: OK fantastic - you've got it
# Student: yes!! thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ - you've ____ it
# [ DIALOGUE CONTEXT ]
# Student: ok
# Teacher: I'm finished = also OK but again, less common
# Teacher: I thought that might be your next question- I was trying to be clever and pre-empt it (it's a common one!)
# Student: pre-empt??
# Student: predict
#
# [ REFERENCE RESPONSE ]
# Teacher: I ____ ____ ____ be ____ ____ question- I ____ ____ to be ____ ____ pre-empt it (it's a ____ one!)
# [ DIALOGUE CONTEXT ]
# Student: I have always felt scared with spider even though there are no dangerous ones in the UK.
# Student: scared of
# Teacher: yes good correction
# Teacher: can you change the verb 'feel' ?
# Teacher: the present = I am scared
# Teacher: and in this example?
# Student: I have always feel scared of spiders
# Teacher: I have always __________ scared of spiders.?
# Teacher: Don't use 'feel'! What verb do you need?
# Teacher: A simple verb!
#
# [ REFERENCE RESPONSE ]
# Teacher: A ____ verb!
# [ DIALOGUE CONTEXT ]
# Student: ok
# Student: because the plans are not truth,  right?
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Teacher: One final question <STUDENT>: do you think bullying is worse than in the past?
# Student: no.. I don't think so, with time goes by, people who got a high education are more than before
# Student: as a result, they will become teachers and parents.
# Student: they have the more soften way to deal with this problem.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ <STUDENT>: do ____ ____ ____ is ____ ____ in ____ past?
# [ DIALOGUE CONTEXT ]
# Teacher: Hi there <STUDENT>...
# Student: Hi <TEACHER>
# Teacher: Everything OK?
# Student: How are you doing today?? less mad?
# Teacher: Um..yes I think so! I'll try and be a bit more upbeat today and avoid coming across like i;m off my head
# Teacher: Which of course I'm not
# Student: Good plan! Is it working?
# Teacher: Oooops - yes so far - I've had a strict timetable of sane productive activities
# Student: I think that works very well (having an structure I mean)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ - ____ so ____ - I've ____ a ____ ____ of ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: OK <STUDENT>? Use the keywords and say it correctly if you  can
# Student: okey, In good English I suppose - For me, I am going home by train and leaving at 9:30.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK <STUDENT>? ____ ____ ____ ____ ____ it ____ if ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: so for example the fact that coal generated such a big proportion of electricity means that coal was very...?
# Student: Important?
# Student: Important source
# Teacher: yes great! was important/was an important source
# Teacher: hold on ...
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ on ...
# [ DIALOGUE CONTEXT ]
# Student: in this intro, do we need the structure of ' it is argued that...'
# Student: we need the present continuous
# Teacher: Um....not really beacuse the lack of teachers would be given as a fact not an opinion or disagree with you see?
# Teacher: to agree or disagree with i mean
# Student: okey,i understand
#
# [ REFERENCE RESPONSE ]
# Teacher: to ____ or ____ ____ i ____
# [ DIALOGUE CONTEXT ]
# Student: important = necessary
# Teacher: ok great
# Teacher: more more!
# Student: problem = issus
# Teacher: fine
# Student: I think that all
# Teacher: yes that was good thanks
# Student: so.. just replace those words into question?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: they don't have enough money to buy.
# Teacher: Yes ok good
# Teacher: Or maybe: 'They can't ______ to live there.'?
# Student: they can not afraid to live there.
# Teacher: you mean 'afford' right?!
# Student: yes..afford
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ 'afford' right?!
# [ DIALOGUE CONTEXT ]
# Student: ok..I am not sure
# Teacher: No problem...well for me <STUDENT> changing round 2 and 3 seems a bit better
#
# [ REFERENCE RESPONSE ]
# Teacher: No problem...well ____ me <STUDENT> ____ ____ 2 ____ 3 ____ a ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: Some topic words and some nice general phrases
# Teacher: I;ll go over some other things to think about when we come back after the break....
# Student: okey, thanks- see you
# Teacher: Ah yes ok  i;ve just noticed: ' even though ' is correct ( notthrough!)
#
# [ REFERENCE RESPONSE ]
# Teacher: Ah ____ ok i;ve ____ noticed: ' ____ ____ ' is ____ ( notthrough!)
# [ DIALOGUE CONTEXT ]
# Student: it is a tower with parkour
# Teacher: I play Lego games with my son
# Student: and it is not easy
# Teacher: I see!
# Student: and I sometimes play brawl stars
# Teacher: oh, on your phone?
# Student: yes
# Teacher: Do you play Lego games?
# Student: no
# Teacher: <STUDENT>, quick revision. If your phone battery is low, you need to ___ ___ your phone (phrasal verb)
# Student: charge up
# Teacher: yes, good!
# Teacher: And to charge it up, you need to __ it ___
# Student: ...
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ to ____ it up, ____ ____ to __ it ___
# [ DIALOGUE CONTEXT ]
# Teacher: So do we use the past simple for BOTH actions?
# Student: no,,I think one of them is past perfect
# Teacher: Ah ok I see your idea...well past perfect is some that happened BEFORE something else -BUT this is different because the other thing happened before, DURING and AFTER OK?
# Student: yes
#
# [ REFERENCE RESPONSE ]
# Teacher: Ah ok I ____ ____ idea...well ____ ____ is ____ ____ ____ ____ ____ ____ -BUT ____ is ____ ____ ____ ____ ____ ____ before, ____ ____ ____ OK?
# [ DIALOGUE CONTEXT ]
# Teacher: *dropped it
# Student: Maybe
# Student: You might know that there is war in Ukraine
# Teacher: Of course I know that :(
# Teacher: But isn't the revolver from a long time ago, when your Grandma was young? That was the impression I got
# Student: Yes
# Teacher: Yes, sure. What were you going to say?
# Student: When?
# Teacher: Never mind :)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ :)
# [ DIALOGUE CONTEXT ]
# Teacher: It could also be 'He is jealous of his sister's success' or something like that
# Student: Ok
# Teacher: Ok :)
# Teacher: Could you give me a preposition, please? __ January
# Student: Now the lizard on the cat's fur
# Student: In
# Teacher: The lizard's on the cat?? Is the cat ok with it?
# Teacher: In - correct!
# Student: The cat is slepping now
# Teacher: Ha, interesting!
# Teacher: __ the morning
# Student: In
# Teacher: yes
# Teacher: ___ Wednesday morning
# Student: On
# Teacher: correct!
# Teacher: __ school
# Student: At
# Teacher: yes
# Teacher: __ August 5th
# Student: In
#
# [ REFERENCE RESPONSE ]
# Teacher: __ ____ 5th
# [ DIALOGUE CONTEXT ]
# Teacher: OK I see - that sounds very valuable. Would you do that in Tenerife? Is there high unemployment there?
# Student: Yes, I'd like to do it here. Unemployment is quite high in all Spain, especially in the south
#
# [ REFERENCE RESPONSE ]
# Teacher: OK I ____ - ____ ____ ____ valuable. ____ ____ do ____ in Tenerife? Is ____ ____ ____ there?
# [ DIALOGUE CONTEXT ]
# Student: maybe I need to use present perfect
# Teacher: Ah ...well if you're talking about right now then the present continuous is OK but have you used it correctly here?
# Teacher: THis is the same mistake you made before (that's why I'm asking you again!)
# Student: no..I think I talk about a period of the time.
# Teacher: OK <STUDENT> ...hold on
# Teacher: Don't worry about changing the tense...it's not the problem here
#
# [ REFERENCE RESPONSE ]
# Teacher: Don't ____ ____ ____ ____ tense...it's ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: Hi <STUDENT> all ok? Sorry for delay - connection problwm
# Student: Hi <TEACHER>
# Student: I’m fine
# Student: And you
# Teacher: Yes fine thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____
# [ DIALOGUE CONTEXT ]
# ...
# Teacher: OK! I feel a bit less bad now...
# Student: hahaha
#
# [ REFERENCE RESPONSE ]
# Teacher: OK! I ____ a ____ ____ ____ now...
# [ DIALOGUE CONTEXT ]
# Student: ok - I am very happy of the whole trip ( because the feeling is happen now ) - we were not obey the plan that we written before.
# Student: because the behaviour of write plan was happened before obey the plan, right?
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: I was confused when I heard about my grandmother's death.
# Student: I didn't use to be optimistic when I was a student.
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: okey, thanks
# Teacher: so the effect of x is NOUN ...OR the effect of x is that + CLAUSE (subject and verb)
# Teacher: or e.g. the effect of x is ADJECTIVE (common actually)
#
# [ REFERENCE RESPONSE ]
# Teacher: or e.g. ____ ____ of x is ____ (common actually)
# [ DIALOGUE CONTEXT ]
# Teacher: Where do you get your genes from?!
# Student: I think it must be form parents.
# Teacher: yes absolutely! So your parents pass on their genes OK? Another way of saying this = You _____ your genes/character from you r parents(like money when they die!)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ absolutely! So ____ ____ ____ on ____ ____ OK? ____ ____ of ____ ____ = ____ _____ ____ genes/character ____ ____ r parents(like ____ ____ ____ die!)
# [ DIALOGUE CONTEXT ]
# Student: Last year I went ti Frace
# Student: went to
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Teacher: Hi <STUDENT> are you there?
# Student: Hi <TEACHER>
# Student: Are you alright?
#
# [ REFERENCE RESPONSE ]
# Teacher: Hi <STUDENT> ____ ____ there?
# [ DIALOGUE CONTEXT ]
# Student: okey,thanks
# Teacher: And the answer for example = 'Yes I _____________ there twice'
# Student: Yes I have been to there twice.
# Teacher: OK great, correct! Did i say exactly when?
# Student: NO, just this behaviour was happened and we didn't know the time.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK great, correct! ____ i ____ ____ when?
# [ DIALOGUE CONTEXT ]
# Student: silent/difference/consequence
# Teacher: THanks <STUDENT>...you need to change one of your answers! Which one?
# Student: slience
# Teacher: Yes ok good!
# Teacher: You need 'something' right (a noun in other words) .... you can say need TO + verb
# Student: need to slent
# Student: silent
# Teacher: Ah well.....need to + verb so....where's the verb in your last example??
#
# [ REFERENCE RESPONSE ]
# Teacher: Ah well.....need to + ____ so....where's ____ ____ in ____ ____ example??
# [ DIALOGUE CONTEXT ]
# Student: languages
# Student: yes I see
# Teacher: yes good example!
# Teacher: give me a sentence with that one if you like
# Student: which one
# Teacher: languages...
# Teacher: cos it was your idea!
# Student: it's also important to develop languages skills to improve the communication with other agencies and colleagues
# Teacher: ok thanks! 'colleagues'/'develop skills' 'important to' = all good!
# Teacher: not 'the' though
# Student: yes sorry
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ 'the' ____
# [ DIALOGUE CONTEXT ]
# Teacher: That's OK - important thing is it's NOT past simple
# Teacher: OK <STUDENT> - shall we try a completely new topic to just get going and forget about these problems
# Student: yes.. I am ready.
#
# [ REFERENCE RESPONSE ]
# Teacher: OK <STUDENT> - ____ we ____ a ____ ____ ____ to ____ ____ ____ ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: it is good to try to do regular exercise
# Teacher: Yes both exercise and exercises means phyiscal activity (ah I see what you mean yes - exercises can be for school or whatever yes)
# Student: okay, I understand .
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ ____ ____ ____ (ah I ____ ____ ____ ____ ____ - ____ ____ be ____ ____ or ____ yes)
# [ DIALOGUE CONTEXT ]
# Student: so the answer is virtually?
# Teacher: yes!
# Student: ahhh
# Student: 6d
# Teacher: yep!
# Student: 77b
# Teacher: well done!
# Student: 8c
# Teacher: OK great  - a clear pass at CAE!
# Student: haha
# Student: The beginning was terrible!!
# Teacher: Well I forgive you the 'ranks' one - but not the 'overlook'! :)
# Student: oh thank you!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ I ____ ____ ____ 'ranks' ____ - ____ ____ ____ 'overlook'! :)
# [ DIALOGUE CONTEXT ]
# Student: Number 3 talks about his physical appearance
# Teacher: ok!
# Student: Number 5 talks about a local problem
# Teacher: yep
# Student: the most sarcastic I think it is number 2?
# Teacher: YEs absolutely! Classic British example - i could have written that myself!
# Student: haha
# Student: nobody here seems to suport Boris heres
# Student: but maybe number 4?
# Teacher: Yes i guess 'support' is not quite the right word!
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ i ____ 'support' is ____ ____ ____ ____ word!
# [ DIALOGUE CONTEXT ]
# Student: No, I don't know 'rake it in'. It's the first time I see it... I think
# Student: accumulate says my dictionary
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Teacher: Do you mean it's good to use 'normal' words instead of 'academic' words?
# Student: yes
# Teacher: OK right sorry yes I understand ...hold on...
# Teacher: I think the important thing is that you achieve the right result using the language you know as accurately as possible
# Teacher: in other words the priority is to write an effective intro
# Teacher: if you don't do that because ou make lots of mistakes trying to use 'difficult' words then no that's not great
#
# [ REFERENCE RESPONSE ]
# Teacher: if ____ don't do ____ ____ ou ____ ____ of ____ ____ to ____ 'difficult' ____ ____ no that's ____ ____
# [ DIALOGUE CONTEXT ]
# Student: organised
# Student: The sun gets on my balcony only a few hours a day so I try to make sure I go out on time!
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: It's famous in Japan as a hometown of the Peter Rabbit.
# Teacher: Yes, it's certainly very pretty - if you're lucky it's sunny (but cold) and clear - if not it just rains! Yes I get that about being famous in Japan - you see quite a few Japanese tourists there...
# Student: I hope you will have many sunny days there!
#
# [ REFERENCE RESPONSE ]
# Teacher: Yes, it's ____ ____ ____ - if you're ____ it's ____ (but cold) ____ ____ - if ____ it ____ rains! ____ I ____ ____ ____ ____ ____ in ____ - ____ ____ ____ a ____ ____ ____ there...
# [ DIALOGUE CONTEXT ]
# Student: I believe so, because if you had a high salary but a job that you don't really enjoy, it would be difficult for you to be happy
# Student: it's important to do a work that we can enjoy because it will be our main occupation during the day
#
# [ REFERENCE RESPONSE ]
# Teacher: None
# [ DIALOGUE CONTEXT ]
# Student: Do you?
# Teacher: ok well....yes definitely! it's very common
# Teacher: including in normal speaking
# Student: It sounds formal to me... but I see than I'm wrong
# Teacher: you know that you can something or someone for granted right?
# Teacher: take something or someone for granted
# Student: I think I know... I can't think of an examlo
# Student: example
# Student: I didn't know you could take someone for granted though
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ or ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: qualities
# Student: characters
# Teacher: yes good ...or characteristics ...OK? Both are countable and mean particular features ...your CHARACTER or PERSONALITY = uncountable (at least for one person they are uncountable )
# Teacher: So in other words a person's character or personality includes different specific qualities or characteristics (OK?)
# Student: not ok
# Teacher: Ha!
# Teacher: Hold on...
# Student: we can only write characteristics here
# Teacher: No 'qualities' is OK too = the same thing
# Teacher: Oh sorry yes you can't write character
#
# [ REFERENCE RESPONSE ]
# Teacher: Oh ____ ____ ____ can't ____ ____
# [ DIALOGUE CONTEXT ]
# Student: yes, i found my mistake
# Teacher: ok....
# Teacher: Yes sorry i see it -good!
# Student: thanks
# Teacher: Try to remember this OK? YOU make this mistake a lot!
# Student: yes, I need to check this point every time when I want to use present continuous.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ to ____ ____ OK? ____ ____ ____ ____ a lot!
# [ DIALOGUE CONTEXT ]
# Teacher: in your opinion?
# Student: of course, I suppose it is the best way for people's health.
# Teacher: OK fine ....so if you agree then you can just say that e.g.: I strongly agree that ....?
# Student: ok, I strongly agree that doing exercise is the best way
# Teacher: Or sorry....at the most basic level you could just say: I strongly agree with this idea.
#
# [ REFERENCE RESPONSE ]
# Teacher: Or sorry....at ____ ____ ____ ____ ____ ____ ____ say: I ____ ____ ____ ____ idea.
# [ DIALOGUE CONTEXT ]
# Student: New knowledge is always studied by me. when I had full motivation on it.
# Student: my parents were disappointed with my last IELTS score.
# Teacher: ok good
# Teacher: but bad sorry
# Teacher: OK <STUDENT>: 'when I had full motivation on it.'  try this again BUT with the verb/adjective structure we're focusing on ok?
#
# [ REFERENCE RESPONSE ]
# Teacher: OK <STUDENT>: 'when I ____ ____ ____ on it.' ____ ____ ____ ____ ____ ____ verb/adjective ____ we're ____ on ok?
# [ DIALOGUE CONTEXT ]
# Student: switch
# Teacher: beginning with'a' ...?
# Teacher: al...@?
# Student: alter
# Student: we lean it on class
# Teacher: yes OK - that's good as a general synonym for change
# Teacher: and good here too
# Student: okey,
# Teacher: switch ' is like one specific to another specific thing do you see ?
# Teacher: like from your left hand to your right hand for example
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ to ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Teacher: yes, well done!
# Student: Ýåý
# Teacher: Has he been to the USA?
# Teacher: I don't know ...
# Student: If  he has ever been to the USA
# Teacher: Perfect!
# Teacher: if or whether
# Teacher: It's starting to make sense, right?
# Student: AHA
# Teacher: It's called 'reported speech' but we use it way more often, with all kinds of 'I don't know' and 'I wonder'
# Teacher: not just 'he said'
# Student: őķ
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ 'he said'
# [ DIALOGUE CONTEXT ]
# Student: it might means wealth I guess
# Teacher: Ah! property is just another word for e.g. buildings/houses/flats etc
# Student: and including houses and others
# Teacher: Actually 'accommodation' would be good here too maybe right?
# Student: okey...thanks
# Teacher: AND your use of wealth is interesting
# Teacher: You could definitely include that somehow!
# Teacher: or similar words...wealth = adjective or noun?
#
# [ REFERENCE RESPONSE ]
# Teacher: or ____ words...wealth = ____ or noun?
# [ DIALOGUE CONTEXT ]
# Teacher: just one word!
# Teacher: You OK?! Bad internet connection?
# Student: yes, i am back
# Student: let me try
# Teacher: ok!
# Student: There are many museums in London. -
# Teacher: OK cool hold on
# Student: okey
#
# [ REFERENCE RESPONSE ]
# Teacher: OK ____ ____ on
# [ DIALOGUE CONTEXT ]
# Teacher: sure ... well 'firmly' first e.g. opposed/committed = common with noun forms too
# Student: By the way, I think the first question is wrong... Maybe 'which adj ca be used with highly?
# Teacher: well both possible... 'with which' and in general prepositions first = formal or normal?
# Student: Ahh thanks, I didn't sound good to me.
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ possible... 'with which' ____ in ____ ____ ____ = ____ or normal?
# [ DIALOGUE CONTEXT ]
# Student: I think I only know put on and off
# Teacher: Well these are good ones to know! Hold on a sec....(but you can continue if you like!)
# Teacher: tolerate/insult or kill!/delay/ suggest/install
# Teacher: can you think of a phrsal verb with put for these meanings?!  (you can use the 'logic' of the preposition as a rough guide(!)
# Student: No idea but I'll try
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ of a ____ ____ ____ ____ ____ ____ meanings?! (you ____ ____ ____ 'logic' of ____ ____ as a ____ guide(!)
# [ DIALOGUE CONTEXT ]
# Teacher: ok
# Student: 1. to start something
# Student: 2. to stop someone to do something
# Student: 3. boring
# Student: 4. Opportunity to change
# Student: 5. to be honest
# Student: 6. to boast
# Student: 7. prepare for something
# Student: 8. something you are good at
#
# [ REFERENCE RESPONSE ]
# Teacher: ok
# [ DIALOGUE CONTEXT ]
# Student: taking about the site, the sentences that are shown with the word are from texts??
# Student: Are all correct? I mean, the sentences...
# Teacher: yes it's called a concordance - have you seen one before? It just has a massive database of spoken and written texts from different sources and searches them for you
# Teacher: well, they're basically 'correct' yes - 'authentic' at least
# Teacher: For me <STUDENT> it's like a dictionary but better you know
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ me <STUDENT> it's ____ a ____ ____ ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: brith
# Teacher: ok yes 'birth'
# Teacher: AND number 3: Beethoven;s talent was 'i _ _ _ _ ' ?
# Teacher: It means something he was born with!
# Student: innate
# Teacher: ok great! And e.g. patience/honesty/kindness/selfishness etc are ....?
# Student: character
# Teacher: you need a COUNTABLE noun here ...so e.g. 'character' is not possible (at least in this context) - a person's character is made up of different _______?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ a ____ ____ ____ ...so e.g. 'character' is ____ ____ (at ____ in ____ context) - a person's ____ is ____ up of ____ _______?
# [ DIALOGUE CONTEXT ]
# Student: coal of electricity?
# Student: I don't know
# Teacher: OK no problem hold on a sec
# Student: I ask me the same question when I wrote the sentence
# Teacher: well...If you begin with e.g. Australia....can you continue from here?
# Teacher: you need a verb next obviously so 'Australia....'?
# Student: Australia use 50% of electricity....
# Teacher: OK nearly...! Did Australia 'use' electricity? well obviously yes but what about coal?
#
# [ REFERENCE RESPONSE ]
# Teacher: OK nearly...! ____ ____ 'use' electricity? ____ ____ ____ ____ ____ ____ coal?
# [ DIALOGUE CONTEXT ]
# Teacher: So OK <STUDENT> yes - this is a good idea and the CATEGORY here is 'scientific' right?
# Teacher: As in increasing fundamental  scientific knowledge...
# Student: 366.0
# Student: like why is 365days a year but sometime is 366 days.
# Teacher: Yes understood!
# Student: yes!! basic knowledge
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ understood!
# [ DIALOGUE CONTEXT ]
# Teacher: Hey welcome back
# Student: yes, I am here
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____
# [ DIALOGUE CONTEXT ]
# Student: Could you tell me another way of saying that they might be motivated to choose their profession by the high salary?
# Student: motivated by something is correct??
# Teacher: Yes OK sure...so 'motivated to' is a good idea...I was going to suggest a couple of phrases for this...yes: motivated to (do something) and 'motivated by (+noun) = good hold on
# Teacher: another good word here might be 'driven' OK?
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ ____ ____ ____ ____ be 'driven' OK?
# [ DIALOGUE CONTEXT ]
# Teacher: So e.g. newspapers exaggerate
# Student: ok, I am remembering those words
# Student: thanks
#
# [ REFERENCE RESPONSE ]
# Teacher: So e.g. ____ ____
# [ DIALOGUE CONTEXT ]
# Student: I want to continue
# Teacher: I understand that you are super busy!
# Student: but this time
# Student: I usually finish at 3 am
# Student: okay
# Student: let's talk about it later
# Teacher: Yes, have a think, ok?
# Student: okay
# Teacher: Oh, can we start a bit earlier on Tuesday, 9.45 am?
# Student: oh, what about the third lesson this week?
# Teacher: Ooh, thanks for reminding me!
# Teacher: Friday 10.30 am?
# Student: okay
# Teacher: Sure :)
#
# [ REFERENCE RESPONSE ]
# Teacher: ____ :)
# [ DIALOGUE CONTEXT ]
# Teacher: OK so <STUDENT>, thinking about the questions from yesterday about different jobs....so you were talking about football players and you said they have a very good salary ...hold on a sec
# Student: haha I don't know much about football but players from Barcelona club or Real Madrid earn far too much money
#
# [ REFERENCE RESPONSE ]
# Teacher: OK so <STUDENT>, ____ ____ ____ ____ ____ ____ ____ ____ jobs....so ____ ____ ____ ____ ____ ____ ____ ____ ____ ____ ____ a ____ ____ ____ ...hold on a ____

# %%
import json
import pandas as pd

# Load training data and separate teacher and student utterances
with open('train_with-reference.jsonl', 'r') as f:
    lines = f.readlines()
train_data = []
for line in lines:
    data = json.loads(line)
    teacher_utterances = []
    student_utterances = []
    for utterance in data['utterances']:
        if utterance['speaker'] == 'teacher':
            teacher_utterances.append(utterance['text'])
        elif utterance['speaker'] == 'student':
            student_utterances.append(utterance['text'])
    train_data.append({'id': data['id'], 'teacher_utterances': teacher_utterances, 'student_utterances': student_utterances})
train_df = pd.DataFrame(train_data)

# Define function to generate teacher response with blanks
def generate_teacher_response(teacher_utterances):
    if len(teacher_utterances) == 0:
        # If there are no teacher utterances, return None
        return None
    else:
        # Select the last teacher utterance
        teacher_utterance = teacher_utterances[-1]
        # Replace some words in the teacher utterance with blanks
        blanks = ['____' if w.isalpha() and len(w) > 2 else w for w in teacher_utterance.split()]
        return ' '.join(blanks)

# Load test data and generate teacher responses for test data
with open('test_without-reference.jsonl', 'r') as f:
    lines = f.readlines()
test_data = []
for line in lines:
    data = json.loads(line)
    test_id = data['id']
    utterances = data['utterances']
    teacher_response = generate_teacher_response([u['text'] for u in utterances if u['speaker'] == 'teacher'])
    test_data.append({'id': test_id, 'context': utterances, 'reference_response': teacher_response})
test_df = pd.DataFrame(test_data)

# Save test data with teacher responses to file
with open('test_with-teacherResponses.jsonl', 'w') as f:
    for line in test_df.to_json(orient='records', lines=True).split('\n'):
        if line.strip():
            f.write(json.dumps(json.loads(line)) + '\n')
